# %%
import gammapy 
print(f'loaded gammapy version: {gammapy.__version__} ' )
print(f'Supposed to be 1.0 (21-12-2022)' )
# Out:
# loaded gammapy version: 1.0
# Supposed to be 1.0 (21-12-2022)

# %%
#get_ipython().system('jupyter nbconvert --to script 1-Nui_Par_Fitting.ipynb')
import pyximport

pyximport.install()
import matplotlib.pyplot as plt
import numpy as np
import astropy.units as u
import gammapy

# from gammapy.datasets import MapDataset
from gammapy.maps import Map
from astropy.coordinates import SkyCoord, Angle
from gammapy.modeling import Fit, Parameter, Parameters, Covariance
from gammapy.datasets import MapDataset , Datasets#, MapDatasetNuisance
from gammapy.modeling.models import (
    PowerLawSpectralModel,
    create_crab_spectral_model,
    SkyModel,
    PointSpatialModel,
    ShellSpatialModel,
    GeneralizedGaussianSpatialModel,
    TemplateSpatialModel,
    LogParabolaSpectralModel,
    GaussianSpatialModel,
    DiskSpatialModel,
    PowerLawNormSpectralModel,
    Models,
    SpatialModel,
    FoVBackgroundModel,
    ExpCutoffPowerLawSpectralModel
)
from gammapy.estimators import TSMapEstimator, ExcessMapEstimator
from gammapy.estimators import FluxPoints
from gammapy.estimators import FluxPointsEstimator

from regions import CircleSkyRegion, RectangleSkyRegion
import yaml
import sys

#sys.path.append(
#    "/home/hpc/caph/mppi045h/3D_analysis/N_parameters_in_L/syserror_3d_bkgmodel/4-Fitting_nuisance_and_model_parameters"
#)
#from my_dataset_maps_20 import MapDatasetNuisance
#from MapDatasetNuisanceE import MapDatasetNuisanceE
#from  my_fit_20 import Fit
from Dataset_Creation import sys_dataset

# %% [markdown]
# ## Read dataset

# %%
dataset_asimov = MapDataset.read("c:/users/yt02izug/downloads/dataset_asimov/dataset_asimov.fits")
# Create the spatial model 
model_spatial = GaussianSpatialModel(
    lon_0="83.631 deg",
    lat_0="22.018 deg",
    sigma="0.02 deg",
    )

# Create the spectral model 
model_spectrum  = ExpCutoffPowerLawSpectralModel(
    index=2.3,
    amplitude="1e-12 TeV-1 cm-2 s-1",
    lambda_="0.1 TeV-1")

# combine the spectral and the spatial model
source_model = SkyModel(spatial_model = model_spatial ,
                       spectral_model = model_spectrum,
                       name = "Source")    
models = Models(source_model)

# Create the model for the Background
bkg_model = FoVBackgroundModel(dataset_name=dataset_asimov.name)
bkg_model.parameters['tilt'].frozen  = False
models.append(bkg_model)

# set the models in the dataset
dataset_asimov.models = models
# set counts
dataset_asimov.counts = dataset_asimov.npred()
    
dataset_asimov.counts.sum_over_axes().plot(add_cbar=1)
binsize = dataset_asimov.geoms["geom"].width[1] / dataset_asimov.geoms["geom"].data_shape[1]
print(
    "spatial binsize = ",
    binsize
)

print(dataset_asimov)
# Out:
# spatial binsize =  [0.08] deg
# MapDataset
# ----------
#
#   Name                            : 1MUXqVCD
#
#   Total counts                    : 361088
#   Total background counts         : 360331.31
#   Total excess counts             : 756.96
#
#   Predicted counts                : 361088.27
#   Predicted background counts     : 360331.34
#   Predicted excess counts         : 756.93
#
#   Exposure min                    : 2.07e-01 m2 s
#   Exposure max                    : 2.41e+11 m2 s
#
#   Number of total bins            : 540000
#   Number of fit bins              : 180191
#
#   Fit statistic type              : cash
#   Fit statistic value (-2 log(L)) : -752490.77
#
#   Number of models                : 2
#   Number of parameters            : 13
#   Number of free parameters       : 8
#
#   Component 0: SkyModel
#
#     Name                      : Source
#     Datasets names            : None
#     Spectral model type       : ExpCutoffPowerLawSpectralModel
#     Spatial  model type       : GaussianSpatialModel
#     Temporal model type       :
#     Parameters:
#       index                         :      2.300   +/-    0.00
#       amplitude                     :   1.00e-12   +/- 0.0e+00 1 / (cm2 s TeV)
#       reference             (frozen):      1.000       TeV
#       lambda_                       :      0.100   +/-    0.00 1 / TeV
#       alpha                 (frozen):      1.000
#       lon_0                         :     83.631   +/-    0.00 deg
#       lat_0                         :     22.018   +/-    0.00 deg
#       sigma                         :      0.020   +/-    0.00 deg
#       e                     (frozen):      0.000
#       phi                   (frozen):      0.000       deg
#
#   Component 1: FoVBackgroundModel
#
#     Name                      : 1MUXqVCD-bkg
#     Datasets names            : ['1MUXqVCD']
#     Spectral model type       : PowerLawNormSpectralModel
#     Parameters:
#       norm                          :      1.000   +/-    0.00
#       tilt                          :      0.000   +/-    0.00
#       reference             (frozen):      1.000       TeV

# %% [markdown]
# ## Varying the Exposure

# %%
savefig = False
picformat = 'svg'
shift = 0.10 #0.085
tilt = 0.015

# %%
infos = np.loadtxt("data/7a_P_draw_info.txt")
pars = np.loadtxt("data/7a_P_draw_par.txt")
flux = np.loadtxt("data/7a_P_draw_flux.txt")
flux2e = np.loadtxt("data/7a_P_draw_flux2e.txt")


lem = len(infos)
N_max = 1000
N = np.min([lem, N_max])

print(N)

shift_rnds = infos[:N_max,0]
index_rnds = infos[:N_max,1]
stat_sums = infos[:N_max,2]


#amplitude', 'index', 'norm', 'tilt
amplitudes = pars[:N_max,0:2] 
indices = pars[:N_max,2:4] 
norms = pars[:N_max,4:6]
tilts = pars[:N_max,6:8]


fluxpoints = []
for f in shift_rnds:
    try:
        print(f'6_fluxpoints_{f:.6}')
        ff = FluxPoints.read(f'data/fluxpoints/6_fluxpoints_{f:.6}.fits') 
        fluxpoints.append(ff)
        
    except:
        pass
print(len(fluxpoints), len(shift_rnds))    
N = len(fluxpoints)
# Out:
# 800
# 6_fluxpoints_0.0587511
# 6_fluxpoints_-0.0834672
# 6_fluxpoints_-0.0297893
# 6_fluxpoints_-0.108303
# 6_fluxpoints_0.130234
# 6_fluxpoints_0.219417
# 6_fluxpoints_0.0270887
# 6_fluxpoints_0.130775
# 6_fluxpoints_0.0225195
# 6_fluxpoints_0.0722159
# 6_fluxpoints_-0.0450871
# 6_fluxpoints_0.0611925
# 6_fluxpoints_-0.0404032
# 6_fluxpoints_-0.0151012
# 6_fluxpoints_-0.102772
# 6_fluxpoints_-0.105511
# 6_fluxpoints_-0.000659377
# 6_fluxpoints_-0.0718063
# 6_fluxpoints_-0.129751
# 6_fluxpoints_0.119162
# 6_fluxpoints_-0.126375
# 6_fluxpoints_-0.0244642
# 6_fluxpoints_-0.0850446
# 6_fluxpoints_0.105678
# 6_fluxpoints_0.00571947
# 6_fluxpoints_0.0827513
# 6_fluxpoints_0.0287238
# 6_fluxpoints_0.0164942
# 6_fluxpoints_0.112043
# 6_fluxpoints_-0.157228
# 6_fluxpoints_-0.0784632
# 6_fluxpoints_0.0287266
# 6_fluxpoints_0.0466975
# 6_fluxpoints_-0.0900618
# 6_fluxpoints_-0.0248642
# 6_fluxpoints_0.128366
# 6_fluxpoints_-0.0928336
# 6_fluxpoints_0.0361148
# 6_fluxpoints_-0.12212
# 6_fluxpoints_-0.0215537
# 6_fluxpoints_-0.192108
# 6_fluxpoints_-0.0972778
# 6_fluxpoints_0.0554357
# 6_fluxpoints_0.039202
# 6_fluxpoints_-0.0416942
# 6_fluxpoints_-0.015059
# 6_fluxpoints_-0.0588986
# 6_fluxpoints_0.0936974
# 6_fluxpoints_0.0268676
# 6_fluxpoints_-0.0570891
# 6_fluxpoints_-0.024409
# 6_fluxpoints_0.0618932
# 6_fluxpoints_0.048129
# 6_fluxpoints_0.134698
# 6_fluxpoints_0.0138476
# 6_fluxpoints_0.0858172
# 6_fluxpoints_0.0995076
# 6_fluxpoints_-0.00102437
# 6_fluxpoints_-0.159208
# 6_fluxpoints_-0.0134268
# 6_fluxpoints_0.13398
# 6_fluxpoints_-0.0235983
# 6_fluxpoints_-0.0939525
# 6_fluxpoints_0.104606
# 6_fluxpoints_0.0599135
# 6_fluxpoints_-0.00341007
# 6_fluxpoints_0.000779187
# 6_fluxpoints_-0.116651
# 6_fluxpoints_0.0199913
# 6_fluxpoints_-0.149753
# 6_fluxpoints_-0.138815
# 6_fluxpoints_0.112486
# 6_fluxpoints_-0.0135109
# 6_fluxpoints_0.052442
# 6_fluxpoints_-0.0757239
# 6_fluxpoints_-0.100134
# 6_fluxpoints_0.0531379
# 6_fluxpoints_0.0840445
# 6_fluxpoints_0.0244894
# 6_fluxpoints_0.0774653
# 6_fluxpoints_-0.0603014
# 6_fluxpoints_-0.0343568
# 6_fluxpoints_-0.0993885
# 6_fluxpoints_0.106225
# 6_fluxpoints_0.0192624
# 6_fluxpoints_-0.0930873
# 6_fluxpoints_-0.0686253
# 6_fluxpoints_0.0280467
# 6_fluxpoints_0.109585
# 6_fluxpoints_0.07046
# 6_fluxpoints_-0.0820485
# 6_fluxpoints_-0.068715
# 6_fluxpoints_0.0701682
# 6_fluxpoints_0.0262276
# 6_fluxpoints_0.096092
# 6_fluxpoints_-0.0463402
# 6_fluxpoints_0.0374344
# 6_fluxpoints_-0.228022
# 6_fluxpoints_0.154014
# 6_fluxpoints_0.0226928
# 6_fluxpoints_0.00134122
# 6_fluxpoints_-0.00857024
# 6_fluxpoints_0.0339969
# 6_fluxpoints_-0.191231
# 6_fluxpoints_0.0182077
# 6_fluxpoints_-0.149554
# 6_fluxpoints_-0.0703616
# 6_fluxpoints_0.0116291
# 6_fluxpoints_-0.0125079
# 6_fluxpoints_0.0131307
# 6_fluxpoints_-0.0384898
# 6_fluxpoints_-0.0172624
# 6_fluxpoints_-0.00162729
# 6_fluxpoints_0.0380632
# 6_fluxpoints_0.0746107
# 6_fluxpoints_0.00831804
# 6_fluxpoints_0.0107916
# 6_fluxpoints_0.226941
# 6_fluxpoints_0.076688
# 6_fluxpoints_0.0405778
# 6_fluxpoints_-0.00512148
# 6_fluxpoints_0.154549
# 6_fluxpoints_0.114627
# 6_fluxpoints_0.194038
# 6_fluxpoints_0.0154531
# 6_fluxpoints_0.109202
# 6_fluxpoints_-0.143264
# 6_fluxpoints_0.182201
# 6_fluxpoints_-0.05238
# 6_fluxpoints_0.0205834
# 6_fluxpoints_0.192086
# 6_fluxpoints_0.0657627
# 6_fluxpoints_0.0155671
# 6_fluxpoints_0.0491454
# 6_fluxpoints_-0.0301703
# 6_fluxpoints_0.0144812
# 6_fluxpoints_-0.103484
# 6_fluxpoints_-0.111943
# 6_fluxpoints_-0.0329554
# 6_fluxpoints_-0.0641372
# 6_fluxpoints_0.0621911
# 6_fluxpoints_-0.108555
# 6_fluxpoints_-0.0543847
# 6_fluxpoints_0.0316448
# 6_fluxpoints_-0.0505239
# 6_fluxpoints_0.0819192
# 6_fluxpoints_-0.0101972
# 6_fluxpoints_-0.0991278
# 6_fluxpoints_0.125399
# 6_fluxpoints_-0.0767159
# 6_fluxpoints_-0.142573
# 6_fluxpoints_-0.0223745
# 6_fluxpoints_0.0809679
# 6_fluxpoints_0.0573019
# 6_fluxpoints_0.104578
# 6_fluxpoints_0.0318384
# 6_fluxpoints_-0.0701417
# 6_fluxpoints_-0.0801037
# 6_fluxpoints_-0.0272312
# 6_fluxpoints_0.0370057
# 6_fluxpoints_0.199517
# 6_fluxpoints_0.0919859
# 6_fluxpoints_-0.164502
# 6_fluxpoints_0.119095
# 6_fluxpoints_-0.0823812
# 6_fluxpoints_-0.105253
# 6_fluxpoints_-0.0216152
# 6_fluxpoints_-0.034489
# 6_fluxpoints_0.0376686
# 6_fluxpoints_-0.0917034
# 6_fluxpoints_0.0137302
# 6_fluxpoints_0.018096
# 6_fluxpoints_0.0413917
# 6_fluxpoints_0.0400123
# 6_fluxpoints_0.00373259
# 6_fluxpoints_-0.0210742
# 6_fluxpoints_-0.138765
# 6_fluxpoints_-0.170193
# 6_fluxpoints_0.100554
# 6_fluxpoints_0.130592
# 6_fluxpoints_0.169485
# 6_fluxpoints_-0.0472763
# 6_fluxpoints_-0.0746706
# 6_fluxpoints_0.0473322
# 6_fluxpoints_-0.118784
# 6_fluxpoints_0.113901
# 6_fluxpoints_-0.0155648
# 6_fluxpoints_0.0332051
# 6_fluxpoints_0.0540966
# 6_fluxpoints_-0.0510016
# 6_fluxpoints_0.0460374
# 6_fluxpoints_-0.0668737
# 6_fluxpoints_0.0595957
# 6_fluxpoints_0.090836
# 6_fluxpoints_-0.227787
# 6_fluxpoints_0.00951913
# 6_fluxpoints_-0.135258
# 6_fluxpoints_-0.205015
# 6_fluxpoints_-0.0667519
# 6_fluxpoints_0.00860167
# 6_fluxpoints_0.00608534
# 6_fluxpoints_-0.0741375
# 6_fluxpoints_0.0669476
# 6_fluxpoints_0.0407692
# 6_fluxpoints_-0.054469
# 6_fluxpoints_-0.00717886
# 6_fluxpoints_0.0167887
# 6_fluxpoints_-0.176658
# 6_fluxpoints_0.0917946
# 6_fluxpoints_-0.105394
# 6_fluxpoints_0.0731613
# 6_fluxpoints_0.0285445
# 6_fluxpoints_-0.0079039
# 6_fluxpoints_-0.238605
# 6_fluxpoints_-0.0531876
# 6_fluxpoints_-0.15782
# 6_fluxpoints_0.117518
# 6_fluxpoints_0.125107
# 6_fluxpoints_0.0521468
# 6_fluxpoints_0.0669195
# 6_fluxpoints_-0.0386512
# 6_fluxpoints_0.0246342
# 6_fluxpoints_0.0642217
# 6_fluxpoints_-0.0848078
# 6_fluxpoints_0.145423
# 6_fluxpoints_-0.0398574
# 6_fluxpoints_0.0256853
# 6_fluxpoints_-0.0781488
# 6_fluxpoints_0.00184299
# 6_fluxpoints_0.0357707
# 6_fluxpoints_-0.118353
# 6_fluxpoints_0.212228
# 6_fluxpoints_0.0448049
# 6_fluxpoints_-0.0767433
# 6_fluxpoints_-0.143617
# 6_fluxpoints_0.07053
# 6_fluxpoints_0.174476
# 6_fluxpoints_0.0327163
# 6_fluxpoints_-0.0966464
# 6_fluxpoints_-0.0834754
# 6_fluxpoints_-0.0613301
# 6_fluxpoints_-0.00454745
# 6_fluxpoints_0.0324773
# 6_fluxpoints_0.0514335
# 6_fluxpoints_-0.0422227
# 6_fluxpoints_0.154404
# 6_fluxpoints_-0.139781
# 6_fluxpoints_-0.00528628
# 6_fluxpoints_-0.142237
# 6_fluxpoints_0.134735
# 6_fluxpoints_0.060044
# 6_fluxpoints_-0.0601424
# 6_fluxpoints_-0.0190189
# 6_fluxpoints_-0.0362929
# 6_fluxpoints_-0.146234
# 6_fluxpoints_-1.60529e-05
# 6_fluxpoints_0.175448
# 6_fluxpoints_-0.0973235
# 6_fluxpoints_0.147432
# 6_fluxpoints_-0.0123899
# 6_fluxpoints_0.120178
# 6_fluxpoints_0.0380333
# 6_fluxpoints_-0.120409
# 6_fluxpoints_0.105948
# 6_fluxpoints_0.00830679
# 6_fluxpoints_0.0617099
# 6_fluxpoints_-0.0363627
# 6_fluxpoints_0.0159675
# 6_fluxpoints_0.0923645
# 6_fluxpoints_-0.0216086
# 6_fluxpoints_0.0719418
# 6_fluxpoints_0.205067
# 6_fluxpoints_-0.00698393
# 6_fluxpoints_0.0279001
# 6_fluxpoints_-0.101868
# 6_fluxpoints_0.0370717
# 6_fluxpoints_0.00635665
# 6_fluxpoints_0.0201741
# 6_fluxpoints_0.0445037
# 6_fluxpoints_0.151806
# 6_fluxpoints_-0.0717365
# 6_fluxpoints_0.00784302
# 6_fluxpoints_-0.0709185
# 6_fluxpoints_0.0910539
# 6_fluxpoints_-0.155766
# 6_fluxpoints_-0.0704012
# 6_fluxpoints_-0.0073482
# 6_fluxpoints_0.00334214
# 6_fluxpoints_0.0694114
# 6_fluxpoints_0.13
# 6_fluxpoints_-0.0519043
# 6_fluxpoints_-0.0779029
# 6_fluxpoints_0.0573783
# 6_fluxpoints_-0.128959
# 6_fluxpoints_0.0856604
# 6_fluxpoints_-0.0514831
# 6_fluxpoints_-0.117589
# 6_fluxpoints_0.0939116
# 6_fluxpoints_0.112525
# 6_fluxpoints_0.0542476
# 6_fluxpoints_0.0981002
# 6_fluxpoints_-0.201861
# 6_fluxpoints_-0.193006
# 6_fluxpoints_-0.0851471
# 6_fluxpoints_-0.033686
# 6_fluxpoints_0.020119
# 6_fluxpoints_-0.0844304
# 6_fluxpoints_-0.0318896
# 6_fluxpoints_-0.131519
# 6_fluxpoints_-0.0341724
# 6_fluxpoints_-0.0274785
# 6_fluxpoints_0.199147
# 6_fluxpoints_0.083053
# 6_fluxpoints_-0.0546934
# 6_fluxpoints_-0.184745
# 6_fluxpoints_-0.118413
# 6_fluxpoints_0.122977
# 6_fluxpoints_-0.10977
# 6_fluxpoints_-0.000722074
# 6_fluxpoints_0.118614
# 6_fluxpoints_0.154503
# 6_fluxpoints_0.191868
# 6_fluxpoints_0.00129177
# 6_fluxpoints_-0.000815662
# 6_fluxpoints_0.0852101
# 6_fluxpoints_0.0435087
# 6_fluxpoints_-0.00453725
# 6_fluxpoints_0.12265
# 6_fluxpoints_-0.175597
# 6_fluxpoints_0.067095
# 6_fluxpoints_-0.0170753
# 6_fluxpoints_-0.0720095
# 6_fluxpoints_-0.022283
# 6_fluxpoints_0.0202128
# 6_fluxpoints_-0.0586819
# 6_fluxpoints_0.0640188
# 6_fluxpoints_-0.0363891
# 6_fluxpoints_-0.105463
# 6_fluxpoints_0.0109908
# 6_fluxpoints_-0.0302497
# 6_fluxpoints_-0.101817
# 6_fluxpoints_0.042497
# 6_fluxpoints_-0.0733643
# 6_fluxpoints_-0.0803182
# 6_fluxpoints_-0.0756528
# 6_fluxpoints_-0.0348576
# 6_fluxpoints_0.0592592
# 6_fluxpoints_-0.0762559
# 6_fluxpoints_-0.115972
# 6_fluxpoints_0.0368869
# 6_fluxpoints_-0.0234225
# 6_fluxpoints_0.0718115
# 6_fluxpoints_-0.04618
# 6_fluxpoints_0.018976
# 6_fluxpoints_0.00761636
# 6_fluxpoints_-0.027247
# 6_fluxpoints_-0.135102
# 6_fluxpoints_0.103237
# 6_fluxpoints_0.0355757
# 6_fluxpoints_0.0488158
# 6_fluxpoints_-0.182822
# 6_fluxpoints_-0.11947
# 6_fluxpoints_-0.0576593
# 6_fluxpoints_-0.0193596
# 6_fluxpoints_0.101489
# 6_fluxpoints_-0.0354886
# 6_fluxpoints_-0.101356
# 6_fluxpoints_0.0234417
# 6_fluxpoints_-0.0794959
# 6_fluxpoints_0.212711
# 6_fluxpoints_0.125999
# 6_fluxpoints_-0.00291421
# 6_fluxpoints_0.154107
# 6_fluxpoints_-0.0154322
# 6_fluxpoints_0.107282
# 6_fluxpoints_-0.180015
# 6_fluxpoints_-0.0134621
# 6_fluxpoints_0.0763381
# 6_fluxpoints_0.0415279
# 6_fluxpoints_0.0595154
# 6_fluxpoints_-0.169896
# 6_fluxpoints_0.0052107
# 6_fluxpoints_-0.117317
# 6_fluxpoints_-0.0870266
# 6_fluxpoints_0.252955
# 6_fluxpoints_0.0828518
# 6_fluxpoints_-0.0346635
# 6_fluxpoints_-0.0392275
# 6_fluxpoints_0.157461
# 6_fluxpoints_-0.0942554
# 6_fluxpoints_0.024155
# 6_fluxpoints_-0.00809519
# 6_fluxpoints_0.107299
# 6_fluxpoints_-0.0452534
# 6_fluxpoints_-0.00726907
# 6_fluxpoints_0.0552977
# 6_fluxpoints_-0.0375019
# 6_fluxpoints_0.225851
# 6_fluxpoints_0.0793955
# 6_fluxpoints_-0.0853796
# 6_fluxpoints_-0.0101469
# 6_fluxpoints_-0.0704513
# 6_fluxpoints_-0.0132103
# 6_fluxpoints_-0.0421375
# 6_fluxpoints_-0.120184
# 6_fluxpoints_-0.044967
# 6_fluxpoints_0.223618
# 6_fluxpoints_0.135884
# 6_fluxpoints_0.0842827
# 6_fluxpoints_-0.0641405
# 6_fluxpoints_0.239231
# 6_fluxpoints_-0.146009
# 6_fluxpoints_0.0820453
# 6_fluxpoints_0.0299802
# 6_fluxpoints_-0.0165536
# 6_fluxpoints_-0.105257
# 6_fluxpoints_0.0524852
# 6_fluxpoints_0.00180205
# 6_fluxpoints_-0.0228239
# 6_fluxpoints_0.100373
# 6_fluxpoints_-0.071501
# 6_fluxpoints_0.121427
# 6_fluxpoints_0.0427544
# 6_fluxpoints_-0.0334309
# 6_fluxpoints_-0.0214868
# 6_fluxpoints_-0.0975238
# 6_fluxpoints_0.190809
# 6_fluxpoints_0.0557841
# 6_fluxpoints_0.0186223
# 6_fluxpoints_-0.0865553
# 6_fluxpoints_-0.0948667
# 6_fluxpoints_-0.0434366
# 6_fluxpoints_0.129312
# 6_fluxpoints_-0.0320484
# 6_fluxpoints_-0.0146378
# 6_fluxpoints_-0.0677279
# 6_fluxpoints_0.0305381
# 6_fluxpoints_0.150325
# 6_fluxpoints_0.00461636
# 6_fluxpoints_0.0473971
# 6_fluxpoints_0.0190463
# 6_fluxpoints_0.250506
# 6_fluxpoints_0.100647
# 6_fluxpoints_-0.18178
# 6_fluxpoints_-0.0796643
# 6_fluxpoints_0.0137853
# 6_fluxpoints_0.00254031
# 6_fluxpoints_0.0124433
# 6_fluxpoints_-0.065891
# 6_fluxpoints_-0.0876053
# 6_fluxpoints_-0.132534
# 6_fluxpoints_0.120633
# 6_fluxpoints_-0.0590143
# 6_fluxpoints_-0.0504122
# 6_fluxpoints_0.0429036
# 6_fluxpoints_-0.0498859
# 6_fluxpoints_-0.194369
# 6_fluxpoints_0.0166905
# 6_fluxpoints_-0.00433328
# 6_fluxpoints_-0.0149896
# 6_fluxpoints_-0.0739901
# 6_fluxpoints_-0.0144931
# 6_fluxpoints_0.156248
# 6_fluxpoints_0.256618
# 6_fluxpoints_0.0461549
# 6_fluxpoints_-0.122728
# 6_fluxpoints_0.150505
# 6_fluxpoints_0.148528
# 6_fluxpoints_-0.0791796
# 6_fluxpoints_0.181353
# 6_fluxpoints_0.0675402
# 6_fluxpoints_-0.0531076
# 6_fluxpoints_-0.0382779
# 6_fluxpoints_0.121012
# 6_fluxpoints_0.148099
# 6_fluxpoints_-0.0654236
# 6_fluxpoints_0.0986364
# 6_fluxpoints_0.288185
# 6_fluxpoints_0.0571193
# 6_fluxpoints_-0.0751216
# 6_fluxpoints_0.047818
# 6_fluxpoints_-0.0171397
# 6_fluxpoints_0.130647
# 6_fluxpoints_0.0971632
# 6_fluxpoints_-0.0653482
# 6_fluxpoints_-0.258655
# 6_fluxpoints_-0.0465163
# 6_fluxpoints_0.0361582
# 6_fluxpoints_0.0245831
# 6_fluxpoints_0.0305065
# 6_fluxpoints_-0.090436
# 6_fluxpoints_0.143613
# 6_fluxpoints_0.0110618
# 6_fluxpoints_0.0366426
# 6_fluxpoints_-0.119133
# 6_fluxpoints_0.0798868
# 6_fluxpoints_-0.0239687
# 6_fluxpoints_-0.0784927
# 6_fluxpoints_0.0705162
# 6_fluxpoints_0.145211
# 6_fluxpoints_0.114943
# 6_fluxpoints_0.0305461
# 6_fluxpoints_-0.0559118
# 6_fluxpoints_0.0198272
# 6_fluxpoints_-0.112477
# 6_fluxpoints_-0.15947
# 6_fluxpoints_-0.0626826
# 6_fluxpoints_0.030581
# 6_fluxpoints_0.037443
# 6_fluxpoints_0.0067419
# 6_fluxpoints_-0.000809206
# 6_fluxpoints_0.119522
# 6_fluxpoints_-0.0957253
# 6_fluxpoints_-0.0370766
# 6_fluxpoints_0.00176942
# 6_fluxpoints_-0.0502621
# 6_fluxpoints_-0.0306065
# 6_fluxpoints_-0.0585862
# 6_fluxpoints_-0.0276523
# 6_fluxpoints_-0.259362
# 6_fluxpoints_0.00270986
# 6_fluxpoints_0.0832511
# 6_fluxpoints_0.136527
# 6_fluxpoints_0.108302
# 6_fluxpoints_-0.0289466
# 6_fluxpoints_0.127352
# 6_fluxpoints_0.0350472
# 6_fluxpoints_0.0648517
# 6_fluxpoints_-0.0809419
# 6_fluxpoints_0.0269531
# 6_fluxpoints_0.378778
# 6_fluxpoints_-0.10237
# 6_fluxpoints_0.0136175
# 6_fluxpoints_-0.00275835
# 6_fluxpoints_-0.000282608
# 6_fluxpoints_0.0265713
# 6_fluxpoints_0.0911344
# 6_fluxpoints_0.0395397
# 6_fluxpoints_-0.100688
# 6_fluxpoints_-0.0349497
# 6_fluxpoints_-0.0669233
# 6_fluxpoints_-0.0979609
# 6_fluxpoints_-0.130561
# 6_fluxpoints_-0.193586
# 6_fluxpoints_-0.0761029
# 6_fluxpoints_0.0128828
# 6_fluxpoints_0.0207886
# 6_fluxpoints_0.0024643
# 6_fluxpoints_0.000527638
# 6_fluxpoints_-0.0650905
# 6_fluxpoints_0.0392278
# 6_fluxpoints_0.197279
# 6_fluxpoints_0.224919
# 6_fluxpoints_0.0343602
# 6_fluxpoints_0.190255
# 6_fluxpoints_-0.110586
# 6_fluxpoints_-0.0052766
# 6_fluxpoints_-0.0435684
# 6_fluxpoints_-0.0802355
# 6_fluxpoints_-0.0459336
# 6_fluxpoints_0.13914
# 6_fluxpoints_-0.226993
# 6_fluxpoints_-0.00113952
# 6_fluxpoints_0.0411193
# 6_fluxpoints_-0.170021
# 6_fluxpoints_-0.0293992
# 6_fluxpoints_0.18344
# 6_fluxpoints_-0.034337
# 6_fluxpoints_0.0636507
# 6_fluxpoints_0.00503099
# 6_fluxpoints_-0.0584706
# 6_fluxpoints_-0.158152
# 6_fluxpoints_0.000553524
# 6_fluxpoints_-0.0175064
# 6_fluxpoints_-0.00624403
# 6_fluxpoints_-0.0913904
# 6_fluxpoints_-0.0703412
# 6_fluxpoints_0.0223522
# 6_fluxpoints_0.0848859
# 6_fluxpoints_0.0623996
# 6_fluxpoints_0.0557389
# 6_fluxpoints_-0.12662
# 6_fluxpoints_0.0343423
# 6_fluxpoints_-0.182702
# 6_fluxpoints_0.14218
# 6_fluxpoints_-0.210596
# 6_fluxpoints_-0.219648
# 6_fluxpoints_-0.01176
# 6_fluxpoints_-0.0218144
# 6_fluxpoints_0.044865
# 6_fluxpoints_0.0183778
# 6_fluxpoints_-0.164194
# 6_fluxpoints_0.0969617
# 6_fluxpoints_-0.0931287
# 6_fluxpoints_0.191585
# 6_fluxpoints_-0.108843
# 6_fluxpoints_0.00839145
# 6_fluxpoints_0.175642
# 6_fluxpoints_0.0162483
# 6_fluxpoints_0.0194937
# 6_fluxpoints_0.101586
# 6_fluxpoints_0.149924
# 6_fluxpoints_-0.0470835
# 6_fluxpoints_-0.0476775
# 6_fluxpoints_0.155783
# 6_fluxpoints_-0.0973476
# 6_fluxpoints_0.0828544
# 6_fluxpoints_-0.0903927
# 6_fluxpoints_-0.209104
# 6_fluxpoints_0.0381021
# 6_fluxpoints_-0.0732359
# 6_fluxpoints_0.0798336
# 6_fluxpoints_-0.0316879
# 6_fluxpoints_-0.0741384
# 6_fluxpoints_-0.0752519
# 6_fluxpoints_-0.00263753
# 6_fluxpoints_0.10889
# 6_fluxpoints_-0.080359
# 6_fluxpoints_-0.0453182
# 6_fluxpoints_-0.0394462
# 6_fluxpoints_0.163481
# 6_fluxpoints_0.0186673
# 6_fluxpoints_-0.0952279
# 6_fluxpoints_-0.095709
# 6_fluxpoints_-0.156743
# 6_fluxpoints_0.06098
# 6_fluxpoints_-0.0964213
# 6_fluxpoints_-0.0595307
# 6_fluxpoints_0.0666663
# 6_fluxpoints_0.0538777
# 6_fluxpoints_0.0586248
# 6_fluxpoints_-0.000190356
# 6_fluxpoints_0.0536717
# 6_fluxpoints_0.139123
# 6_fluxpoints_0.0250277
# 6_fluxpoints_-0.0017001
# 6_fluxpoints_0.073418
# 6_fluxpoints_0.0215663
# 6_fluxpoints_0.0733591
# 6_fluxpoints_-0.0793868
# 6_fluxpoints_-0.0373877
# 6_fluxpoints_0.189855
# 6_fluxpoints_0.0474207
# 6_fluxpoints_-0.0756181
# 6_fluxpoints_0.0146873
# 6_fluxpoints_-0.0996698
# 6_fluxpoints_0.238089
# 6_fluxpoints_-0.0469703
# 6_fluxpoints_0.00863508
# 6_fluxpoints_0.0758159
# 6_fluxpoints_-0.0231529
# 6_fluxpoints_0.0397227
# 6_fluxpoints_-0.175459
# 6_fluxpoints_0.0859874
# 6_fluxpoints_-0.120624
# 6_fluxpoints_-0.0424742
# 6_fluxpoints_-0.01721
# 6_fluxpoints_-0.157366
# 6_fluxpoints_0.0259524
# 6_fluxpoints_0.0480106
# 6_fluxpoints_0.050545
# 6_fluxpoints_0.0268527
# 6_fluxpoints_0.00507634
# 6_fluxpoints_-0.0110391
# 6_fluxpoints_-0.0551079
# 6_fluxpoints_0.156945
# 6_fluxpoints_-0.0434157
# 6_fluxpoints_0.195011
# 6_fluxpoints_0.0425177
# 6_fluxpoints_0.0161405
# 6_fluxpoints_0.113539
# 6_fluxpoints_-0.130273
# 6_fluxpoints_0.103846
# 6_fluxpoints_0.0548927
# 6_fluxpoints_0.0860975
# 6_fluxpoints_-0.0936648
# 6_fluxpoints_0.0849935
# 6_fluxpoints_0.0172957
# 6_fluxpoints_0.0585035
# 6_fluxpoints_-0.0148115
# 6_fluxpoints_-0.055662
# 6_fluxpoints_-0.0570198
# 6_fluxpoints_-0.0578862
# 6_fluxpoints_0.0985574
# 6_fluxpoints_-0.0368624
# 6_fluxpoints_-0.122111
# 6_fluxpoints_0.0700666
# 6_fluxpoints_0.13836
# 6_fluxpoints_0.0303572
# 6_fluxpoints_0.100189
# 6_fluxpoints_0.139865
# 6_fluxpoints_-0.0603466
# 6_fluxpoints_0.0602796
# 6_fluxpoints_-0.136794
# 6_fluxpoints_0.090783
# 6_fluxpoints_-0.0656831
# 6_fluxpoints_-0.0611952
# 6_fluxpoints_-0.141735
# 6_fluxpoints_-0.127501
# 6_fluxpoints_-0.0713676
# 6_fluxpoints_-0.108412
# 6_fluxpoints_0.0311516
# 6_fluxpoints_-0.101652
# 6_fluxpoints_0.0385463
# 6_fluxpoints_-0.098601
# 6_fluxpoints_0.0263177
# 6_fluxpoints_0.171658
# 6_fluxpoints_-0.0679136
# 6_fluxpoints_0.00389477
# 6_fluxpoints_0.160736
# 6_fluxpoints_-0.0647641
# 6_fluxpoints_-0.0199298
# 6_fluxpoints_-0.0234735
# 6_fluxpoints_0.116807
# 6_fluxpoints_0.0160761
# 6_fluxpoints_0.0640979
# 6_fluxpoints_-0.0163234
# 6_fluxpoints_-0.0964621
# 6_fluxpoints_0.226453
# 6_fluxpoints_0.0597956
# 6_fluxpoints_-0.0797577
# 6_fluxpoints_-0.105896
# 6_fluxpoints_0.112862
# 6_fluxpoints_0.16253
# 6_fluxpoints_0.155485
# 6_fluxpoints_0.12195
# 6_fluxpoints_0.0838239
# 6_fluxpoints_-0.0488037
# 6_fluxpoints_-0.0328974
# 6_fluxpoints_0.05608
# 6_fluxpoints_-0.0433865
# 6_fluxpoints_0.0388956
# 6_fluxpoints_-0.0166191
# 6_fluxpoints_-0.052895
# 6_fluxpoints_0.00650106
# 6_fluxpoints_0.0254752
# 6_fluxpoints_-0.239893
# 6_fluxpoints_-0.0568589
# 6_fluxpoints_-0.0806694
# 6_fluxpoints_0.204655
# 6_fluxpoints_-0.0902692
# 6_fluxpoints_0.0609418
# 6_fluxpoints_0.126772
# 6_fluxpoints_-0.0925799
# 6_fluxpoints_-0.0859817
# 6_fluxpoints_-0.190364
# 6_fluxpoints_-0.0829641
# 6_fluxpoints_-0.0960275
# 6_fluxpoints_0.0134075
# 6_fluxpoints_-0.0297204
# 6_fluxpoints_-0.0336124
# 6_fluxpoints_-0.0175792
# 6_fluxpoints_-0.0335626
# 6_fluxpoints_0.164666
# 6_fluxpoints_-0.124444
# 6_fluxpoints_-0.0186636
# 6_fluxpoints_0.0199773
# 6_fluxpoints_-0.271534
# 6_fluxpoints_-0.032477
# 6_fluxpoints_0.0497665
# 6_fluxpoints_-0.0351619
# 6_fluxpoints_-0.0955279
# 6_fluxpoints_-0.0279735
# 6_fluxpoints_0.164423
# 6_fluxpoints_0.132092
# 6_fluxpoints_-0.0263967
# 6_fluxpoints_-0.0478913
# 6_fluxpoints_0.113359
# 6_fluxpoints_-0.033494
# 6_fluxpoints_0.120162
# 6_fluxpoints_-0.120522
# 6_fluxpoints_0.163139
# 6_fluxpoints_-0.015124
# 6_fluxpoints_-0.0500806
# 6_fluxpoints_0.0273459
# 6_fluxpoints_0.023705
# 6_fluxpoints_0.128931
# 6_fluxpoints_0.172389
# 6_fluxpoints_0.0437127
# 6_fluxpoints_0.184544
# 6_fluxpoints_0.0337379
# 6_fluxpoints_0.168562
# 6_fluxpoints_0.084931
# 6_fluxpoints_0.020702
# 6_fluxpoints_-0.0106131
# 6_fluxpoints_-0.104704
# 6_fluxpoints_-0.19384
# 6_fluxpoints_-0.0788274
# 6_fluxpoints_-0.0677386
# 6_fluxpoints_0.0169793
# 6_fluxpoints_0.0884277
# 6_fluxpoints_-0.1657
# 6_fluxpoints_-0.0618348
# 6_fluxpoints_-0.0695667
# 6_fluxpoints_-0.0408124
# 6_fluxpoints_-0.114196
# 6_fluxpoints_-0.0999628
# 6_fluxpoints_-0.0969773
# 6_fluxpoints_-0.0149631
# 6_fluxpoints_-0.00419028
# 800 800

# %%
sys_ = sys_dataset(dataset_asimov= dataset_asimov,
                        shift = 0, 
                        tilt = 0,
                        rnd = False)
dataset_asimov = sys_.create_dataset()
dataset_asimov_N = sys_.create_dataset_N()
zero = 1e-24
## additional parameter bias and resolution (ereco) but are frozen
penalising_invcovmatrix = np.zeros((4, 4))
np.fill_diagonal(penalising_invcovmatrix,
                 [1/shift**2, 1/tilt**2, 1/zero**2, 1/zero**2])
dataset_asimov_N.penalising_invcovmatrix = penalising_invcovmatrix


fit_cor = Fit(store_trace=False)
minuit_opts = {"tol": 0.001, "strategy": 2}
fit_cor.backend = "minuit"
fit_cor.optimize_opts = minuit_opts
result_cor = fit_cor.run([dataset_asimov])

fit_cor_N = Fit(store_trace=False)
minuit_opts = {"tol": 0.001, "strategy": 2}
fit_cor_N.backend = "minuit"
fit_cor_N.optimize_opts = minuit_opts
result_cor_N = fit_cor_N.run([dataset_asimov_N])

# %%
dataset_asimov_N.models[-1].parameters['norm_nuisance'].frozen = True
dataset_asimov_N.models[-1].parameters['tilt_nuisance'].frozen = True

# %%
mask = dataset_asimov.mask.data[:,60,60]
ebins = dataset_asimov.counts.geom.axes[0].center[mask]
energy_bounds = (ebins[0] , ebins[-1] ) *u.TeV

# %%
fig, (axs, ax1) = plt.subplots(1,2, figsize = (2*4,7/3))
nbins = 30
count, bins, ignored = axs.hist(shift_rnds, nbins, density=True, color = 'steelblue')
sigma =shift
mu = 0
axs.plot(bins, 1/(sigma * np.sqrt(2 * np.pi)) *
               np.exp( - (bins - mu)**2 / (2 * sigma**2) ),
         linewidth=2, color='r', label = f'$\mu = {mu}; \sigma = {sigma}$')

axs.set_xlabel("Systematic [%]")
axs.legend()

x = axs.get_xlim()
deltax = np.max([ mu - x[0] , x[1] - mu ])
axs.set_xlim(mu -deltax, 
                mu + deltax)


count, bins, ignored = ax1.hist(index_rnds, nbins, density=True, color = 'steelblue')
sigma =tilt
mu = 0
ax1.plot(bins, 1/(sigma * np.sqrt(2 * np.pi)) *
               np.exp( - (bins - mu)**2 / (2 * sigma**2) ),
         linewidth=2, color='r', label = f'$\mu = {mu}; \sigma = {sigma:.3}$')

ax1.set_xlabel("Systematic [%]")
ax1.set_title(f"N = {N}")
ax1.legend()

x = axs.get_xlim()
deltax = np.max([ mu - x[0] , x[1] - mu ])
axs.set_xlim(mu -deltax, 
                mu + deltax)
# Out:
# (-0.41129321414385916, 0.41129321414385916)

# %% [markdown]
# ## Compute Asimov Fluxpoints
#
# does not work because of the is_norm in the model

# %%
fluxpoints_asimov_N = FluxPoints.read("data/6_fluxpoints_asimov_N.fits")
fluxpoints_asimov = FluxPoints.read("data/6_fluxpoints_asimov.fits")

# %%
energy_edges = dataset_asimov.geoms['geom'].axes[0].edges

# %%
def plot_shifted (ff, shift):
    return ff.energy_ref* shift, ff.e2dnde.data[:,0,0],  ff.e2dnde_err.data[:,0,0],

# %%
fig, axs = plt.subplots(1,1, figsize = (6,4))
dataset_asimov_N.models[0].spectral_model.plot_error(energy_bounds,  energy_power = 2, ax = axs,
                                label = "$1\sigma$ Nuisance", facecolor = "green", alpha = 0.5)    
    
dataset_asimov.models[0].spectral_model.plot_error(energy_bounds,  energy_power = 2, ax = axs,
                                label = "$1\sigma$ Standard", facecolor = "red", alpha = 0.6)

dataset_asimov.models[0].spectral_model.plot(energy_bounds, linestyle=':', energy_power = 2, ax = axs,
                                label = "Input", color = "black", )




e_, f_, ferr_ = plot_shifted(fluxpoints_asimov, 1.1)
axs.errorbar(e_, f_, yerr = ferr_, color = 'darkred', fmt='o')  

e_, f_, ferr_ = plot_shifted(fluxpoints_asimov_N, 1.)
axs.errorbar(e_, f_, yerr = ferr_, color = 'darkgreen', fmt='o')  


axs.legend()
axs.set_title(f"N = {N}")
plt.tight_layout()

# %%
mask2 = fluxpoints[0].ts.data[:,0,0].data > 4
mask2

fluxpoints[0].ts.data[:,0,0].mask = mask2

# %%
e2dnde = []

for f in fluxpoints:
    mask2 = f.ts.data[:,0,0].data > 4
    e2dnde.append(f.e2dnde.data[:,0,0])
e2dnde = np.array(e2dnde)

# %%
fig, axs1 = plt.subplots(1,1,figsize = (6,4) )
for f,e  in zip(fluxpoints,e2dnde):
    axs1.plot(f.energy_ref* 1.0, e    , color = 'black', alpha = 0.01)
    
axs1.errorbar(f.energy_ref, e2dnde.mean(axis = 0), yerr = e2dnde.std(axis=0) , 
              label = "$\mu$, $\sigma$"
            )

dataset_asimov.models[0].spectral_model.plot(energy_bounds, linestyle=':', energy_power = 2, ax = axs1,
                                label = "Input", color = "black", )
ylim = axs.get_ylim()
axs1.set_ylim(ylim[0], ylim[1])
axs1.loglog()
axs1.set_title(f"N = {N}")
axs1.legend()
plt.tight_layout()

if savefig:
    fig.savefig(f"plots/7d_fluxpoints_rnd_{factor}_{N}." + picformat)

# %%
def fraction_within_e(lower_lim, upper_lim, data):
    withine = []
    for ie in range(len(lower_lim)):
        xs = []
        for f in data:
            value = f[ie]   
            lowerlim = (np.all(value >= lower_lim[ie]))
            upperlim = (np.all(value <= upper_lim[ie]))
            x = lowerlim & upperlim
            xs.append(x)
        withine.append(np.count_nonzero(xs) / len(data))
    withine  = np.array(withine)
    return withine[withine>0]

# %%
e_, f_, ferr_ = plot_shifted(fluxpoints_asimov, 1.05)
within_e = fraction_within_e(f_-ferr_ , f_ + ferr_, e2dnde)

e_, f_, ferr_ = plot_shifted(fluxpoints_asimov_N, 1.05)
within_eN = fraction_within_e(f_-ferr_ , f_ + ferr_, e2dnde)
within_eN
# Out:
# array([0.6725 , 0.7025 , 0.67375, 0.695  , 0.69125, 0.70375, 0.67   ,
#        0.68125, 0.66875, 0.67125, 0.6725 , 0.66625, 0.67125, 0.70375,
#        0.72625, 0.70625, 0.64   , 0.5675 ])

# %%
def compute_precision(N):
    Z = 1.645
    return  Z / np.sqrt(N)
p = compute_precision(N)

# %%
fig, (axs, ax2) = plt.subplots(2,1, gridspec_kw={'height_ratios': [3, 2]},
                         sharex = True, figsize = ((5,5)))

dataset_asimov_N.models[0].spectral_model.plot_error(energy_bounds,  energy_power = 2, ax = axs,
                                label = "", facecolor = "green", alpha = 0.5)    
    
dataset_asimov.models[0].spectral_model.plot_error(energy_bounds,  energy_power = 2, ax = axs,
                                label = "", facecolor = "red", alpha = 0.6)

dataset_asimov.models[0].spectral_model.plot(energy_bounds, linestyle=':', energy_power = 2, ax = axs,
                                label = "Input", color = "black", )

e_, f_, ferr_ = plot_shifted(fluxpoints_asimov_N, 1.)
axs.errorbar(e_, f_, yerr = ferr_, color = 'darkgreen', fmt='x', label = "Fluxpoints Nuisance")  

e_, f_, ferr_ = plot_shifted(fluxpoints_asimov, 1.05)
axs.errorbar(e_, f_, yerr = ferr_, color = 'darkred', fmt='x', label = "Fluxpoints Standard")  



axs.errorbar(f.energy_ref* 1.1, e2dnde.mean(axis = 0), yerr = e2dnde.std(axis=0) , 
                 label = "$\mu$, $\sigma$")


ax2.errorbar(ebins, within_e, yerr=p,color = 'red', label = f"Standard ")
ax2.errorbar(ebins, within_eN,yerr=p, color = 'green', label = "Nuisance")
ax2.plot(ebins, [0.68] * len(ebins), ':', color = 'green', label = "68 %")

axs.set_xlabel('')
axs.legend()
ax2.legend()
axs.set_title(f"N = {N}; (p={p:.2})")
ax2.set_xlabel('Energy [TeV]')
ax2.set_ylabel('Coverage')

axs.set_xlabel('')
axs.legend()

plt.tight_layout()
if savefig:
    fig.savefig(f"plots/7d_fluxpoints_coverage_{shift}_{N}." + picformat)
