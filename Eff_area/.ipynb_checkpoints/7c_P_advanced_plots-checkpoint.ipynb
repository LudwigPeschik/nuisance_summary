# %%
import gammapy 
print(f'loaded gammapy version: {gammapy.__version__} ' )
print(f'Supposed to be 1.0 (21-12-2022)' )
# Out:
# loaded gammapy version: 1.0
# Supposed to be 1.0 (21-12-2022)

# %%
#get_ipython().system('jupyter nbconvert --to script 1-Nui_Par_Fitting.ipynb')
import pyximport

pyximport.install()
import matplotlib.pyplot as plt
import numpy as np
import astropy.units as u
import gammapy
from scipy.interpolate import interp2d

# from gammapy.datasets import MapDataset
from gammapy.maps import Map
from astropy.coordinates import SkyCoord, Angle
from gammapy.modeling import Fit, Parameter, Parameters, Covariance
from gammapy.datasets import MapDataset #, MapDatasetNuisance
from gammapy.modeling.models import (
    PowerLawSpectralModel,
    create_crab_spectral_model,
    SkyModel,
    PointSpatialModel,
    ShellSpatialModel,
    GeneralizedGaussianSpatialModel,
    TemplateSpatialModel,
    LogParabolaSpectralModel,
    GaussianSpatialModel,
    DiskSpatialModel,
    PowerLawNormSpectralModel,
    Models,
    SpatialModel,
    FoVBackgroundModel,
    ExpCutoffPowerLawSpectralModel
)
from gammapy.estimators import TSMapEstimator, ExcessMapEstimator

from regions import CircleSkyRegion, RectangleSkyRegion
import yaml
import sys

from Dataset_Creation import sys_dataset

# %% [markdown]
# ## Read dataset

# %%
dataset_asimov = MapDataset.read("c:/users/yt02izug/downloads/dataset_asimov/dataset_asimov.fits")
# Create the spatial model 
model_spatial = GaussianSpatialModel(
    lon_0="83.631 deg",
    lat_0="22.018 deg",
    sigma="0.02 deg",
    )

# Create the spectral model 
model_spectrum  = ExpCutoffPowerLawSpectralModel(
    index=2.3,
    amplitude="1e-12 TeV-1 cm-2 s-1",
    lambda_="0.1 TeV-1")

# combine the spectral and the spatial model
source_model = SkyModel(spatial_model = model_spatial ,
                       spectral_model = model_spectrum,
                       name = "Source")    
models = Models(source_model)

# Create the model for the Background
bkg_model = FoVBackgroundModel(dataset_name=dataset_asimov.name)
bkg_model.parameters['tilt'].frozen  = False
models.append(bkg_model)

# set the models in the dataset
dataset_asimov.models = models
# set counts
dataset_asimov.counts = dataset_asimov.npred()
    
dataset_asimov.counts.sum_over_axes().plot(add_cbar=1)
binsize = dataset_asimov.geoms["geom"].width[1] / dataset_asimov.geoms["geom"].data_shape[1]
print(
    "spatial binsize = ",
    binsize
)

print(dataset_asimov)
# Out:
# spatial binsize =  [0.08] deg
# MapDataset
# ----------
#
#   Name                            : 1MUXqVCD
#
#   Total counts                    : 361088
#   Total background counts         : 360331.31
#   Total excess counts             : 756.96
#
#   Predicted counts                : 361088.27
#   Predicted background counts     : 360331.34
#   Predicted excess counts         : 756.93
#
#   Exposure min                    : 2.07e-01 m2 s
#   Exposure max                    : 2.41e+11 m2 s
#
#   Number of total bins            : 540000
#   Number of fit bins              : 180191
#
#   Fit statistic type              : cash
#   Fit statistic value (-2 log(L)) : -752490.77
#
#   Number of models                : 2
#   Number of parameters            : 13
#   Number of free parameters       : 8
#
#   Component 0: SkyModel
#
#     Name                      : Source
#     Datasets names            : None
#     Spectral model type       : ExpCutoffPowerLawSpectralModel
#     Spatial  model type       : GaussianSpatialModel
#     Temporal model type       :
#     Parameters:
#       index                         :      2.300   +/-    0.00
#       amplitude                     :   1.00e-12   +/- 0.0e+00 1 / (cm2 s TeV)
#       reference             (frozen):      1.000       TeV
#       lambda_                       :      0.100   +/-    0.00 1 / TeV
#       alpha                 (frozen):      1.000
#       lon_0                         :     83.631   +/-    0.00 deg
#       lat_0                         :     22.018   +/-    0.00 deg
#       sigma                         :      0.020   +/-    0.00 deg
#       e                     (frozen):      0.000
#       phi                   (frozen):      0.000       deg
#
#   Component 1: FoVBackgroundModel
#
#     Name                      : 1MUXqVCD-bkg
#     Datasets names            : ['1MUXqVCD']
#     Spectral model type       : PowerLawNormSpectralModel
#     Parameters:
#       norm                          :      1.000   +/-    0.00
#       tilt                          :      0.000   +/-    0.00
#       reference             (frozen):      1.000       TeV

# %%
def compute_fraction(Ls_new, x_new,
               y_new, threshold, plot = False):
    tot_int = np.sum(Ls_new)
    offset = Ls_new.min() + threshold
    outside = Ls_new* (Ls_new < offset)
    inside = Ls_new* (Ls_new >= offset)
    fraction_inside = np.sum(inside)/ tot_int
    fraction=  (tot_int - np.sum(outside))/ tot_int 
    if plot:
        fig,ax = plt.subplots(1,1, )
        im =ax.pcolormesh(x_new,
               y_new,
               Ls_new)
        fig.colorbar(im);
        ax.set_title(f"frac inside : {fraction_inside * 100:.4} %")

        CS = ax.contour(x_new,
               y_new,Ls_new, colors=('gold',), levels = [Ls_new.min() + threshold])    
    return fraction_inside

def plot_L(Ls_new, x_new, y_new, threshold, xlabel, ylabel, find_min = True, color = 'red'):
    index_min, index_max,  ampli_min,  ampli_max, index_best, ampli_best = compute_errors(
        Ls_new, x_new, y_new, threshold, find_min = find_min )
    fig,ax = plt.subplots(1,1, )
    im =ax.pcolormesh(x_new,
       y_new,
       Ls_new)
    fig.colorbar(im);

    CS = ax.contour(x_new,
       y_new,Ls_new, colors=('gold',), levels = [ Ls_new.min() + threshold]) 
    linewidth = 2
    ax.hlines(y = index_min, xmin = x_new[0], xmax = x_new[-1], color = color,
             linestyle = 'dotted', linewidth = linewidth)
    ax.hlines(y = index_max, xmin = x_new[0], xmax = x_new[-1], color = color,
             linestyle = 'dotted', linewidth = linewidth)

    ax.vlines(x = ampli_min, ymin = y_new[0], ymax = y_new[-1], color = color,
             linestyle = 'dotted', linewidth = linewidth)
    ax.vlines(x = ampli_max, ymin = y_new[0], ymax = y_new[-1], color = color,
             linestyle = 'dotted', linewidth = linewidth)

    ax.plot(ampli_best, index_best, 'x')

    plt.ylabel(ylabel)
    plt.xlabel(xlabel)
    return CS
    
    
def compute_errors(Ls_new, x_new,
               y_new, threshold , find_min = False):
    tot_int = np.sum(Ls_new)
    offset = Ls_new.min() + threshold
    outside = Ls_new* (Ls_new < offset)
    inside = Ls_new* (Ls_new >= offset)
    if find_min: # find min:
        pos = np.where(inside >= 0 )
        ampli_best = x_new[np.where(Ls_new == Ls_new.min())[1][0]]
        index_best = y_new[np.where(Ls_new == Ls_new.min())[0][0]]
        
    else:  # find max
        pos = np.where(inside > 0 )
        ampli_best = x_new[np.where(Ls_new == Ls_new.max())[1][0]]
        index_best = y_new[np.where(Ls_new == Ls_new.max())[0][0]]
        
    delta_bin = (x_new[1] - x_new[0] )/2
    ampli_min = x_new[np.min(pos[1])]-delta_bin
    ampli_max = x_new[np.max(pos[1])]+delta_bin
    ampli_best += delta_bin
    
    delta_bin = (y_new[1] - y_new[0] )/2
    index_min = y_new[np.min(pos[0])]-delta_bin
    index_max = y_new[np.max(pos[0])]+delta_bin
    index_best += delta_bin
    
    print(ampli_best, index_best)
    return index_min, index_max,  ampli_min,  ampli_max, index_best, ampli_best

# %% [markdown]
# ## Varying the Exposure

# %%
savefig = False
shift = 0.1 #0.085
tilt = 0.015

# %%
infos = np.loadtxt("data/7a_P_draw_info.txt")
pars = np.loadtxt("data/7a_P_draw_par.txt")
flux = np.loadtxt("data/7a_P_draw_flux.txt")
flux2e = np.loadtxt("data/7a_P_draw_flux2e.txt")


lem = len(infos)
N_max = 1000
N = np.min([lem, N_max])

print(N)

shift_rnds = infos[:N_max,0]
index_rnds = infos[:N_max,1]
stat_sums = infos[:N_max,2]


#amplitude', 'index', 'lambda_', 'norm', 'tilt
amplitudes = pars[:N_max,0:2] 
indices = pars[:N_max,2:4]
lambdas = pars[:N_max,4:6] 
norms = pars[:N_max,6:8]
tilts = pars[:N_max,8:10]

valuies = [norms, amplitudes, indices, lambdas]
# Out:
# 800

# %%
sys_ = sys_dataset(dataset_asimov= dataset_asimov,
                        shift = 0, 
                        tilt = 0,
                        rnd = False)
dataset_asimov = sys_.create_dataset()
dataset_asimov_N = sys_.create_dataset_N()

zero = 1e-24
## additional parameter bias and resolution (ereco) but are frozen
penalising_invcovmatrix = np.zeros((4, 4))
np.fill_diagonal(penalising_invcovmatrix,
                 [1/shift**2, 1/tilt**2, 1/zero**2, 1/zero**2])
dataset_asimov_N.penalising_invcovmatrix = penalising_invcovmatrix


fit_cor = Fit(store_trace=False)
#minuit_opts = {"tol": 0.001, "strategy": 2}
#fit_cor.backend = "minuit"
#fit_cor.optimize_opts = minuit_opts
result_cor = fit_cor.run([dataset_asimov])    
result_cor = fit_cor.run([dataset_asimov_N])

# %%
print(dataset_asimov_N)
# Out:
# MapDataset
# ----------
#
#   Name                            : dataset N
#
#   Total counts                    : 361088
#   Total background counts         : 360331.31
#   Total excess counts             : 756.96
#
#   Predicted counts                : 361089.30
#   Predicted background counts     : 360332.93
#   Predicted excess counts         : 756.37
#
#   Exposure min                    : 2.07e-01 m2 s
#   Exposure max                    : 2.41e+11 m2 s
#
#   Number of total bins            : 540000
#   Number of fit bins              : 180191
#
#   Fit statistic type              : cash
#   Fit statistic value (-2 log(L)) : -752490.76
#
#   Number of models                : 3
#   Number of parameters            : 18
#   Number of free parameters       : 7
#
#   Component 0: SkyModel
#
#     Name                      : Source
#     Datasets names            : None
#     Spectral model type       : ExpCutoffPowerLawSpectralModel
#     Spatial  model type       : GaussianSpatialModel
#     Temporal model type       :
#     Parameters:
#       index                         :      2.302   +/-    0.16
#       amplitude                     :   1.00e-12   +/- 1.7e-13 1 / (cm2 s TeV)
#       reference             (frozen):      1.000       TeV
#       lambda_                       :      0.100   +/-    0.05 1 / TeV
#       alpha                 (frozen):      1.000
#       lon_0                 (frozen):     83.631       deg
#       lat_0                 (frozen):     22.018       deg
#       sigma                 (frozen):      0.020       deg
#       e                     (frozen):      0.000
#       phi                   (frozen):      0.000       deg
#
#   Component 1: FoVBackgroundModel
#
#     Name                      : dataset N-bkg
#     Datasets names            : ['dataset N']
#     Spectral model type       : PowerLawNormSpectralModel
#     Parameters:
#       norm                          :      1.000   +/-    0.00
#       tilt                          :      0.000   +/-    0.00
#       reference             (frozen):      1.000       TeV
#
#   Component 2: IRFModel
#
#     Name                      : dataset N-irf
#     Datasets names            : ['dataset N']
#     Spectral model type       : PowerLawNormPenSpectralModel
#     Parameters:
#       norm_nuisance                 :      0.001   +/-    0.11
#       tilt_nuisance                 :      0.000   +/-    0.01
#       reference             (frozen):      1.000       TeV
#       bias                  (frozen):      0.000
#       resolution            (frozen):      0.000

# %%
valuies_asimov = [[dataset_asimov.models[1].parameters['norm'].value, 
                   dataset_asimov.models[1].parameters['norm'].error],
                  [dataset_asimov.models[0].parameters['amplitude'].value, 
                   dataset_asimov.models[0].parameters['amplitude'].error],
                  [dataset_asimov.models[0].parameters['index'].value, 
                   dataset_asimov.models[0].parameters['index'].error],
                  [dataset_asimov.models[0].parameters['lambda_'].value, 
                   dataset_asimov.models[0].parameters['lambda_'].error]]


valuies_asimov_N = [[dataset_asimov_N.models[1].parameters['norm'].value, 
                   dataset_asimov_N.models[1].parameters['norm'].error],
                  [dataset_asimov_N.models[0].parameters['amplitude'].value, 
                   dataset_asimov_N.models[0].parameters['amplitude'].error],
                  [dataset_asimov_N.models[0].parameters['index'].value, 
                   dataset_asimov_N.models[0].parameters['index'].error],
                    [dataset_asimov_N.models[0].parameters['lambda_'].value, 
                   dataset_asimov_N.models[0].parameters['lambda_'].error]]

# %%
fig, axs = plt.subplots(4,1, figsize = (4,7))
xlabels = ["Best Fit BKG Norm", "Best Fit Amplitude", "Best Fit Index, Best Fit Lambda"]

for i, v in enumerate(valuies):
    axs[i].hist(v[1:,0], color ='steelblue')
    
    x = axs[i].get_xlim()
    deltax = np.max([ valuies_asimov[i][0] - x[0] , x[1] - valuies_asimov[i][0] ])
    axs[i].set_xlim(valuies_asimov[i][0] - deltax, 
                    valuies_asimov[i][0] + deltax)
#plt.legend()   
plt.tight_layout()

# %% [markdown]
# ## Asimov Likelihood (Without - With Nuisance)

# %% [markdown]
# ### Amplitude - Index

# %%
# %%time
computing = True
if computing:

    x = dataset_asimov.models[0].parameters['amplitude']
    y = dataset_asimov.models[0].parameters['index']
    x.scan_n_sigma = 3
    y.scan_n_sigma = 3
    x.scan_n_values = 11
    y.scan_n_values = 10

    contour = fit_cor.stat_surface([dataset_asimov], x, y, reoptimize=True) 

    contour_write = dict()
    for k in contour.keys():
        print(k)
        if k != 'fit_results':
            contour_write[k]  = contour[k].tolist()
            
    with open('data/7c_contour_amplitude_index.yml' , 'w') as outfile:
        yaml.dump(contour_write, outfile, default_flow_style=False)
        
else:
    with open('data/7c_contour_amplitude_index.yml', 'r') as stream:
        contour=yaml.safe_load(stream)
        
amplix__ = contour['Source.spectral.amplitude_scan']
indexy__ = contour['Source.spectral.index_scan']
N_new = 110
N_new_y = 110
amplix__new =  np.linspace(amplix__[0], amplix__[-1],N_new)
indexy__new =  np.linspace(indexy__[0], indexy__[-1],N_new_y)


f = interp2d(x = indexy__, y= amplix__, z = contour['stat_scan'], kind='cubic',fill_value = None, bounds_error = False )
data_contour = f(indexy__new, amplix__new)
# Out:
# Source.spectral.amplitude_scan
# Source.spectral.index_scan
# stat_scan
# fit_results
# CPU times: total: 1min 52s
# Wall time: 1min 53s

# %%
fig, (ax1, ax) = plt.subplots(1,2, figsize = (14,5))


im =ax1.pcolormesh(indexy__, amplix__, contour['stat_scan'])
dddd = np.array(contour['stat_scan'])
ampli_best = amplix__[np.where(dddd == dddd.min())[0][0]]
index_best = indexy__[np.where(dddd == dddd.min())[1][0]]

ax1.plot(index_best, ampli_best, 'x')
fig.colorbar(im, ax=ax1)
ax1.set_ylabel("Amplitude")
ax1.set_xlabel("Index",)
ax1.set_title(f"Likelihood")


im =ax.pcolormesh(indexy__new, amplix__new, data_contour)
dddd = np.array(data_contour)
ampli_best = amplix__new[np.where(dddd == dddd.min())[0][0]]
index_best = indexy__new[np.where(dddd == dddd.min())[1][0]]
print("min index:", index_best)
print("min amplitude:", ampli_best)

ax.plot(index_best, ampli_best, 'x')
fig.colorbar(im, ax=ax)
ax.set_ylabel("Amplitude")
ax.set_xlabel("Index",)
ax.set_title(f"Likelihood")
# Out:
# min index: 2.295672331331057
# min amplitude: 1.0033968197865849e-12
# Text(0.5, 1.0, 'Likelihood')

# %%
threshold_contour = 1
ampli_min_asimov,  ampli_max_asimov, index_min_asimov, index_max_asimov,  ampli_best_asimov, index_best_asimov = compute_errors(
    data_contour, indexy__new, amplix__new,  threshold_contour, find_min = True)

CS= plot_L(data_contour, indexy__new, amplix__new,  threshold_contour, xlabel = 'Index', ylabel = 'Amplitude [TeV cm-2 s-1]',
      find_min = True, color = 'red')

dat= CS.allsegs[0][0]
# Out:
# 2.3 1.0067936395731698e-12
# 2.3 1.0067936395731698e-12

# %%
# %%time
if computing:
    x = dataset_asimov.models[0].parameters['amplitude']
    y = dataset_asimov.models[0].parameters['index']
    x_N = dataset_asimov_N.models[0].parameters['amplitude']
    y_N = dataset_asimov_N.models[0].parameters['index']

    #find suitable values
    x_N.scan_values = x.scan_values
    y_N.scan_values = y.scan_values

    contour_N = fit_cor.stat_surface([dataset_asimov_N], x_N, y_N, reoptimize=True ) 


    contour_write = dict()
    for k in contour_N.keys():
        print(k)
        if k != 'fit_results':
            contour_write[k]  = contour_N[k].tolist()
            
    with open('data/7c_contour_amplitude_index_N.yml' , 'w') as outfile:
        yaml.dump(contour_write, outfile, default_flow_style=False)
        
else:
    with open('data/7c_contour_amplitude_index_N.yml', 'r') as stream:
        contour_N=yaml.safe_load(stream)
        

amplix___N = contour_N['Source.spectral.amplitude_scan']
indexy___N = contour_N['Source.spectral.index_scan']
amplix__new_N =  np.linspace(amplix___N[0], amplix___N[-1],N_new)
indexy__new_N =  np.linspace(indexy___N[0], indexy___N[-1],N_new_y)    
        

f = interp2d(x = indexy___N, y= amplix___N, z = contour_N['stat_scan'], kind='cubic',fill_value = None, bounds_error = False )
data_contour_N = f(indexy__new_N, amplix__new_N)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File <timed exec>:11, in <module>
#
# File ~\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\gammapy\modeling\fit.py:434, in Fit.stat_surface(self, datasets, x, y, reoptimize)
#     432 if reoptimize:
#     433     x.frozen, y.frozen = True, True
# --> 434     result = self.optimize(datasets=datasets)
#     435     stat = result.total_stat
#     436     fit_results.append(result)
#
# File ~\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\gammapy\modeling\fit.py:212, in Fit.optimize(self, datasets)
#     208 compute = registry.get("optimize", backend)
#     209 # TODO: change this calling interface!
#     210 # probably should pass a fit statistic, which has a model, which has parameters
#     211 # and return something simpler, not a tuple of three things
# --> 212 factors, info, optimizer = compute(
#     213     parameters=parameters,
#     214     function=datasets.stat_sum,
#     215     store_trace=self.store_trace,
#     216     **kwargs,
#     217 )
#     219 if backend == "minuit":
#     220     self._minuit = optimizer
#
# File ~\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\gammapy\modeling\iminuit.py:79, in optimize_iminuit(parameters, function, store_trace, **kwargs)
#      73 migrad_opts = kwargs.pop("migrad_opts", {})
#      75 minuit, minuit_func = setup_iminuit(
#      76     parameters=parameters, function=function, store_trace=store_trace, **kwargs
#      77 )
# ---> 79 minuit.migrad(**migrad_opts)
#      81 factors = minuit.values
#      82 info = {
#      83     "success": minuit.valid,
#      84     "nfev": minuit.nfcn,
#      85     "message": _get_message(minuit, parameters),
#      86     "trace": minuit_func.trace,
#      87 }
#
# File ~\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\iminuit\minuit.py:694, in Minuit.migrad(self, ncall, iterate)
#     692 if self._precision is not None:
#     693     migrad.precision = self._precision
# --> 694 fm = migrad(ncall, self._tolerance)
#     695 if fm.is_valid or fm.has_reached_call_limit:
#     696     break
#
# File ~\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\gammapy\modeling\iminuit.py:25, in MinuitLikelihood.fcn(self, *factors)
#      22 def fcn(self, *factors):
#      23     self.parameters.set_parameter_factors(factors)
# ---> 25     total_stat = self.function()
#      27     if self.store_trace:
#      28         self.store_trace_iteration(total_stat)
#
# File ~\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\gammapy\datasets\core.py:236, in Datasets.stat_sum(self)
#     234 # TODO: add parallel evaluation of likelihoods
#     235 for dataset in self:
# --> 236     stat_sum += dataset.stat_sum()
#     237 return stat_sum
#
# File ~\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\gammapy\datasets\map.py:911, in MapDataset.stat_sum(self)
#     909 def stat_sum(self):
#     910     """Total likelihood given the current model parameters plus the Gaussian penalty term."""
# --> 911     counts, npred = self.counts.data.astype(float), self.npred().data
#     912     if len(self.models.parameters.penalised_parameters) > 0:
#     913         # if self.penalising_invcovmatrix is not None:
#     914         penalty = gaussian_penality(
#     915             self.models.parameters.penalised_parameters,
#     916             self._penalising_invcovmatrix,
#     917         )
#
# File ~\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\gammapy\datasets\map.py:453, in MapDataset.npred(self)
#     445 def npred(self):
#     446     """Total predicted source and background counts
#     447
#     448     Returns
#    (...)
#     451         Total predicted counts
#     452     """
# --> 453     npred_total = self.npred_signal()
#     455     if self.background:
#     456         npred_total += self.npred_background()
#
# File ~\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\gammapy\datasets\map.py:584, in MapDataset.npred_signal(self, model_name)
#     582     exposure = self.npred_exposure()
#     583     edisp = self.npred_edisp()
# --> 584     evaluator.update(
#     585         exposure,
#     586         self.psf,
#     587         edisp,
#     588         self._geom,
#     589         self.mask_image,
#     590     )
#     592 if evaluator.contributes:
#     593     npred = evaluator.compute_npred()
#
# File ~\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\gammapy\datasets\evaluator.py:193, in MapEvaluator.update(self, exposure, psf, edisp, geom, mask)
#     190         if geom_psf.is_region or geom_psf.is_hpx:
#     191             geom_psf = geom_psf.to_wcs_geom()
# --> 193         self.psf = psf.get_psf_kernel(
#     194             position=self.model.position,
#     195             geom=geom_psf,
#     196             containment=PSF_CONTAINMENT,
#     197             max_radius=PSF_MAX_RADIUS,
#     198         )
#     200 if self.evaluation_mode == "local":
#     201     self.contributes = self.model.contributes(mask=mask, margin=self.psf_width)
#
# File ~\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\gammapy\irf\psf\map.py:262, in PSFMap.get_psf_kernel(self, geom, position, max_radius, containment, factor)
#     256     energy_axis = self.psf_map.geom.axes[self.energy_name]
#     257     kwargs = {
#     258         "fraction": containment,
#     259         "position": position,
#     260         self.energy_name: energy_axis.center,
#     261     }
# --> 262     radii = self.containment_radius(**kwargs)
#     263     max_radius = np.max(radii)
#     265 geom = geom.to_odd_npix(max_radius=max_radius)
#
# File ~\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\gammapy\irf\psf\map.py:195, in PSFMap.containment_radius(self, fraction, energy_true, position)
#     192 kwargs = {self.energy_name: energy_true, "skycoord": position}
#     193 coords = self._get_irf_coords(**kwargs)
# --> 195 return self._psf_irf.containment_radius(fraction, **coords)
#
# File ~\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\gammapy\irf\psf\core.py:69, in PSF.containment_radius(self, fraction, factor, **kwargs)
#      67 axis = tuple(range(output.ndim))
#      68 rad = np.expand_dims(rad, axis=axis).T
# ---> 69 containment = self.containment(rad=rad, **kwargs)
#      71 fraction_idx = np.argmin(np.abs(containment - fraction), axis=0)
#      72 return rad[fraction_idx].reshape(output.shape)
#
# File ~\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\gammapy\irf\psf\core.py:33, in PSF.containment(self, rad, **kwargs)
#      18 def containment(self, rad, **kwargs):
#      19     """Containment tof the PSF at given axes coordinates
#      20
#      21     Parameters
#    (...)
#      31         Containment
#      32     """
# ---> 33     containment = self.integral(axis_name="rad", rad=rad, **kwargs)
#      34     return containment.to("")
#
# File ~\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\gammapy\irf\core.py:372, in IRF.integral(self, axis_name, **kwargs)
#     354 def integral(self, axis_name, **kwargs):
#     355     """Compute integral along a given axis
#     356
#     357     This method uses interpolation of the cumulative sum.
#    (...)
#     370
#     371     """
# --> 372     cumsum = self.cumsum(axis_name=axis_name)
#     373     return cumsum.evaluate(**kwargs)
#
# File ~\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\gammapy\irf\core.py:346, in IRF.cumsum(self, axis_name)
#     342 if axis_name == "rad":
#     343     # take Jacobian into account
#     344     values = 2 * np.pi * axis.center.reshape(shape) * values
# --> 346 data = values.cumsum(axis=axis_idx)
#     348 axis_shifted = MapAxis.from_nodes(
#     349     axis.edges[1:], name=axis.name, interp=axis.interp
#     350 )
#     351 axes = self.axes.replace(axis_shifted)
#
# File ~\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620, in Quantity.__array_ufunc__(self, function, method, *inputs, **kwargs)
#     617     arrays.append(converter(input_) if converter else input_)
#     619 # Call our superclass's __array_ufunc__
# --> 620 result = super().__array_ufunc__(function, method, *arrays, **kwargs)
#     621 # If unit is None, a plain array is expected (e.g., comparisons), which
#     622 # means we're done.
#     623 # We're also done if the result was None (for method 'at') or
#     624 # NotImplemented, which can happen if other inputs/outputs override
#     625 # __array_ufunc__; hopefully, they can then deal with us.
#     626 if unit is None or result is None or result is NotImplemented:
#
# KeyboardInterrupt:

# %%
fig, (ax1, ax) = plt.subplots(1,2, figsize = (14,5))

im =ax1.pcolormesh(indexy___N, amplix___N, contour_N['stat_scan'])
dddd = np.array(contour_N['stat_scan'])
ampli_best_N = amplix___N[np.where(dddd == dddd.min())[0][0]]
index_best_N = indexy___N[np.where(dddd == dddd.min())[1][0]]

ax1.plot(index_best_N, ampli_best_N, 'x')
fig.colorbar(im, ax=ax1)
ax1.set_ylabel("amplitude")
ax1.set_xlabel("index",)
ax1.set_title(f"Likelihood")


im =ax.pcolormesh(indexy__new_N, amplix__new_N, data_contour_N)
dddd = np.array(data_contour_N)
ampli_best_N = amplix__new_N[np.where(dddd == dddd.min())[0][0]]
index_best_N = indexy__new_N[np.where(dddd == dddd.min())[1][0]]
print("min index:", index_best_N)
print("min amplitude:", ampli_best_N)

ax.plot(index_best_N, ampli_best_N, 'x')
fig.colorbar(im, ax=ax)
ax.set_ylabel("amplitude")
ax.set_xlabel("index",)
ax.set_title(f"Likelihood")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [36], in <cell line: 3>()
#       1 fig, (ax1, ax) = plt.subplots(1,2, figsize = (14,5))
# ----> 3 im =ax1.pcolormesh(indexy___N, amplix___N, contour_N['stat_scan'])
#       4 dddd = np.array(contour_N['stat_scan'])
#       5 ampli_best_N = amplix___N[np.where(dddd == dddd.min())[0][0]]
#
# NameError: name 'indexy___N' is not defined

# %%
ampli_min_asimov_N,  ampli_max_asimov_N, index_min_asimov_N, index_max_asimov_N, ampli_best_asimov_N, index_best_asimov_N = compute_errors(
    data_contour_N, indexy__new_N, amplix__new_N,  threshold_contour, find_min = True)

CS_N= plot_L(data_contour_N, indexy__new_N, amplix__new_N,  threshold_contour, xlabel = 'Index', ylabel = 'Amplitude [TeV cm-2 s-1]',
      find_min = True, color = 'green')

dat_N = CS_N.allsegs[0][0]
plt.plot(dat[:,0],dat[:,1], color = 'red')
plt.plot(index_best_N, ampli_best_N, 'x', color = 'green')
plt.plot(index_best, ampli_best, 'x', color = 'red')

# %% [markdown]
# ### Amplitude - Lambda

# %%
# %%time
computing = True
if computing:

    x = dataset_asimov.models[0].parameters['amplitude']
    y = dataset_asimov.models[0].parameters['lambda_']
    x.scan_n_sigma = 3
    y.scan_n_sigma = 2.5
    x.scan_n_values = 11
    y.scan_n_values = 10

    contour = fit_cor.stat_surface([dataset_asimov], x, y, reoptimize=True) 

    contour_write = dict()
    for k in contour.keys():
        print(k)
        if k != 'fit_results':
            contour_write[k]  = contour[k].tolist()
            
    with open('data/7c_contour_amplitude_lambda.yml' , 'w') as outfile:
        yaml.dump(contour_write, outfile, default_flow_style=False)
        
else:
    with open('data/7c_contour_amplitude_lambda.yml', 'r') as stream:
        contour=yaml.safe_load(stream)
        
amplix__ = contour['Source.spectral.amplitude_scan']
lambday__ = contour['Source.spectral.lambda__scan']
N_new = 110
N_new_y = 110
amplix__new =  np.linspace(amplix__[0], amplix__[-1],N_new)
lambday__new =  np.linspace(lambday__[0], lambday__[-1],N_new_y)


f = interp2d(x = lambday__, y= amplix__, z = contour['stat_scan'], kind='cubic', fill_value = None, bounds_error = False )
data_contour = f(lambday__new, amplix__new)
# Out:
# Source.spectral.amplitude_scan
# Source.spectral.lambda__scan
# stat_scan
# fit_results
# CPU times: total: 1min 32s
# Wall time: 1min 33s

# %%
fig, (ax1, ax) = plt.subplots(1,2, figsize = (14,5))


im =ax1.pcolormesh(lambday__, amplix__, contour['stat_scan'])
dddd = np.array(contour['stat_scan'])
ampli_best = amplix__[np.where(dddd == dddd.min())[0][0]]
lambda_best = lambday__[np.where(dddd == dddd.min())[1][0]]

ax1.plot(lambda_best, ampli_best, 'x')
fig.colorbar(im, ax=ax1)
ax1.set_ylabel("Amplitude")
ax1.set_xlabel("Lambda",)
ax1.set_title(f"Likelihood")


im =ax.pcolormesh(lambday__new, amplix__new, data_contour)
dddd = np.array(data_contour)
ampli_best = amplix__new[np.where(dddd == dddd.min())[0][0]]
lambda_best = lambday__new[np.where(dddd == dddd.min())[1][0]]
print("min lambda:", lambda_best)
print("min amplitude:", ampli_best)

ax.plot(lambda_best, ampli_best, 'x')
fig.colorbar(im, ax=ax)
ax.set_ylabel("Amplitude")
ax.set_xlabel("Lambda",)
ax.set_title(f"Likelihood")
# Out:
# min lambda: 0.10087381815574181
# min amplitude: 1.0033968197865849e-12
# Text(0.5, 1.0, 'Likelihood')

# %%
threshold_contour = 1
ampli_min_asimov,  ampli_max_asimov, lambda_min_asimov, lambda_max_asimov,  ampli_best_asimov, lambda_best_asimov = compute_errors(
    data_contour, lambday__new, amplix__new,  threshold_contour, find_min = True)

CS= plot_L(data_contour, lambday__new, amplix__new,  threshold_contour, xlabel = 'Lambda [1/TeV]', ylabel = 'Amplitude [TeV cm-2 s-1]',
      find_min = True, color = 'red')

dat= CS.allsegs[0][0]
# Out:
# 0.10174763631148362 1.0067936395731698e-12
# 0.10174763631148362 1.0067936395731698e-12

# %%
# %%time
if computing:
    x = dataset_asimov.models[0].parameters['amplitude']
    y = dataset_asimov.models[0].parameters['lambda_']
    x_N = dataset_asimov_N.models[0].parameters['amplitude']
    y_N = dataset_asimov_N.models[0].parameters['lambda_']

    x_N.scan_values = x.scan_values
    y_N.scan_values = y.scan_values

    contour_N = fit_cor.stat_surface([dataset_asimov_N], x_N, y_N, reoptimize=True ) 


    contour_write = dict()
    for k in contour_N.keys():
        print(k)
        if k != 'fit_results':
            contour_write[k]  = contour_N[k].tolist()
            
    with open('data/7c_contour_amplitude_lambda_N.yml' , 'w') as outfile:
        yaml.dump(contour_write, outfile, default_flow_style=False)
        
else:
    with open('data/7c_contour_amplitude_lambda_N.yml', 'r') as stream:
        contour_N=yaml.safe_load(stream)
        

amplix___N = contour_N['Source.spectral.amplitude_scan']
lambday___N = contour_N['Source.spectral.lambda__scan']
amplix__new_N =  np.linspace(amplix___N[0], amplix___N[-1],N_new)
lambday__new_N =  np.linspace(lambday___N[0], lambday___N[-1],N_new_y)    
        

f = interp2d(x = lambday___N, y= amplix___N, z = contour_N['stat_scan'], kind='cubic',fill_value = None, bounds_error = False )
data_contour_N = f(lambday__new_N, amplix__new_N)

# %%
fig, (ax1, ax) = plt.subplots(1,2, figsize = (14,5))

im =ax1.pcolormesh(lambday___N, amplix___N, contour_N['stat_scan'])
dddd = np.array(contour_N['stat_scan'])
ampli_best_N = amplix___N[np.where(dddd == dddd.min())[0][0]]
lambda_best_N = lambday___N[np.where(dddd == dddd.min())[1][0]]

ax1.plot(lambda_best_N, ampli_best_N, 'x')
fig.colorbar(im, ax=ax1)
ax1.set_ylabel("amplitude")
ax1.set_xlabel("lambda",)
ax1.set_title(f"Likelihood")


im =ax.pcolormesh(lambday__new_N, amplix__new_N, data_contour_N)
dddd = np.array(data_contour_N)
ampli_best_N = amplix__new_N[np.where(dddd == dddd.min())[0][0]]
lambda_best_N = lambday__new_N[np.where(dddd == dddd.min())[1][0]]
print("min lambda:", lambda_best_N)
print("min amplitude:", ampli_best_N)

ax.plot(lambda_best_N, ampli_best_N, 'x')
fig.colorbar(im, ax=ax)
ax.set_ylabel("amplitude")
ax.set_xlabel("lambda",)
ax.set_title(f"Likelihood")

# %%
ampli_min_asimov_N,  ampli_max_asimov_N, lambda_min_asimov_N, lambda_max_asimov_N, ampli_best_asimov_N, lambda_best_asimov_N = compute_errors(
    data_contour_N, lambday__new_N, amplix__new_N,  threshold_contour, find_min = True)

CS_N= plot_L(data_contour_N, lambday__new_N, amplix__new_N,  threshold_contour, xlabel = 'Lambda [1/TeV]', ylabel = 'Amplitude [TeV cm-2 s-1]',
      find_min = True, color = 'green')

dat_N = CS_N.allsegs[0][0]
plt.plot(dat[:,0],dat[:,1], color = 'red')
plt.plot(lambda_best_N, ampli_best_N, 'x', color = 'green')
plt.plot(lambda_best, ampli_best, 'x', color = 'red')

# %% [markdown]
# ### Lambda - Index

# %%
# %%time
computing = True
if computing:

    x = dataset_asimov.models[0].parameters['lambda_']
    y = dataset_asimov.models[0].parameters['index']
    x.scan_n_sigma = 2.5  #5
    y.scan_n_sigma = 3
    x.scan_n_values = 11
    y.scan_n_values = 10

    contour = fit_cor.stat_surface([dataset_asimov], x, y, reoptimize=True) 

    contour_write = dict()
    for k in contour.keys():
        print(k)
        if k != 'fit_results':
            contour_write[k]  = contour[k].tolist()
            
    with open('data/7c_contour_lambda_index.yml' , 'w') as outfile:
        yaml.dump(contour_write, outfile, default_flow_style=False)
        
else:
    with open('data/7c_contour_lambda_index.yml', 'r') as stream:
        contour=yaml.safe_load(stream)
        
lambdax__ = contour['Source.spectral.lambda__scan']
indexy__ = contour['Source.spectral.index_scan']
N_new = 110
N_new_y = 110
lambdax__new =  np.linspace(lambdax__[0], lambdax__[-1],N_new)
indexy__new =  np.linspace(indexy__[0], indexy__[-1],N_new_y)


f = interp2d(x = indexy__, y= lambdax__, z = contour['stat_scan'], kind='cubic',fill_value = None, bounds_error = False )
data_contour = f(indexy__new, lambdax__new)
# Out:
# Source.spectral.lambda__scan
# Source.spectral.index_scan
# stat_scan
# fit_results
# CPU times: total: 1min 32s
# Wall time: 1min 32s

# %%
fig, (ax1, ax) = plt.subplots(1,2, figsize = (14,5))


im =ax1.pcolormesh(indexy__, lambdax__, contour['stat_scan'])
dddd = np.array(contour['stat_scan'])
lambda_best = lambdax__[np.where(dddd == dddd.min())[0][0]]
index_best = indexy__[np.where(dddd == dddd.min())[1][0]]

ax1.plot(index_best, lambda_best, 'x')
fig.colorbar(im, ax=ax1)
ax1.set_ylabel("Lambda")
ax1.set_xlabel("Index",)
ax1.set_title(f"Likelihood")


im =ax.pcolormesh(indexy__new, lambdax__new, data_contour)
dddd = np.array(data_contour)
lambda_best = lambdax__new[np.where(dddd == dddd.min())[0][0]]
index_best = indexy__new[np.where(dddd == dddd.min())[1][0]]
print("min index:", index_best)
print("min Lambda:", lambda_best)

ax.plot(index_best, lambda_best, 'x')
fig.colorbar(im, ax=ax)
ax.set_ylabel("Lambda")
ax.set_xlabel("Index",)
ax.set_title(f"Likelihood")
# Out:
# min index: 2.295672331331057
# min Lambda: 0.10087381815574181
# Text(0.5, 1.0, 'Likelihood')

# %%
threshold_contour = 1
lambda_min_asimov,  lambda_max_asimov, index_min_asimov, index_max_asimov,  lambda_best_asimov, index_best_asimov = compute_errors(
    data_contour, indexy__new, lambdax__new,  threshold_contour, find_min = True)

CS= plot_L(data_contour, indexy__new, lambdax__new,  threshold_contour, xlabel = 'Index', ylabel = 'Lambda [1/TeV]',
      find_min = True, color = 'red')

dat= CS.allsegs[0][0]
# Out:
# 2.3 0.10174763631148362
# 2.3 0.10174763631148362

# %%
# %%time
if computing:
    x = dataset_asimov.models[0].parameters['lambda_']
    y = dataset_asimov.models[0].parameters['index']
    x_N = dataset_asimov_N.models[0].parameters['lambda_']
    y_N = dataset_asimov_N.models[0].parameters['index']

    x_N.scan_values = x.scan_values
    y_N.scan_values = y.scan_values

    contour_N = fit_cor.stat_surface([dataset_asimov_N], x_N, y_N, reoptimize=True ) 


    contour_write = dict()
    for k in contour_N.keys():
        print(k)
        if k != 'fit_results':
            contour_write[k]  = contour_N[k].tolist()
            
    with open('data/7c_contour_lambda_index_N.yml' , 'w') as outfile:
        yaml.dump(contour_write, outfile, default_flow_style=False)
        
else:
    with open('data/7c_contour_lambda_index_N.yml', 'r') as stream:
        contour_N=yaml.safe_load(stream)
        

lambdax___N = contour_N['Source.spectral.lambda__scan']
indexy___N = contour_N['Source.spectral.index_scan']
lambdax__new_N =  np.linspace(lambdax___N[0], lambdax___N[-1],N_new)
indexy__new_N =  np.linspace(indexy___N[0], indexy___N[-1],N_new_y)    
        

f = interp2d(x = indexy___N, y= lambdax___N, z = contour_N['stat_scan'], kind='cubic',fill_value = None, bounds_error = False )
data_contour_N = f(indexy__new_N, lambdax__new_N)
# Out:
# CPU times: total: 46.9 ms
# Wall time: 41 ms

# %%
fig, (ax1, ax) = plt.subplots(1,2, figsize = (14,5))

im =ax1.pcolormesh(indexy___N, lambdax___N, contour_N['stat_scan'])
dddd = np.array(contour_N['stat_scan'])
lambda_best_N = lambdax___N[np.where(dddd == dddd.min())[0][0]]
index_best_N = indexy___N[np.where(dddd == dddd.min())[1][0]]

ax1.plot(index_best_N, lambda_best_N, 'x')
fig.colorbar(im, ax=ax1)
ax1.set_ylabel("lambda")
ax1.set_xlabel("index",)
ax1.set_title(f"Likelihood")


im =ax.pcolormesh(indexy__new_N, lambdax__new_N, data_contour_N)
dddd = np.array(data_contour_N)
lambda_best_N = lambdax__new_N[np.where(dddd == dddd.min())[0][0]]
index_best_N = indexy__new_N[np.where(dddd == dddd.min())[1][0]]
print("min index:", index_best_N)
print("min lambda:", lambda_best_N)

ax.plot(index_best_N, lambda_best_N, 'x')
fig.colorbar(im, ax=ax)
ax.set_ylabel("Lambda")
ax.set_xlabel("Index",)
ax.set_title(f"Likelihood")
# Out:
# min index: 1.9855227433901577
# min lambda: 0.060678182991618645
# Text(0.5, 1.0, 'Likelihood')

# %%
lambda_min_asimov_N,  lambda_max_asimov_N, index_min_asimov_N, index_max_asimov_N, lambda_best_asimov_N, index_best_asimov_N = compute_errors(
    data_contour_N, indexy__new_N, lambdax__new_N,  threshold_contour, find_min = True)

CS_N= plot_L(data_contour_N, indexy__new_N, lambdax__new_N,  threshold_contour, ylabel = 'Lambda [1/TeV]', xlabel = 'Index',
      find_min = True, color = 'green')

dat_N = CS_N.allsegs[0][0]
plt.plot(dat[:,0],dat[:,1], color = 'red')
plt.plot(index_best_N, lambda_best_N, 'x', color = 'green')
plt.plot(index_best, lambda_best, 'x', color = 'red')
# Out:
# 1.9884078558361196 0.06155200114736045
# 1.9884078558361196 0.06155200114736045

# %% [markdown]
# ## Asimov Likelihood N

# %%
computing = False

# %% [markdown]
# Correct? Variables form amplitude/index necessary? Restructure: Asimov -> Asimov_N -> New Pair of Parameters?

# %%
# %%time
if computing:
    x = dataset_asimov.models[0].parameters['amplitude']
    y = dataset_asimov.models[0].parameters['index']
    x_N = dataset_asimov_N.models[0].parameters['amplitude']
    y_N = dataset_asimov_N.models[0].parameters['index']

    #find suitable values
    x_N.scan_values = x.scan_values
    y_N.scan_values = y.scan_values

    contour_N = fit_cor.stat_surface([dataset_asimov_N], x_N, y_N, reoptimize=True ) 


    contour_write = dict()
    for k in contour_N.keys():
        print(k)
        if k != 'fit_results':
            contour_write[k]  = contour_N[k].tolist()
            
    with open('data/7c_contour_amplitude_index_N.yml' , 'w') as outfile:
        yaml.dump(contour_write, outfile, default_flow_style=False)
        
else:
    with open('data/7c_contour_amplitude_index_N.yml', 'r') as stream:
        contour_N=yaml.safe_load(stream)
        

amplix___N = contour_N['Source.spectral.amplitude_scan']
indexy___N = contour_N['Source.spectral.index_scan']
amplix__new_N =  np.linspace(amplix___N[0], amplix___N[-1],N_new)
indexy__new_N =  np.linspace(indexy___N[0], indexy___N[-1],N_new_y)    
        

f = interp2d(x = indexy___N, y= amplix___N, z = contour_N['stat_scan'], kind='cubic',fill_value = None, bounds_error = False )
data_contour_N = f(indexy__new_N, amplix__new_N)
# Out:
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# ...
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# Source.spectral.amplitude_scan
# Source.spectral.index_scan
# stat_scan
# fit_results
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File <timed exec>:26, in <module>
#
# KeyError: 'SourceN.spectral.amplitude_scan'

# %%
amplix___N = contour_N['Source.spectral.amplitude_scan']
indexy___N = contour_N['Source.spectral.index_scan']
amplix__new_N =  np.linspace(amplix___N[0], amplix___N[-1],N_new)
indexy__new_N =  np.linspace(indexy___N[0], indexy___N[-1],N_new_y)    
        

f = interp2d(x = indexy___N, y= amplix___N, z = contour_N['stat_scan'], kind='cubic',fill_value = None, bounds_error = False )
data_contour_N = f(indexy__new_N, amplix__new_N)

# %%
fig, (ax1, ax) = plt.subplots(1,2, figsize = (14,5))

im =ax1.pcolormesh(indexy___N, amplix___N, contour_N['stat_scan'])
dddd = np.array(contour_N['stat_scan'])
ampli_best_N = amplix___N[np.where(dddd == dddd.min())[0][0]]
index_best_N = indexy___N[np.where(dddd == dddd.min())[1][0]]

ax1.plot(index_best_N, ampli_best_N, 'x')
fig.colorbar(im, ax=ax1)
ax1.set_ylabel("amplitude")
ax1.set_xlabel("index",)
ax1.set_title(f"Likelihood")


im =ax.pcolormesh(indexy__new_N, amplix__new_N, data_contour_N)
dddd = np.array(data_contour_N)
ampli_best_N = amplix__new_N[np.where(dddd == dddd.min())[0][0]]
index_best_N = indexy__new_N[np.where(dddd == dddd.min())[1][0]]
print("min index:", index_best_N)
print("min amplitude:", ampli_best_N)

ax.plot(index_best_N, ampli_best_N, 'x')
fig.colorbar(im, ax=ax)
ax.set_ylabel("amplitude")
ax.set_xlabel("index",)
ax.set_title(f"Likelihood")
# Out:
# min index: 1.9855227433901577
# min amplitude: 0.060678182991618645
# Text(0.5, 1.0, 'Likelihood')

# %%
ampli_min_asimov_N,  ampli_max_asimov_N, index_min_asimov_N, index_max_asimov_N, ampli_best_asimov_N, index_best_asimov_N = compute_errors(
    data_contour_N, indexy__new_N, amplix__new_N,  threshold_contour, find_min = True)

CS_N= plot_L(data_contour_N, indexy__new_N, amplix__new_N,  threshold_contour, xlabel = 'Index', ylabel = 'Amplitude [TeV cm-2 s-1]',
      find_min = True, color = 'green')

dat_N = CS_N.allsegs[0][0]
plt.plot(dat[:,0],dat[:,1], color = 'red')
plt.plot(index_best_N, ampli_best_N, 'x', color = 'green')
plt.plot(index_best, ampli_best, 'x', color = 'red')
# Out:
# 1.9884078558361196 0.06155200114736045
# 1.9884078558361196 0.06155200114736045

# %%
# %%time
if computing:
    x = dataset_asimov.models[0].parameters['amplitude']
    y = dataset_asimov.models[0].parameters['lambda_']
    x_N = dataset_asimov_N.models[0].parameters['amplitude']
    y_N = dataset_asimov_N.models[0].parameters['lambda_']

    x_N.scan_values = x.scan_values
    y_N.scan_values = y.scan_values

    contour_N = fit_cor.stat_surface([dataset_asimov_N], x_N, y_N, reoptimize=True ) 


    contour_write = dict()
    for k in contour_N.keys():
        print(k)
        if k != 'fit_results':
            contour_write[k]  = contour_N[k].tolist()
            
    with open('data/7c_contour_amplitude_lambda_N.yml' , 'w') as outfile:
        yaml.dump(contour_write, outfile, default_flow_style=False)
        
else:
    with open('data/7c_contour_amplitude_lambda_N.yml', 'r') as stream:
        contour_N=yaml.safe_load(stream)
        

amplix___N = contour_N['Source.spectral.amplitude_scan']
lambday___N = contour_N['Source.spectral.lambda__scan']
amplix__new_N =  np.linspace(amplix___N[0], amplix___N[-1],N_new)
lambday__new_N =  np.linspace(lambday___N[0], lambday___N[-1],N_new_y)    
        

f = interp2d(x = lambday___N, y= amplix___N, z = contour_N['stat_scan'], kind='cubic',fill_value = None, bounds_error = False )
data_contour_N = f(lambday__new_N, amplix__new_N)

# %%
fig, (ax1, ax) = plt.subplots(1,2, figsize = (14,5))

im =ax1.pcolormesh(lambday___N, amplix___N, contour_N['stat_scan'])
dddd = np.array(contour_N['stat_scan'])
ampli_best_N = amplix___N[np.where(dddd == dddd.min())[0][0]]
lambda_best_N = lambday___N[np.where(dddd == dddd.min())[1][0]]

ax1.plot(lambda_best_N, ampli_best_N, 'x')
fig.colorbar(im, ax=ax1)
ax1.set_ylabel("amplitude")
ax1.set_xlabel("lambda",)
ax1.set_title(f"Likelihood")


im =ax.pcolormesh(lambday__new_N, amplix__new_N, data_contour_N)
dddd = np.array(data_contour_N)
ampli_best_N = amplix__new_N[np.where(dddd == dddd.min())[0][0]]
lambda_best_N = lambday__new_N[np.where(dddd == dddd.min())[1][0]]
print("min lambda:", lambda_best_N)
print("min amplitude:", ampli_best_N)

ax.plot(lambda_best_N, ampli_best_N, 'x')
fig.colorbar(im, ax=ax)
ax.set_ylabel("amplitude")
ax.set_xlabel("lambda",)
ax.set_title(f"Likelihood")

# %%
ampli_min_asimov_N,  ampli_max_asimov_N, lambda_min_asimov_N, lambda_max_asimov_N, ampli_best_asimov_N, lambda_best_asimov_N = compute_errors(
    data_contour_N, lambday__new_N, amplix__new_N,  threshold_contour, find_min = True)

CS_N= plot_L(data_contour_N, lambday__new_N, amplix__new_N,  threshold_contour, xlabel = 'Lambda [1/TeV]', ylabel = 'Amplitude [TeV cm-2 s-1]',
      find_min = True, color = 'green')

dat_N = CS_N.allsegs[0][0]
plt.plot(dat[:,0],dat[:,1], color = 'red')
plt.plot(lambda_best_N, ampli_best_N, 'x', color = 'green')
plt.plot(lambda_best, ampli_best, 'x', color = 'red')

# %%
# %%time
if computing:
    x = dataset_asimov.models[0].parameters['lambda_']
    y = dataset_asimov.models[0].parameters['index']
    x_N = dataset_asimov_N.models[0].parameters['lambda_']
    y_N = dataset_asimov_N.models[0].parameters['index']

    x_N.scan_values = x.scan_values
    y_N.scan_values = y.scan_values

    contour_N = fit_cor.stat_surface([dataset_asimov_N], x_N, y_N, reoptimize=True ) 


    contour_write = dict()
    for k in contour_N.keys():
        print(k)
        if k != 'fit_results':
            contour_write[k]  = contour_N[k].tolist()
            
    with open('data/7c_contour_lambda_index_N.yml' , 'w') as outfile:
        yaml.dump(contour_write, outfile, default_flow_style=False)
        
else:
    with open('data/7c_contour_lambda_index_N.yml', 'r') as stream:
        contour_N=yaml.safe_load(stream)
        

lambdax___N = contour_N['Source.spectral.lambda__scan']
indexy___N = contour_N['Source.spectral.index_scan']
lambdax__new_N =  np.linspace(lambdax___N[0], lambdax___N[-1],N_new)
indexy__new_N =  np.linspace(indexy___N[0], indexy___N[-1],N_new_y)    
        

f = interp2d(x = indexy___N, y= lambdax___N, z = contour_N['stat_scan'], kind='cubic',fill_value = None, bounds_error = False )
data_contour_N = f(indexy__new_N, lambdax__new_N)
# Out:
# CPU times: total: 78.1 ms
# Wall time: 71.1 ms

# %%
fig, (ax1, ax) = plt.subplots(1,2, figsize = (14,5))

im =ax1.pcolormesh(indexy___N, lambdax___N, contour_N['stat_scan'])
dddd = np.array(contour_N['stat_scan'])
lambda_best_N = lambdax___N[np.where(dddd == dddd.min())[0][0]]
index_best_N = indexy___N[np.where(dddd == dddd.min())[1][0]]

ax1.plot(index_best_N, lambda_best_N, 'x')
fig.colorbar(im, ax=ax1)
ax1.set_ylabel("lambda")
ax1.set_xlabel("index",)
ax1.set_title(f"Likelihood")


im =ax.pcolormesh(indexy__new_N, lambdax__new_N, data_contour_N)
dddd = np.array(data_contour_N)
lambda_best_N = lambdax__new_N[np.where(dddd == dddd.min())[0][0]]
index_best_N = indexy__new_N[np.where(dddd == dddd.min())[1][0]]
print("min index:", index_best_N)
print("min lambda:", lambda_best_N)

ax.plot(index_best_N, lambda_best_N, 'x')
fig.colorbar(im, ax=ax)
ax.set_ylabel("lambda")
ax.set_xlabel("index",)
ax.set_title(f"Likelihood")
# Out:
# min index: 1.9855227433901577
# min lambda: 0.060678182991618645
# Text(0.5, 1.0, 'Likelihood')

# %%
lambda_min_asimov_N,  lambda_max_asimov_N, index_min_asimov_N, index_max_asimov_N, lambda_best_asimov_N, index_best_asimov_N = compute_errors(
    data_contour_N, indexy__new_N, lambdax__new_N,  threshold_contour, find_min = True)

CS_N= plot_L(data_contour_N, indexy__new_N, lambdax__new_N,  threshold_contour, ylabel = 'Lambda [1/TeV]', xlabel = 'Index',
      find_min = True, color = 'green')

dat_N = CS_N.allsegs[0][0]
plt.plot(dat[:,0],dat[:,1], color = 'red')
plt.plot(index_best_N, lambda_best_N, 'x', color = 'green')
plt.plot(index_best, lambda_best, 'x', color = 'red')
# Out:
# 1.9884078558361196 0.06155200114736045
# 1.9884078558361196 0.06155200114736045

# %% [markdown]
# ## Compute fraction of within

# %%
def fraction_within(lower_lim, upper_lim, data):
    is_within = []
    for d in data:
        larger = np.all(d[0] >= lower_lim )
        smaller = np.all(d[0] <= upper_lim)
        is_within.append(larger and smaller)
        
    return (np.count_nonzero(is_within) / len(data))

# %%
# std best fit, nui best fit, ... 
within_norm = [fraction_within(valuies_asimov[0][0] - valuies_asimov[0][1],
                               valuies_asimov[0][0] +  valuies_asimov[0][1],
                               norms
                              ),
               fraction_within(valuies_asimov_N[0][0] - valuies_asimov_N[0][1],
                               valuies_asimov_N[0][0] + valuies_asimov_N[0][1],
                               norms
                              ),
               0., 0.,
              ]

within_amplitude = [fraction_within(valuies_asimov[1][0] - valuies_asimov[1][1],
                               valuies_asimov[1][0] +  valuies_asimov[1][1],
                               amplitudes
                              ),
               fraction_within(valuies_asimov_N[1][0] - valuies_asimov_N[1][1],
                               valuies_asimov_N[1][0] + valuies_asimov_N[1][1],
                               amplitudes
                              ),
               fraction_within(ampli_min_asimov,
                               ampli_max_asimov,
                               amplitudes
                              ),
                fraction_within(ampli_min_asimov_N,
                               ampli_max_asimov_N,
                               amplitudes
                              ),
                ]

within_index = [fraction_within(valuies_asimov[2][0] - valuies_asimov[2][1],
                               valuies_asimov[2][0] +  valuies_asimov[2][1],
                               indices
                              ),
               fraction_within(valuies_asimov_N[2][0] - valuies_asimov_N[2][1],
                               valuies_asimov_N[2][0] + valuies_asimov_N[2][1],
                               indices
                              ),
                fraction_within(index_min_asimov,
                               index_max_asimov,
                               indices
                              ),
                fraction_within(index_min_asimov_N,
                               index_max_asimov_N,
                               indices
                              ),]

within_lambda = [fraction_within(valuies_asimov[3][0] - valuies_asimov[3][1],
                               valuies_asimov[3][0] +  valuies_asimov[3][1],
                               lambdas
                              ),
               fraction_within(valuies_asimov_N[3][0] - valuies_asimov_N[3][1],
                               valuies_asimov_N[3][0] + valuies_asimov_N[3][1],
                               lambdas
                              ),
                fraction_within(lambda_min_asimov,
                               lambda_max_asimov,
                               lambdas
                              ),
                fraction_within(lambda_min_asimov_N,
                               lambda_max_asimov_N,
                               lambdas
                              ),]

withins = [within_norm, 
          within_amplitude,
          within_index,
          within_lambda]
print(withins)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [37], in <cell line: 13>()
#       1 # std best fit, nui best fit, ...
#       2 within_norm = [fraction_within(valuies_asimov[0][0] - valuies_asimov[0][1],
#       3                                valuies_asimov[0][0] +  valuies_asimov[0][1],
#       4                                norms
#    (...)
#      10                0., 0.,
#      11               ]
#      13 within_amplitude = [fraction_within(valuies_asimov[1][0] - valuies_asimov[1][1],
#      14                                valuies_asimov[1][0] +  valuies_asimov[1][1],
#      15                                amplitudes
#      16                               ),
#      17                fraction_within(valuies_asimov_N[1][0] - valuies_asimov_N[1][1],
#      18                                valuies_asimov_N[1][0] + valuies_asimov_N[1][1],
#      19                                amplitudes
#      20                               ),
#      21                fraction_within(ampli_min_asimov,
#      22                                ampli_max_asimov,
#      23                                amplitudes
#      24                               ),
# ---> 25                 fraction_within(ampli_min_asimov_N,
#      26                                ampli_max_asimov_N,
#      27                                amplitudes
#      28                               ),
#      29                 ]
#      31 within_index = [fraction_within(valuies_asimov[2][0] - valuies_asimov[2][1],
#      32                                valuies_asimov[2][0] +  valuies_asimov[2][1],
#      33                                indices
#    (...)
#      45                                indices
#      46                               ),]
#      48 within_lambda = [fraction_within(valuies_asimov[3][0] - valuies_asimov[3][1],
#      49                                valuies_asimov[3][0] +  valuies_asimov[3][1],
#      50                                lambdas
#    (...)
#      62                                lambdas
#      63                               ),]
#
# NameError: name 'ampli_min_asimov_N' is not defined

# %%
fig, axs = plt.subplots(4,1, figsize = (4,7))
xlabels = ["Best Fit BKG Norm", "Best Fit Amplitude", "Best Fit Index", "Best Fit Lambda"]
legends = ["Nuisance",'Standard',   ]

for i, v in enumerate(valuies):
    print(i, xlabels[i])
    axs[i].hist(v[1:,0], color ='steelblue', alpha = 0.8)
    ylim = axs[i].get_ylim()
    delta_ylim = 5
    
    axs[i].vlines(valuies_asimov_N[i][0], ylim[0], ylim[1]+ delta_ylim, color = 'green', 
                 linestyle= 'dashed', )
    axs[i].fill_between([valuies_asimov_N[i][0] - valuies_asimov_N[i][1],
                         valuies_asimov_N[i][0] + valuies_asimov_N[i][1]]
                        , ylim[0], ylim[1]+ delta_ylim,
                       alpha = 0.3, color = 'green', 
                        label = legends[0] + f' \n({withins[i][1]*100 :.3}%)')
    axs[i].vlines(valuies_asimov[i][0], ylim[0], ylim[1], color = 'red')
    axs[i].fill_between([valuies_asimov[i][0] - valuies_asimov[i][1],
                         valuies_asimov[i][0] + valuies_asimov[i][1]]
                        , ylim[0], ylim[1],
                       alpha = 0.4 , color = 'red', 
                        label = legends[1] +  f' \n({withins[i][0]*100 :.3}%)'  )
    
    axs[i].set_xlabel(xlabels[i])  
    
    
    x = axs[i].get_xlim()
    deltax = np.max([ valuies_asimov[i][0] - x[0] , x[1] - valuies_asimov[i][0] ])
    axs[i].set_xlim(valuies_asimov[i][0] -deltax, 
                    valuies_asimov[i][0] + deltax)
    
ylim = axs[1].get_ylim()
delta_ylim = 9  
axs[1].vlines(ampli_min_asimov_N, ylim[0], ylim[1]+delta_ylim, color = 'green',  linestyle = 'dashed') 
axs[1].vlines(ampli_max_asimov_N, ylim[0], ylim[1]+delta_ylim, color = 'green',  linestyle = 'dashed',
             label=f'({withins[1][3]*100:.3} %)')    
axs[1].vlines(ampli_best_asimov_N, ylim[0], ylim[1]+delta_ylim, color = 'green',
              linestyle = 'dotted')

delta_ylim = 2
axs[1].vlines(ampli_min_asimov, ylim[0], ylim[1]+delta_ylim, color = 'red',  linestyle = 'dashed') 
axs[1].vlines(ampli_max_asimov, ylim[0], ylim[1]+delta_ylim, color = 'red',  linestyle = 'dashed',
             label=f'({withins[1][2]*100:.3} %)')    
axs[1].vlines(ampli_best_asimov, ylim[0], ylim[1]+delta_ylim, color = 'red',
              linestyle = 'dotted')

ylim = axs[2].get_ylim()
delta_ylim = 9

axs[2].vlines(index_min_asimov_N, ylim[0], ylim[1]+delta_ylim, color = 'green', linestyle = 'dashed') 
axs[2].vlines(index_max_asimov_N, ylim[0], ylim[1]+delta_ylim, color = 'green', linestyle = 'dashed',
             label=f'({withins[2][3]*100:.3} %)')   
axs[2].vlines(index_best_asimov_N, ylim[0], ylim[1]+delta_ylim, color = 'green',
              linestyle = 'dotted')
delta_ylim = 2
axs[2].vlines(index_min_asimov, ylim[0], ylim[1]+delta_ylim, color = 'red', linestyle = 'dashed') 
axs[2].vlines(index_max_asimov, ylim[0], ylim[1]+delta_ylim, color = 'red', linestyle = 'dashed',
             label=f'({withins[2][2]*100:.3} %)') 
axs[2].vlines(index_best_asimov, ylim[0], ylim[1]+delta_ylim, color = 'red',
              linestyle = 'dotted')

ylim = axs[3].get_ylim()
delta_ylim = 9

axs[3].vlines(lambda_min_asimov_N, ylim[0], ylim[1]+delta_ylim, color = 'green', linestyle = 'dashed') 
axs[3].vlines(lambda_max_asimov_N, ylim[0], ylim[1]+delta_ylim, color = 'green', linestyle = 'dashed',
             label=f'({withins[3][3]*100:.3} %)')   
axs[3].vlines(lambda_best_asimov_N, ylim[0], ylim[1]+delta_ylim, color = 'green',
              linestyle = 'dotted')
delta_ylim = 2
axs[3].vlines(lambda_min_asimov, ylim[0], ylim[1]+delta_ylim, color = 'red', linestyle = 'dashed') 
axs[3].vlines(lambda_max_asimov, ylim[0], ylim[1]+delta_ylim, color = 'red', linestyle = 'dashed',
             label=f'({withins[3][2]*100:.3} %)') 
axs[3].vlines(lambda_best_asimov, ylim[0], ylim[1]+delta_ylim, color = 'red',
              linestyle = 'dotted')

plt.tight_layout()
for a in axs:
    a.legend(title="1$\sigma$ eror",loc='center left', bbox_to_anchor=(1, 0.5))

# %% [markdown]
# ## 2D Histograms Poission (Only Amplitude/Index yet)

# %%
N_bins = N_new + 1
amplitude_bin = np.linspace(amplix__new_N[0], amplix__new_N[-1], N_bins )
index_bin = np.linspace(indexy__new_N[0], indexy__new_N[-1], N_bins )

amplitudes_data = valuies[1][:,0]
indices_data = valuies[2][:,0]
data_N_new, (abins, ibins) = np.histogramdd((amplitudes_data, indices_data), (amplitude_bin, index_bin))

fig, ax = plt.subplots()
im =ax.pcolormesh(ibins, 
           abins,
           data_N_new)

fig.colorbar(im, ax=ax)
ax.plot(index_best_N, ampli_best_N, 'x', color = 'green')
ax.plot(index_best, ampli_best, 'x', color = 'red')

ax.set_ylabel("Amplitudes")
ax.set_xlabel("Indices")
plt.plot(dat[:,0],dat[:,1], color = 'red')
plt.plot(dat_N[:,0],dat_N[:,1], color = 'green')

# %%
def compute_inside(Ls_new, x_new,
               y_new, threshold,  find_min = False,  delta=1
                 ):
    tot_int = np.sum(Ls_new)
    offset = Ls_new.min() + threshold
    outside = Ls_new* (Ls_new < offset)
    inside = Ls_new* (Ls_new >= offset)

    return outside

# %%
threshold_contour = 1
outside_N = compute_inside(
    data_contour_N, amplix__new_N,
           indexy__new_N,  threshold_contour,  find_min = True, delta =1 )

outside = compute_inside(
    data_contour, amplix__new_N,
           indexy__new_N, threshold_contour,  find_min = True, delta =1 )

outside_N = outside_N <-1.0
outside = outside <-1.0

# %%
masked_N =  data_N_new * outside_N
masked =  data_N_new * outside

fig, (ax, ax2) = plt.subplots(1,2, figsize = (11,4))
im =ax.pcolormesh(indexy__new_N,
           amplix__new_N, masked)

fig.colorbar(im, ax=ax)
im =ax2.pcolormesh(indexy__new_N,
           amplix__new_N, masked_N)

fig.colorbar(im, ax=ax2)
for a in [ax, ax2]:
    a.set_ylabel("amplitude")
    a.set_xlabel("index",)
    a.plot(dat[:,0],dat[:,1], color = 'red')
    a.plot(dat_N[:,0],dat_N[:,1], color = 'green')

fraction_within_2d_N = np.sum(masked_N) /  np.sum(data_N_new)
fraction_within_2d = np.sum(masked) /  np.sum(data_N_new)

ax2.set_title(f"Likelihood Nuisance: {fraction_within_2d_N:.3}")
ax.set_title(f"Likelihood {fraction_within_2d:.3}")
