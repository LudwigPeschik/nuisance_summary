# %%
import gammapy 
print(f'loaded gammapy version: {gammapy.__version__} ' )
print(f'Supposed to be 1.0 (21-11-2022)' )
# Out:
# loaded gammapy version: 1.0
# Supposed to be 1.0 (21-11-2022)

# %%
#get_ipython().system('jupyter nbconvert --to script 1-Nui_Par_Fitting.ipynb')
import pyximport

pyximport.install()
import matplotlib.pyplot as plt
import numpy as np
import astropy.units as u
import gammapy

# from gammapy.datasets import MapDataset
from gammapy.maps import Map
from astropy.coordinates import SkyCoord, Angle
from gammapy.modeling import Fit,  Parameters, Covariance , Parameter
from gammapy.datasets import MapDataset, Datasets#, MapDatasetNuisance
from gammapy.modeling.models import (
    PowerLawSpectralModel,
    create_crab_spectral_model,
    SkyModel,
    PointSpatialModel,
    ShellSpatialModel,
    GeneralizedGaussianSpatialModel,
    TemplateSpatialModel,
    LogParabolaSpectralModel,
    GaussianSpatialModel,
    DiskSpatialModel,
    PowerLawNormSpectralModel,
    Models,
    SpatialModel,
    FoVBackgroundModel,
    ExpCutoffPowerLawSpectralModel
)
from gammapy.estimators import TSMapEstimator, ExcessMapEstimator

from regions import CircleSkyRegion, RectangleSkyRegion
import yaml
import sys

from Dataset_Creation_Test import sys_dataset

# %% [markdown]
# ## Read dataset

# %%
dataset_asimov = MapDataset.read("c:/users/yt02izug/downloads/dataset_asimov/dataset_asimov.fits")
# Create the spatial model 
model_spatial = GaussianSpatialModel(
    lon_0="83.631 deg",
    lat_0="22.018 deg",
    sigma="0.02 deg",
    )

# Create the spectral model 
model_spectrum  = ExpCutoffPowerLawSpectralModel(
    index=2.3,
    amplitude="1e-12 TeV-1 cm-2 s-1",
    lambda_="0.1 TeV-1")

# combine the spectral and the spatial model
source_model = SkyModel(spatial_model = model_spatial ,
                       spectral_model = model_spectrum,
                       name = "Source")    
models = Models(source_model)

# Create the model for the Background
bkg_model = FoVBackgroundModel(dataset_name=dataset_asimov.name)
bkg_model.parameters['tilt'].frozen  = False
models.append(bkg_model)

# set the models in the dataset
dataset_asimov.models = models
# set counts
dataset_asimov.counts = dataset_asimov.npred()
    
dataset_asimov.counts.sum_over_axes().plot(add_cbar=1)
binsize = dataset_asimov.geoms["geom"].width[1] / dataset_asimov.geoms["geom"].data_shape[1]
print(
    "spatial binsize = ",
    binsize
)

print(dataset_asimov)
# Out:
# spatial binsize =  [0.08] deg
# MapDataset
# ----------
#
#   Name                            : 1MUXqVCD
#
#   Total counts                    : 361088
#   Total background counts         : 360331.31
#   Total excess counts             : 756.96
#
#   Predicted counts                : 361088.27
#   Predicted background counts     : 360331.34
#   Predicted excess counts         : 756.93
#
#   Exposure min                    : 2.07e-01 m2 s
#   Exposure max                    : 2.41e+11 m2 s
#
#   Number of total bins            : 540000
#   Number of fit bins              : 180191
#
#   Fit statistic type              : cash
#   Fit statistic value (-2 log(L)) : -752490.77
#
#   Number of models                : 2
#   Number of parameters            : 13
#   Number of free parameters       : 8
#
#   Component 0: SkyModel
#
#     Name                      : Source
#     Datasets names            : None
#     Spectral model type       : ExpCutoffPowerLawSpectralModel
#     Spatial  model type       : GaussianSpatialModel
#     Temporal model type       :
#     Parameters:
#       index                         :      2.300   +/-    0.00
#       amplitude                     :   1.00e-12   +/- 0.0e+00 1 / (cm2 s TeV)
#       reference             (frozen):      1.000       TeV
#       lambda_                       :      0.100   +/-    0.00 1 / TeV
#       alpha                 (frozen):      1.000
#       lon_0                         :     83.631   +/-    0.00 deg
#       lat_0                         :     22.018   +/-    0.00 deg
#       sigma                         :      0.020   +/-    0.00 deg
#       e                     (frozen):      0.000
#       phi                   (frozen):      0.000       deg
#
#   Component 1: FoVBackgroundModel
#
#     Name                      : 1MUXqVCD-bkg
#     Datasets names            : ['1MUXqVCD']
#     Spectral model type       : PowerLawNormSpectralModel
#     Parameters:
#       norm                          :      1.000   +/-    0.00
#       tilt                          :      0.000   +/-    0.00
#       reference             (frozen):      1.000       TeV

# %% [markdown]
# ## Cases with varied Amplitude

# %%
amplitude_array = [1e-13, 5e-13, 1e-12, 5e-12]

sigma_spatial = 0.02

shift_neg = 0.0 #0.1 #0.085
tilt_neg = 0.0 #0.015

sigma_shift = 0.1
sigma_tilt = 0.015

# %%
#initialize asimov datasets with different amplitude
dataset_asimov_array = []
true_energy_array = []
datasets = []
datasets_N = []
for i, a in enumerate(amplitude_array):
    dataset_asimov = MapDataset.read("c:/users/yt02izug/downloads/dataset_asimov/dataset_asimov.fits")
    # Create the spatial model 
    model_spatial = GaussianSpatialModel(
        lon_0="83.631 deg",
        lat_0="22.018 deg",
        sigma=f"{sigma_spatial} deg",
        )

    # Create the spectral model 
    model_spectrum  = ExpCutoffPowerLawSpectralModel(
        index=2.3,
        amplitude=f"{a} TeV-1 cm-2 s-1",
        lambda_="0.1 TeV-1"
    )

    # combine the spectral and the spatial model
    source_model = SkyModel(spatial_model = model_spatial ,
                           spectral_model = model_spectrum,
                           name = "Source")    
    models = Models(source_model)

    # Create the model for the Background
    bkg_model = FoVBackgroundModel(dataset_name=dataset_asimov.name)
    bkg_model.parameters['tilt'].frozen  = False
    models.append(bkg_model)

    # set the models in the dataset
    dataset_asimov.models = models
    # set counts
    dataset_asimov.counts = dataset_asimov.npred()
    
    dataset_asimov_array.append(dataset_asimov)
    
    sys_ = sys_dataset(dataset_asimov= dataset_asimov,
                        shift = shift_neg, 
                        tilt = tilt_neg,
                        rnd = False,
                        amplitude = a,
                        sigma = sigma_spatial)
    dataset = sys_.create_dataset()
    dataset.models[0].parameters['lon_0'].frozen = True
    dataset.models[0].parameters['lat_0'].frozen = True
    datasets.append(dataset)
    
    dataset_N = sys_.create_dataset_N()
    zero = 1e-24
    ## additional parameter bias and resolution (ereco) but are frozen
    penalising_invcovmatrix = np.zeros((4, 4))
    np.fill_diagonal(penalising_invcovmatrix,
                     [1/sigma_shift**2, 1/sigma_tilt**2, 1/zero**2, 1/zero**2])
    dataset_N.penalising_invcovmatrix = penalising_invcovmatrix
    dataset_N.models[0].parameters['lon_0'].frozen = True
    dataset_N.models[0].parameters['lat_0'].frozen = True
    datasets_N.append(dataset_N)
    
    
    true_energy_array.append(dataset_asimov.exposure.geom.axes[0].center.value)

# %%
# %%time
for i, a in enumerate(amplitude_array):
    print(a)
    fit = Fit(store_trace=False)
    minuit_opts = {"tol": 0.001, "strategy": 2}
    fit.backend = "minuit"
    fit.optimize_opts = minuit_opts
    result = fit.run([datasets[i]])
# Out:
# 1e-13
# 5e-13
# 1e-12
# 5e-12
# CPU times: total: 11.5 s
# Wall time: 11.6 s

# %%
# %%time
for i, a in enumerate(amplitude_array):
    print(a)
    fit_N = Fit(store_trace=False)
    minuit_opts = {"tol": 0.001, "strategy": 2}
    fit_N.backend = "minuit"
    fit_N.optimize_opts = minuit_opts
    result_N = fit_N.run([datasets_N[i]])
# Out:
# 1e-13
# 5e-13
# 1e-12
# 5e-12
# CPU times: total: 50min 24s
# Wall time: 13min 24s

# %% [markdown]
# # Stat Profiles

# %%
import upper_limit_18_02

# %% [markdown]
# ## Stat Profiles for BKG Norm

# %%
def make_writable(stat):
    write = dict()
    for k in stat.keys():
        if k != 'fit_results':
            write[k] = [float(i) for i in stat[k]]
            
                
    return write

# %%
# %%time
computing_norm = True
for i, a in enumerate(amplitude_array):
    print(a)
    if computing_norm :
        parameter = datasets[i].models[1].parameters['norm']
        sigma = 3
        parameter.scan_n_sigma  = sigma
        stat_profile = fit.stat_profile([datasets[i]], parameter, reoptimize= True)
        stat_profile['scale_scan'] = stat_profile.pop(next(iter(stat_profile)) )    
        with open(f'data/5b_scan_norm_A{a}_zero.yaml', 'w') as file:
            documents = yaml.dump(make_writable(stat_profile), file)
    else:
        with open(f'data/5b_scan_norm_A{a}_zero.yaml') as file:
            stat_profile = yaml.load( file, Loader=yaml.FullLoader)
# Out:
# 1e-13
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# 5e-13
# 1e-12
# 5e-12
# CPU times: total: 3min 42s
# Wall time: 3min 42s

# %%
# %%time
for i, a in enumerate(amplitude_array):
    print(a)
    if computing_norm :
        parameter = datasets_N[i].models[1].parameters['norm']
        sigma = 3
        parameter.scan_n_sigma  = sigma
        stat_profile_N = fit.stat_profile([datasets_N[i]], parameter, reoptimize = True)
        stat_profile_N['scale_scan'] = stat_profile_N.pop(next(iter(stat_profile_N)) )    
        with open(f'data/5b_scan_norm_N_A{a}_zero.yaml', 'w') as file:
            documents = yaml.dump(make_writable(stat_profile_N), file)
        for k in stat_profile_N:
            if "spectral" in k:
                key_name = "scale_scan"
                stat_profile_N[key_name] = stat_profile_N[k]      
    else:
        with open(f'data/5b_scan_norm_N_A{a}_zero.yaml') as file:
            stat_profile_N = yaml.load( file, Loader=yaml.FullLoader)
# Out:
# 1e-13
# 5e-13
# 1e-12
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# 5e-12
# CPU times: total: 9h 31min 17s
# Wall time: 2h 52min 38s

# %%
import upper_limit_18_02
fig = plt.figure()
for i, a in enumerate(amplitude_array):
    with open(f'data/5b_scan_norm_N_A{a}_zero.yaml') as file:
            stat_profile_N = yaml.load( file, Loader=yaml.FullLoader)
    ll_N = stat_profile_N.copy()
    ul_N = upper_limit_18_02.upper_limit(ll_N,0,0)
    L_N, x_N = ul_N.interpolate()
    plt.plot(x_N, L_N(x_N)-min(L_N(x_N)),label =f"Scan Standard, A = {a}")
    
    with open(f'data/5b_scan_norm_A{a}_zero.yaml') as file:
            stat_profile = yaml.load( file, Loader=yaml.FullLoader)
    ll = stat_profile.copy()
    ul = upper_limit_18_02.upper_limit(ll,0,0)
    L, x = ul.interpolate()
    plt.plot(x, L(x)-min(L(x)),label =f"Scan with Nuisance Par., A = {a}")

    norm_err_N = datasets_N[i].models.parameters['norm'].error
    norm_err = datasets[i].models.parameters['norm'].error


    min_, er = ul_N.likelihood_error()
    min_ = min_[0]; er = er[0]
    ax = plt.gca()
    ylim= ax.get_ylim()
    ax.fill_between(  [min_-er, min_+ er], ylim[0], ylim[1], alpha = 0.2, 
                    label = f'1$\sigma$ error = {er:.2} ({norm_err_N:.2}), A = {a}')
    min_, er = ul.likelihood_error() #min_, er, upp = ul.likelihood_upper()
    min_ = min_[0]; er = er[0]
    ax.fill_between(  [min_-er, min_+ er], ylim[0], ylim[1],  alpha = 0.2, 
                    label = f'1$\sigma$ error = {er:.2} ({norm_err:.2}), A = {a}')

plt.xlabel("BKG Norm []")
plt.ylabel("-2log (L) [arb. unit]")
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
#plt.ylim(ylim[0], ylim[1]-4)
plt.title(f"Sys = 0% (s = {shift_neg}, t = {tilt_neg})")

fig.savefig("plots/5b_stat_scan_norm_zero.png")

# %%
L_N(x_N)
# Out:
# array([-773102.3187553 , -773102.33082222, -773102.34288104, ...,
#        -773102.41686884, -773102.4049625 , -773102.39304826])

# %% [markdown]
# ## Stat Profiles for Source Signal

# %%
# %%time
computing_amplitude = True
for i, a in enumerate(amplitude_array):
    print(a)
    if computing_amplitude:
        sigma = 3
        parameter_a = datasets[i].models.parameters['amplitude']
        parameter_a.scan_n_sigma = sigma
        stat_profile_a = fit.stat_profile([datasets[i]], parameter_a, reoptimize= True)
        stat_profile_a['scale_scan'] = stat_profile_a.pop(next(iter(stat_profile_a)) )    
        with open(f'data/5b_scan_amplitude_A{a}_zero.yaml', 'w') as file:
            documents = yaml.dump(make_writable(stat_profile_a), file)

    else:
        with open(f'data/5b_scan_amplitude_A{a}_zero.yaml') as file:
            stat_profile_a = yaml.load( file, Loader=yaml.FullLoader)
# Out:
# 1e-13
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# ...
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# 5e-13
# 1e-12
# 5e-12
# CPU times: total: 2min 48s
# Wall time: 2min 48s

# %%
# %%time
computing_amplitude_N = True
for i, a in enumerate(amplitude_array):
    print(a)
    if computing_amplitude_N:
        sigma = 3
        parameter_a = datasets_N[i].models.parameters['amplitude']
        parameter_a.scan_n_sigma = sigma
        stat_profile_N_a = fit.stat_profile([datasets_N[i]], parameter_a, reoptimize = True)
        stat_profile_N_a['scale_scan'] = stat_profile_N_a.pop(next(iter(stat_profile_N_a)) )    

        with open(f'data/5b_scan_amplitude_N_A{a}_zero.yaml', 'w') as file:
            documents = yaml.dump(make_writable(stat_profile_N_a), file)

    else:
        with open(f'data/5b_scan_amplitude_N_A{a}_zero.yaml') as file:
            stat_profile_N_a = yaml.load( file, Loader=yaml.FullLoader)
# Out:
# 1e-13
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# 5e-13
# 1e-12
# 5e-12
# CPU times: total: 7h 43min 34s
# Wall time: 1h 55min 27s

# %%
fig = plt.figure()
for i, a in enumerate(amplitude_array[1:]):
    with open(f'data/5b_scan_amplitude_N_A{a}_zero.yaml') as file:
            stat_profile_N_a = yaml.load( file, Loader=yaml.FullLoader)
    ll_N_a = stat_profile_N_a.copy()
    ul_N_a = upper_limit_18_02.upper_limit(ll_N_a,0,0)
    L_N_a, x_N_a = ul_N_a.interpolate()
    plt.plot(x_N_a*a**(-1), L_N_a(x_N_a)-min(L_N_a(x_N_a)),label = f"Nuisance, A = {a}")

    with open(f'data/5b_scan_amplitude_A{a}_zero.yaml') as file:
            stat_profile_a = yaml.load( file, Loader=yaml.FullLoader)
    ll_a = stat_profile_a.copy()
    ul_a = upper_limit_18_02.upper_limit(ll_a,0,0)
    L_a, x_a = ul_a.interpolate()
    plt.plot(x_a*a**(-1), L_a(x_a)-min(L_a(x_a)),label = f"Standard, A = {a}")

    amplitude_err = datasets[i].models[0].parameters['amplitude'].error
    amplitude_err_N = datasets_N[i].models[0].parameters['amplitude'].error



    min_, er = ul_N_a.likelihood_error()
    min_ = min_[0]; er = er[0]
    ax = plt.gca()
    ylim= ax.get_ylim()
    ax.fill_between(  [(min_-er)*a**(-1), (min_+ er)*a**(-1)], ylim[0], ylim[1], alpha = 0.2, 
                    label = f'1$\sigma$ error = {er:.2} ({amplitude_err_N:.2}), A = {a}')
    min_, er = ul_a.likelihood_error() #min_, er, upp = ul.likelihood_upper()
    min_ = min_[0]; er = er[0]
    ax.fill_between(  [(min_-er)*a**(-1), (min_+ er)*a**(-1)], ylim[0], ylim[1],  alpha = 0.2, 
                    label = f'1$\sigma$ error = {er:.2} ({amplitude_err:.2}), A = {a}')

plt.xlabel("Source amplitude * 1/A [1/cm2sTeV]")
plt.ylabel("-2log (L) [arb. unit]")
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
#plt.ylim(ylim[0], ylim[1]-25)
plt.title(f"Sys = 0% (s = {shift_neg}, t = {tilt_neg})")

fig.savefig("plots/5b_stat_scan_amplitude_zero.png")

# %% [markdown]
# ## Stat Profiles for Source Index

# %%
# %%time
computing_index = False

for i, a in enumerate(amplitude_array):
    print(a)
    if computing_index:
        sigma = 3
        parameter_i = datasets[i].models.parameters['index']
        parameter_i.scan_n_sigma = sigma
        stat_profile_i = fit.stat_profile([datasets[i]], parameter_i, reoptimize= True)
        stat_profile_i['scale_scan'] = stat_profile_i.pop(next(iter(stat_profile_i)) )    
        with open(f'data/5b_scan_index_A{a}_zero.yaml', 'w') as file:
            documents = yaml.dump(make_writable(stat_profile_i), file)

    else:
        with open(f'data/5b_scan_index_A{a}_zero.yaml') as file:
            stat_profile_i = yaml.load( file, Loader=yaml.FullLoader)
# Out:
# 1e-13
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# 5e-13
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# 1e-12
# 5e-12
# CPU times: total: 2min 40s
# Wall time: 2min 44s

# %%
# %%time
computing_index_N = False
for i, a in enumerate(amplitude_array):
    print(a)
    if computing_index_N:
        sigma = 3
        parameter_i = datasets_N[i].models.parameters['index']
        parameter_i.scan_n_sigma = sigma
        stat_profile_N_i = fit.stat_profile([datasets_N[i]], parameter_i, reoptimize = True)
        stat_profile_N_i['scale_scan'] = stat_profile_N_i.pop(next(iter(stat_profile_N_i)) )    

        with open(f'data/5b_scan_index_N_A{a}_zero.yaml', 'w') as file:
            documents = yaml.dump(make_writable(stat_profile_N_i), file)

    else:
        with open(f'data/5b_scan_index_N_A{a}_zero.yaml') as file:
            stat_profile_N_i = yaml.load( file, Loader=yaml.FullLoader)
# Out:
# 1e-13
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:907: RuntimeWarning: overflow encountered in multiply
#   value = value * scale
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# ...
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\Ludwig\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# 5e-13
# 1e-12
# 5e-12
# CPU times: total: 12h 16min 31s
# Wall time: 1h 50min 10s

# %%
fig = plt.figure()
for i, a in enumerate(amplitude_array[1:]):
    with open(f'data/5b_scan_index_N_A{a}_zero.yaml') as file:
            stat_profile_N_i = yaml.load( file, Loader=yaml.FullLoader)
    ll_N_a = stat_profile_N_i.copy()
    ul_N_a = upper_limit_18_02.upper_limit(ll_N_a,0,0)
    L_N_a, x_N_a = ul_N_a.interpolate()
    plt.plot(x_N_a, L_N_a(x_N_a)-min(L_N_a(x_N_a)),label = f"Nuisance, A = {a}")

    with open(f'data/5b_scan_index_A{a}_zero.yaml') as file:
            stat_profile_i = yaml.load( file, Loader=yaml.FullLoader)
    ll_a = stat_profile_i.copy()
    ul_a = upper_limit_18_02.upper_limit(ll_a,0,0)
    L_a, x_a = ul_a.interpolate()
    plt.plot(x_a, L_a(x_a)-min(L_a(x_a)),label = f"Standard, A = {a}")

    index_err = datasets[i].models[0].parameters['index'].error
    index_err_N = datasets_N[i].models[0].parameters['index'].error



    min_, er = ul_N_a.likelihood_error()
    min_ = min_[0]; er = er[0]
    ax = plt.gca()
    ylim= ax.get_ylim()
    ax.fill_between(  [min_-er, min_+ er], ylim[0], ylim[1], alpha = 0.2, 
                    label = f'1$\sigma$ error = {er:.2} ({index_err_N:.2}), A = {a}')
    min_, er = ul_a.likelihood_error() #min_, er, upp = ul.likelihood_upper()
    min_ = min_[0]; er = er[0]
    ax.fill_between(  [min_-er, min_+ er], ylim[0], ylim[1],  alpha = 0.2, 
                    label = f'1$\sigma$ error = {er:.2} ({index_err:.2}), A = {a}')

plt.xlabel("Source Index")
plt.ylabel("-2log (L) [arb. unit]")
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
#plt.ylim(ylim[0], ylim[1]-25)
plt.title(f"Sys = 0% (s = {shift_neg}, t = {tilt_neg})")

fig.savefig("plots/5b_stat_scan_index_zero.png")

# %% [markdown]
# ## Stat Profiles for Source Lambda

# %%
# %%time
computing_lambda = True

for i, a in enumerate(amplitude_array):
    print(a)
    if computing_lambda:
        sigma = 3
        scan_array = np.linspace(0.01, 0.51, 11)
        parameter_l = datasets[i].models.parameters['lambda_']
        parameter_l.scan_values = scan_array#scan_n_sigma = sigma
        stat_profile_l = fit.stat_profile([datasets[i]], parameter_l, reoptimize= True)
        stat_profile_l['scale_scan'] = stat_profile_l.pop(next(iter(stat_profile_l)) )    
        with open(f'data/5b_scan_lambda_A{a}_zero.yaml', 'w') as file:
            documents = yaml.dump(make_writable(stat_profile_l), file)

    else:
        with open(f'data/5b_scan_lambda_A{a}_zero.yaml') as file:
            stat_profile_l = yaml.load( file, Loader=yaml.FullLoader)
# Out:
# 1e-13
# 5e-13
# 1e-12
# 5e-12
# CPU times: total: 3min 36s
# Wall time: 3min 36s

# %%
# %%time
computing_lambda_N = True
for i, a in enumerate(amplitude_array):
    print(a)
    if computing_lambda_N:
        sigma = 3
        scan_array = np.linspace(0.01, 0.51, 11)
        parameter_l = datasets_N[i].models.parameters['lambda_']
        parameter_l.scan_values = scan_array#scan_n_sigma = sigma
        stat_profile_N_l = fit.stat_profile([datasets_N[i]], parameter_l, reoptimize = True)
        stat_profile_N_l['scale_scan'] = stat_profile_N_l.pop(next(iter(stat_profile_N_l)) )    

        with open(f'data/5b_scan_lambda_N_A{a}_zero.yaml', 'w') as file:
            documents = yaml.dump(make_writable(stat_profile_N_l), file)

    else:
        with open(f'data/5b_scan_lambda_N_A{a}_zero.yaml') as file:
            stat_profile_N_l = yaml.load( file, Loader=yaml.FullLoader)
# Out:
# 1e-13
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File <timed exec>:9, in <module>
#
# File ~\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\gammapy\modeling\fit.py:377, in Fit.stat_profile(self, datasets, parameter, reoptimize)
#     375 if reoptimize:
#     376     parameter.frozen = True
# --> 377     result = self.optimize(datasets=datasets)
#     378     stat = result.total_stat
#     379     fit_results.append(result)
#
# File ~\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\gammapy\modeling\fit.py:212, in Fit.optimize(self, datasets)
#     208 compute = registry.get("optimize", backend)
#     209 # TODO: change this calling interface!
#     210 # probably should pass a fit statistic, which has a model, which has parameters
#     211 # and return something simpler, not a tuple of three things
# --> 212 factors, info, optimizer = compute(
#     213     parameters=parameters,
#     214     function=datasets.stat_sum,
#     215     store_trace=self.store_trace,
#     216     **kwargs,
#     217 )
#     219 if backend == "minuit":
#     220     self._minuit = optimizer
#
# File ~\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\gammapy\modeling\iminuit.py:79, in optimize_iminuit(parameters, function, store_trace, **kwargs)
#      73 migrad_opts = kwargs.pop("migrad_opts", {})
#      75 minuit, minuit_func = setup_iminuit(
#      76     parameters=parameters, function=function, store_trace=store_trace, **kwargs
#      77 )
# ---> 79 minuit.migrad(**migrad_opts)
#      81 factors = minuit.values
#      82 info = {
#      83     "success": minuit.valid,
#      84     "nfev": minuit.nfcn,
#      85     "message": _get_message(minuit, parameters),
#      86     "trace": minuit_func.trace,
#      87 }
#
# File ~\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\iminuit\minuit.py:694, in Minuit.migrad(self, ncall, iterate)
#     692 if self._precision is not None:
#     693     migrad.precision = self._precision
# --> 694 fm = migrad(ncall, self._tolerance)
#     695 if fm.is_valid or fm.has_reached_call_limit:
#     696     break
#
# File ~\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\gammapy\modeling\iminuit.py:25, in MinuitLikelihood.fcn(self, *factors)
#      22 def fcn(self, *factors):
#      23     self.parameters.set_parameter_factors(factors)
# ---> 25     total_stat = self.function()
#      27     if self.store_trace:
#      28         self.store_trace_iteration(total_stat)
#
# File ~\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\gammapy\datasets\core.py:236, in Datasets.stat_sum(self)
#     234 # TODO: add parallel evaluation of likelihoods
#     235 for dataset in self:
# --> 236     stat_sum += dataset.stat_sum()
#     237 return stat_sum
#
# File ~\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\gammapy\datasets\map.py:911, in MapDataset.stat_sum(self)
#     909 def stat_sum(self):
#     910     """Total likelihood given the current model parameters plus the Gaussian penalty term."""
# --> 911     counts, npred = self.counts.data.astype(float), self.npred().data
#     912     if len(self.models.parameters.penalised_parameters) > 0:
#     913         # if self.penalising_invcovmatrix is not None:
#     914         penalty = gaussian_penality(
#     915             self.models.parameters.penalised_parameters,
#     916             self._penalising_invcovmatrix,
#     917         )
#
# File ~\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\gammapy\datasets\map.py:453, in MapDataset.npred(self)
#     445 def npred(self):
#     446     """Total predicted source and background counts
#     447
#     448     Returns
#    (...)
#     451         Total predicted counts
#     452     """
# --> 453     npred_total = self.npred_signal()
#     455     if self.background:
#     456         npred_total += self.npred_background()
#
# File ~\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\gammapy\datasets\map.py:584, in MapDataset.npred_signal(self, model_name)
#     582     exposure = self.npred_exposure()
#     583     edisp = self.npred_edisp()
# --> 584     evaluator.update(
#     585         exposure,
#     586         self.psf,
#     587         edisp,
#     588         self._geom,
#     589         self.mask_image,
#     590     )
#     592 if evaluator.contributes:
#     593     npred = evaluator.compute_npred()
#
# File ~\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\gammapy\datasets\evaluator.py:193, in MapEvaluator.update(self, exposure, psf, edisp, geom, mask)
#     190         if geom_psf.is_region or geom_psf.is_hpx:
#     191             geom_psf = geom_psf.to_wcs_geom()
# --> 193         self.psf = psf.get_psf_kernel(
#     194             position=self.model.position,
#     195             geom=geom_psf,
#     196             containment=PSF_CONTAINMENT,
#     197             max_radius=PSF_MAX_RADIUS,
#     198         )
#     200 if self.evaluation_mode == "local":
#     201     self.contributes = self.model.contributes(mask=mask, margin=self.psf_width)
#
# File ~\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\gammapy\irf\psf\map.py:276, in PSFMap.get_psf_kernel(self, geom, position, max_radius, containment, factor)
#     268 rad = coords.skycoord.separation(geom.center_skydir)
#     270 coords = {
#     271     self.energy_name: coords[self.energy_name],
#     272     "rad": rad,
#     273     "skycoord": position,
#     274 }
# --> 276 data = self.psf_map.interp_by_coord(
#     277     coords=coords,
#     278     method="linear",
#     279 )
#     281 kernel_map = Map.from_geom(geom=geom_upsampled, data=np.clip(data, 0, np.inf))
#     282 kernel_map = kernel_map.downsample(factor, preserve_counts=True)
#
# File ~\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\gammapy\maps\wcs\ndmap.py:133, in WcsNDMap.interp_by_coord(self, coords, method, fill_value)
#     131 if self.geom.is_regular:
#     132     pix = self.geom.coord_to_pix(coords)
# --> 133     return self.interp_by_pix(pix, method=method, fill_value=fill_value)
#     134 else:
#     135     return self._interp_by_coord_griddata(coords, method=method)
#
# File ~\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\gammapy\maps\wcs\ndmap.py:152, in WcsNDMap.interp_by_pix(self, pix, method, fill_value)
#     147     data = self.data.T
#     149 fn = ScaledRegularGridInterpolator(
#     150     grid_pix, data, fill_value=None, bounds_error=False, method=method
#     151 )
# --> 152 interp_data = fn(tuple(pix), clip=False)
#     154 if fill_value is not None:
#     155     idxs = self.geom.pix_to_idx(pix, clip=False)
#
# File ~\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\gammapy\utils\interpolation.py:120, in ScaledRegularGridInterpolator.__call__(self, points, method, clip, **kwargs)
#     118     points = np.broadcast_arrays(*points)
#     119     points_interp = np.stack([_.flat for _ in points]).T
# --> 120     values = self._interpolate(points_interp, method, **kwargs)
#     121     values = self.scale.inverse(values.reshape(points[0].shape))
#     122 else:
#
# File ~\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\scipy\interpolate\_rgi.py:323, in RegularGridInterpolator.__call__(self, xi, method)
#     318         if not np.logical_and(np.all(self.grid[i][0] <= p),
#     319                               np.all(p <= self.grid[i][-1])):
#     320             raise ValueError("One of the requested xi is out of bounds "
#     321                              "in dimension %d" % i)
# --> 323 indices, norm_distances, out_of_bounds = self._find_indices(xi.T)
#     324 if method == "linear":
#     325     result = self._evaluate_linear(indices,
#     326                                    norm_distances,
#     327                                    out_of_bounds)
#
# File ~\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\scipy\interpolate\_rgi.py:427, in RegularGridInterpolator._find_indices(self, xi)
#     425 # iterate through dimensions
#     426 for x, grid in zip(xi, self.grid):
# --> 427     i = np.searchsorted(grid, x) - 1
#     428     i[i < 0] = 0
#     429     i[i > grid.size - 2] = grid.size - 2
#
# File <__array_function__ internals>:180, in searchsorted(*args, **kwargs)
#
# File ~\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\numpy\core\fromnumeric.py:1387, in searchsorted(a, v, side, sorter)
#    1319 @array_function_dispatch(_searchsorted_dispatcher)
#    1320 def searchsorted(a, v, side='left', sorter=None):
#    1321     """
#    1322     Find indices where elements should be inserted to maintain order.
#    1323
#    (...)
#    1385
#    1386     """
# -> 1387     return _wrapfunc(a, 'searchsorted', v, side=side, sorter=sorter)
#
# File ~\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\numpy\core\fromnumeric.py:57, in _wrapfunc(obj, method, *args, **kwds)
#      54     return _wrapit(obj, method, *args, **kwds)
#      56 try:
# ---> 57     return bound(*args, **kwds)
#      58 except TypeError:
#      59     # A TypeError occurs if the object does have such a method in its
#      60     # class, but its signature is not identical to that of NumPy's. This
#    (...)
#      64     # Call _wrapit from within the except clause to ensure a potential
#      65     # exception has a traceback chain.
#      66     return _wrapit(obj, method, *args, **kwds)
#
# KeyboardInterrupt:

# %%
fig = plt.figure()
for i, a in enumerate(amplitude_array[1:]):
    with open(f'data/5b_scan_lambda_N_A{a}_zero.yaml') as file:
            stat_profile_N_l = yaml.load( file, Loader=yaml.FullLoader)
    ll_N_a = stat_profile_N_l.copy()
    ul_N_a = upper_limit_18_02.upper_limit(ll_N_a,0,0)
    L_N_a, x_N_a = ul_N_a.interpolate()
    plt.plot(x_N_a, L_N_a(x_N_a)-min(L_N_a(x_N_a)),label = f"Nuisance, A = {a}")

    with open(f'data/5b_scan_lambda_A{a}_zero.yaml') as file:
            stat_profile_l = yaml.load( file, Loader=yaml.FullLoader)
    ll_a = stat_profile_l.copy()
    ul_a = upper_limit_18_02.upper_limit(ll_a,0,0)
    L_a, x_a = ul_a.interpolate()
    plt.plot(x_a, L_a(x_a)-min(L_a(x_a)),label = f"Standard, A = {a}")

    lambda_err = datasets[i].models[0].parameters['lambda_'].error
    lambda_err_N = datasets_N[i].models[0].parameters['lambda_'].error



    min_, er = ul_N_a.likelihood_error()
    min_ = min_[0]; er = er[0]
    ax = plt.gca()
    ylim= ax.get_ylim()
    ax.fill_between(  [min_-er, min_+ er], ylim[0], ylim[1], alpha = 0.2, 
                    label = f'1$\sigma$ error = {er:.2} ({lambda_err_N:.2}), A = {a}')
    min_, er = ul_a.likelihood_error() #min_, er, upp = ul.likelihood_upper()
    min_ = min_[0]; er = er[0]
    ax.fill_between(  [min_-er, min_+ er], ylim[0], ylim[1],  alpha = 0.2, 
                    label = f'1$\sigma$ error = {er:.2} ({lambda_err:.2}), A = {a}')

plt.xlabel("Source lambda")
plt.ylabel("-2log (L) [arb. unit]")
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
#plt.ylim(ylim[0], ylim[1]-25)
plt.title(f"Sys = 0% (s = {shift_neg}, t = {tilt_neg})")

fig.savefig("plots/5b_stat_scan_lambda_zero.png")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [18], in <cell line: 2>()
#       1 fig = plt.figure()
#       2 for i, a in enumerate(amplitude_array[1:]):
# ----> 3     with open(f'data/5b_scan_lambda_N_A{a}_zero.yaml') as file:
#       4             stat_profile_N_l = yaml.load( file, Loader=yaml.FullLoader)
#       5     ll_N_a = stat_profile_N_l.copy()
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data/5b_scan_lambda_N_A5e-13_zero.yaml'

# %% [markdown]
# ## Penalty Examples

# %%
ps = [1e-2, 0.05, 0.1]
plot_values = np.linspace(-0.1, 0.1, 100)
for p in ps:
    plt.plot(plot_values, plot_values ** 2 / p ** 2, label = "$\sigma$ = "+ str(p)) 
plt.legend()

plt.ylabel('Penalty on Likelihood')    
plt.xlabel('Eff. Area Parameter')
fig  = plt.gcf()
fig.savefig('plots/5b_gaussian_penalty_example.pdf')

# %% [markdown]
# ### Calculating Delta TS

# %%
# %%time
computing_amplitude = True
for i, a in enumerate(amplitude_array):
    print(a)
    if computing_amplitude:
        sigma = 3
        parameter_a = datasets[i].models.parameters['amplitude']
        parameter_a.scan_values = [0.0]
        stat_profile_a = fit.stat_profile([datasets[i]], parameter_a, reoptimize= True)
        stat_profile_a['scale_scan'] = stat_profile_a.pop(next(iter(stat_profile_a)) )    
        with open(f'data/5b_scan_amplitude_at_zero_A{a}_zero.yaml', 'w') as file:
            documents = yaml.dump(make_writable(stat_profile_a), file)
# Out:
# 1e-13
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# 5e-13
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# 1e-12
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# 5e-12
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# CPU times: total: 14 s
# Wall time: 14 s

# %%
# %%time
computing_amplitude_N = True
for i, a in enumerate(amplitude_array):
    print(a)
    if computing_amplitude_N:
        sigma = 3
        parameter_a = datasets_N[i].models.parameters['amplitude']
        parameter_a.scan_values = [0.0]
        stat_profile_N_a = fit.stat_profile([datasets_N[i]], parameter_a, reoptimize = True)
        stat_profile_N_a['scale_scan'] = stat_profile_N_a.pop(next(iter(stat_profile_N_a)) )    

        with open(f'data/5b_scan_amplitude_at_zero_N_A{a}_zero.yaml', 'w') as file:
            documents = yaml.dump(make_writable(stat_profile_N_a), file)
# Out:
# 1e-13
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# 5e-13
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# 1e-12
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# 5e-12
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in exp
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: overflow encountered in power
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# C:\Users\yt02izug\AppData\Local\miniconda3\envs\gammapy-1.0-irf\lib\site-packages\astropy\units\quantity.py:620: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# CPU times: total: 27min 8s
# Wall time: 7min 31s

# %%
from numpy import savetxt
deltats = []
for i, a in enumerate(amplitude_array):
    with open(f'data/5b_scan_amplitude_at_zero_A{a}_zero.yaml') as file:
                stat_profile_a_0 = yaml.load( file, Loader=yaml.FullLoader)
    with open(f'data/5b_scan_amplitude_A{a}_zero.yaml') as file:
            stat_profile_a = yaml.load( file, Loader=yaml.FullLoader)
    #print(min(stat_profile_a['stat_scan']))
    b = min(stat_profile_a_0['stat_scan']) - min(stat_profile_a['stat_scan'])
    print(a, np.sqrt(b))
    deltats.append(np.sqrt(b))
np.savetxt(f'data/5b_significance_zero.txt', [amplitude_array, deltats])
# Out:
# 1e-13 0.005490355303371301
# 5e-13 6.8763753193863195
# 1e-12 13.347460565976034
# 5e-12 56.86028871396425

# %%
deltats_N = []
for i, a in enumerate(amplitude_array):
    with open(f'data/5b_scan_amplitude_at_zero_N_A{a}_zero.yaml') as file:
                stat_profile_N_a_0 = yaml.load( file, Loader=yaml.FullLoader)
    with open(f'data/5b_scan_amplitude_N_A{a}_zero.yaml') as file:
            stat_profile_N_a = yaml.load( file, Loader=yaml.FullLoader)
    #print(min(stat_profile_a['stat_scan']))
    b = min(stat_profile_N_a_0['stat_scan']) - min(stat_profile_N_a['stat_scan'])
    print(a, np.sqrt(b))
    deltats_N.append(np.sqrt(b))
np.savetxt(f'data/5b_significance_N_A_zero.txt', [amplitude_array, deltats])
# Out:
# 1e-13 1.313306852547975
# 5e-13 6.876506256211292
# 1e-12 13.347119581055628
# 5e-12 56.85908170072068
