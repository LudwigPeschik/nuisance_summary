# %%
import gammapy 
print(f'loaded gammapy version: {gammapy.__version__} ' )
print(f'Supposed to be 1.0 (21-12-2022)' )
# Out:
# loaded gammapy version: 1.0
# Supposed to be 1.0 (21-12-2022)

# %%
#get_ipython().system('jupyter nbconvert --to script 1-Nui_Par_Fitting.ipynb')
import pyximport

pyximport.install()
import matplotlib.pyplot as plt
import numpy as np
import astropy.units as u
import gammapy

# from gammapy.datasets import MapDataset
from gammapy.maps import Map
from astropy.coordinates import SkyCoord, Angle
from gammapy.modeling import Fit, Parameter, Parameters, Covariance
from gammapy.datasets import MapDataset #, MapDatasetNuisance
from gammapy.modeling.models import (
    PowerLawSpectralModel,
    create_crab_spectral_model,
    SkyModel,
    PointSpatialModel,
    ShellSpatialModel,
    GeneralizedGaussianSpatialModel,
    TemplateSpatialModel,
    LogParabolaSpectralModel,
    GaussianSpatialModel,
    DiskSpatialModel,
    PowerLawNormSpectralModel,
    ExpCutoffPowerLawSpectralModel,
    Models,
    SpatialModel,
    FoVBackgroundModel,
)
from gammapy.estimators import TSMapEstimator, ExcessMapEstimator

from regions import CircleSkyRegion, RectangleSkyRegion
import yaml
import sys

from Dataset_Creation import sys_dataset

# %% [markdown]
# ## Read dataset

# %%
source = 'Galactic Centre'
path = 'C:/Users/yt02izug/Downloads'

dataset_standard = MapDataset.read(f'{path}/GC_fullsys/GC_fullsys.fits')
#dataset_standard = dataset_standard.downsample(4)
models = Models.read(f"{path}/nuisance_summary/Eff_area/Galactic Centre/GC_model.yml")


diff = Map.read(f'{path}/diffusetemplate.fits')
new_geom = diff.geom.rename_axes(['energy'], ['energy_true'])
diff_new = Map.from_geom(geom = new_geom, data = diff.data, unit = diff.unit) 
temp = TemplateSpatialModel(diff_new, normalize=False, filename = f'{path}/diffusetemplate.fits')
diff = SkyModel(spatial_model=temp, name = 'diff', spectral_model = PowerLawNormSpectralModel())
models.append(diff)
bkg_model = FoVBackgroundModel(dataset_name=dataset_standard.name)
bkg_model.parameters['tilt'].frozen  = False
models.append(bkg_model)
dataset_standard.models = models

dataset_asimov = dataset_standard.copy()
dataset_asimov.counts = dataset_standard.npred()
#models = Models(source_model.copy())
bkg_model = FoVBackgroundModel(dataset_name=dataset_asimov.name)
bkg_model.parameters['tilt'].frozen  = False
models.append(bkg_model)
dataset_asimov.models = models

    
dataset_standard.counts.sum_over_axes().plot(add_cbar=1)
binsize = dataset_standard.geoms["geom"].width[1] / dataset_standard.geoms["geom"].data_shape[1]
print(
    "spatial binsize = ",
    binsize
)

print(dataset_standard)
# Out:
# Position <SkyCoord (Galactic): (l, b) in deg
#     (355.31064696, 1.44801054)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (355.31064696, 1.44801054)> is outside valid IRF map range, using nearest IRF defined within
# spatial binsize =  [0.08] deg
# MapDataset
# ----------
#
#   Name                            : LcDu2fN2
#
#   Total counts                    : 596011
#   Total background counts         : 533641.19
#   Total excess counts             : 62369.81
#
#   Predicted counts                : 540868.19
#   Predicted background counts     : 533641.14
#   Predicted excess counts         : 7227.05
#
#   Exposure min                    : 5.70e+01 m2 s
#   Exposure max                    : 1.54e+11 m2 s
#
#   Number of total bins            : 540000
#   Number of fit bins              : 100300
#
#   Fit statistic type              : cash
#   Fit statistic value (-2 log(L)) : -2461702.57
#
#   Number of models                : 6
#   Number of parameters            : 31
#   Number of free parameters       : 21
#
#   Component 0: SkyModel
#
#     Name                      : Source
#     Datasets names            : None
#     Spectral model type       : ExpCutoffPowerLawSpectralModel
#     Spatial  model type       : PointSpatialModel
#     Temporal model type       :
#     Parameters:
#       index                         :      2.365   +/-     nan
#       amplitude                     :   8.82e-13   +/-     nan 1 / (cm2 s TeV)
#       reference             (frozen):      1.000       TeV
#       lambda_                       :      0.061   +/-     nan 1 / TeV
#       alpha                 (frozen):      1.000
#       lon_0                         :      0.000   +/-     nan deg
#       lat_0                         :      0.000   +/-     nan deg
#
#   Component 1: SkyModel
#
#     Name                      : g09
#     Datasets names            : None
#     Spectral model type       : PowerLawSpectralModel
#     Spatial  model type       : PointSpatialModel
#     Temporal model type       :
#     Parameters:
#       index                         :      2.297   +/-     nan
#       amplitude                     :   5.94e-13   +/-     nan 1 / (cm2 s TeV)
#       reference             (frozen):      1.000       TeV
#       lon_0                         :      0.887   +/-     nan deg
#       lat_0                         :      0.087   +/-     nan deg
#
#   Component 2: SkyModel
#
#     Name                      : 1745
#     Datasets names            : None
#     Spectral model type       : PowerLawSpectralModel
#     Spatial  model type       : GaussianSpatialModel
#     Temporal model type       :
#     Parameters:
#       index                         :      9.881   +/-     nan
#       amplitude                     :   3.01e-15   +/-     nan 1 / (cm2 s TeV)
#       reference             (frozen):      1.000       TeV
#       lon_0                         :    355.311   +/-     nan deg
#       lat_0                         :      1.448   +/-     nan deg
#       sigma                         :      3.231   +/-     nan deg
#       e                     (frozen):      0.000
#       phi                   (frozen):      0.000       deg
#
#   Component 3: SkyModel
#
#     Name                      : 1746
#     Datasets names            : None
#     Spectral model type       : PowerLawSpectralModel
#     Spatial  model type       : PointSpatialModel
#     Temporal model type       :
#     Parameters:
#       index                         :      3.015   +/-     nan
#       amplitude                     :   2.52e-13   +/-     nan 1 / (cm2 s TeV)
#       reference             (frozen):      1.000       TeV
#       lon_0                         :      0.615   +/-     nan deg
#       lat_0                         :      0.117   +/-     nan deg
#
#   Component 4: SkyModel
#
#     Name                      : diff
#     Datasets names            : None
#     Spectral model type       : PowerLawNormSpectralModel
#     Spatial  model type       : TemplateSpatialModel
#     Temporal model type       :
#     Parameters:
#       norm                          :      1.000   +/-    0.00
#       tilt                  (frozen):      0.000
#       reference             (frozen):      1.000       TeV
#
#   Component 5: FoVBackgroundModel
#
#     Name                      : LcDu2fN2-bkg
#     Datasets names            : ['LcDu2fN2']
#     Spectral model type       : PowerLawNormSpectralModel
#     Parameters:
#       norm                          :      1.000   +/-    0.00
#       tilt                          :      0.000   +/-    0.00
#       reference             (frozen):      1.000       TeV

# %%
estimator = TSMapEstimator(
    dataset_standard.models[0],
    kernel_width="1 deg",
    energy_edges=[0.7, 3] * u.TeV#dataset_standard.counts.geom.axes['energy'].edges[7:17]#energy_edges=[10, 500] * u.GeV#
)
maps = estimator.run(dataset_standard)
# Out:
# Position <SkyCoord (Galactic): (l, b) in deg
#     (355.31064696, 1.44801054)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (355.31064696, 1.44801054)> is outside valid IRF map range, using nearest IRF defined within

# %%
fig, (ax1, ax2, ax3) = plt.subplots(
    ncols=3,
    figsize=(15, 3),
    subplot_kw={"projection": dataset_standard.counts.geom.wcs},
    gridspec_kw={"left": 0.1, "right": 0.98},
)

maps["sqrt_ts"].plot(ax = ax1, add_cbar=True)
ax1.set_title("Significance map")
maps["flux"].plot(ax=ax2, add_cbar=True, stretch="sqrt", vmin=0)
ax2.set_title("Flux map")
maps["niter"].plot(ax=ax3, add_cbar=True)
ax3.set_title("Iteration map")
# Out:
# Text(0.5, 1.0, 'Iteration map')

# %%
from gammapy.estimators.utils import find_peaks
sources = find_peaks(maps["sqrt_ts"], threshold=5, min_distance="0.25 deg")#threshold=5
nsou = len(sources)
display(sources)

# Plot sources on top of significance sky image
plt.figure(figsize=(9, 5))
ax = maps["sqrt_ts"].plot(add_cbar=True)

ax.scatter(
    sources["ra"],
    sources["dec"],
    transform=plt.gca().get_transform("icrs"),
    color="none",
    edgecolor="w",
    marker="o",
    s=600,
    lw=1.5,
)
plt.show()
# Out:
# <Table length=4>
#  value    x     y       ra       dec
#                        deg       deg
# float64 int64 int64  float64   float64
# ------- ----- ----- --------- ---------
#   41.27    75    74 266.42019 -28.99116
#  8.8141    90    68 266.17092 -30.26529
#  8.2897    64    75 266.86284 -28.19759
#  6.1854    68    74 266.75217 -28.51273

# %%
fig, ax = plt.subplots()
colors = plt.rcParams['axes.prop_cycle'].by_key()['color']

dataset_standard.plot_residuals_spectral(ax =ax, color= "tab:red")
ax.legend()
#fig.savefig(f"plots/1b_Residual_standard.pdf")
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
j1745_coord = SkyCoord(358.6435538, -0.5617789, unit='deg',frame='galactic')
skyregion_1745 = RectangleSkyRegion(center=j1745_coord, width=1*u.deg,height=1*u.deg)#, angle = 108*u.deg)
geom = dataset_standard.counts.geom
mask_space = ~geom.region_mask([skyregion_1745])
dataset_standard.mask_fit = mask_space
dataset_standard.mask_fit.plot_grid(vmin=0, vmax=1, add_cbar=True)
# Out:
# array([[<WCSAxesSubplot: title={'center': 'Energy 100 GeV - 133 GeV'}>,
#         <WCSAxesSubplot: title={'center': 'Energy 133 GeV - 178 GeV'}>,
#         <WCSAxesSubplot: title={'center': 'Energy 178 GeV - 237 GeV'}>],
#        [<WCSAxesSubplot: title={'center': 'Energy 237 GeV - 316 GeV'}>,
#         <WCSAxesSubplot: title={'center': 'Energy 316 GeV - 422 GeV'}>,
#         <WCSAxesSubplot: title={'center': 'Energy 422 GeV - 562 GeV'}>],
#        [<WCSAxesSubplot: title={'center': 'Energy 562 GeV - 750 GeV'}>,
#         <WCSAxesSubplot: title={'center': 'Energy 750 GeV - 1.00 TeV'}>,
#         <WCSAxesSubplot: title={'center': 'Energy 1.00 TeV - 1.33 TeV'}>],
#        [<WCSAxesSubplot: title={'center': 'Energy 1.33 TeV - 1.78 TeV'}>,
#         <WCSAxesSubplot: title={'center': 'Energy 1.78 TeV - 2.37 TeV'}>,
#         <WCSAxesSubplot: title={'center': 'Energy 2.37 TeV - 3.16 TeV'}>],
#        [<WCSAxesSubplot: title={'center': 'Energy 3.16 TeV - 4.22 TeV'}>,
#         <WCSAxesSubplot: title={'center': 'Energy 4.22 TeV - 5.62 TeV'}>,
#         <WCSAxesSubplot: title={'center': 'Energy 5.62 TeV - 7.50 TeV'}>],
#        [<WCSAxesSubplot: title={'center': 'Energy 7.50 TeV - 10.0 TeV'}>,
#         <WCSAxesSubplot: title={'center': 'Energy 10.0 TeV - 13.3 TeV'}>,
#         <WCSAxesSubplot: title={'center': 'Energy 13.3 TeV - 17.8 TeV'}>],
#        [<WCSAxesSubplot: title={'center': 'Energy 17.8 TeV - 23.7 TeV'}>,
#         <WCSAxesSubplot: title={'center': 'Energy 23.7 TeV - 31.6 TeV'}>,
#         <WCSAxesSubplot: title={'center': 'Energy 31.6 TeV - 42.2 TeV'}>],
#        [<WCSAxesSubplot: title={'center': 'Energy 42.2 TeV - 56.2 TeV'}>,
#         <WCSAxesSubplot: title={'center': 'Energy 56.2 TeV - 75.0 TeV'}>,
#         <WCSAxesSubplot: title={'center': 'Energy 75.0 TeV - 100 TeV'}>]],
#       dtype=object)

# %%
# %%time
fit_standard = Fit(store_trace=False)
result_standard = fit_standard.run([dataset_standard])
# Out:
# Position <SkyCoord (Galactic): (l, b) in deg
#     (69.26830676, 1.44801054)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (69.26830676, 1.44801054)> is outside valid IRF map range, using nearest IRF defined within
# CPU times: total: 44.6 s
# Wall time: 44.6 s

# %%
print(dataset_standard)
# Out:
# MapDataset
# ----------
#
#   Name                            : LcDu2fN2
#
#   Total counts                    : 596011
#   Total background counts         : 533641.19
#   Total excess counts             : 62369.81
#
#   Predicted counts                : 591518.45
#   Predicted background counts     : 574764.84
#   Predicted excess counts         : 16753.61
#
#   Exposure min                    : 5.70e+01 m2 s
#   Exposure max                    : 1.54e+11 m2 s
#
#   Number of total bins            : 540000
#   Number of fit bins              : 97420
#
#   Fit statistic type              : cash
#   Fit statistic value (-2 log(L)) : -2303819.30
#
#   Number of models                : 6
#   Number of parameters            : 31
#   Number of free parameters       : 21
#
#   Component 0: SkyModel
#
#     Name                      : Source
#     Datasets names            : None
#     Spectral model type       : ExpCutoffPowerLawSpectralModel
#     Spatial  model type       : PointSpatialModel
#     Temporal model type       :
#     Parameters:
#       index                         :      2.051   +/-    0.04
#       amplitude                     :   2.77e-12   +/- 8.5e-14 1 / (cm2 s TeV)
#       reference             (frozen):      1.000       TeV
#       lambda_                       :      0.089   +/-    0.02 1 / TeV
#       alpha                 (frozen):      1.000
#       lon_0                         :     -0.057   +/-    0.00 deg
#       lat_0                         :     -0.049   +/-    0.00 deg
#
#   Component 1: SkyModel
#
#     Name                      : g09
#     Datasets names            : None
#     Spectral model type       : PowerLawSpectralModel
#     Spatial  model type       : PointSpatialModel
#     Temporal model type       :
#     Parameters:
#       index                         :      2.407   +/-    0.06
#       amplitude                     :   6.38e-13   +/- 4.0e-14 1 / (cm2 s TeV)
#       reference             (frozen):      1.000       TeV
#       lon_0                         :      0.869   +/-    0.00 deg
#       lat_0                         :      0.074   +/-    0.00 deg
#
#   Component 2: SkyModel
#
#     Name                      : 1745
#     Datasets names            : None
#     Spectral model type       : PowerLawSpectralModel
#     Spatial  model type       : GaussianSpatialModel
#     Temporal model type       :
#     Parameters:
#       index                         :      9.881   +/-    1.41
#       amplitude                     :   3.01e-15   +/- 1.4e-15 1 / (cm2 s TeV)
#       reference             (frozen):      1.000       TeV
#       lon_0                         :    355.311   +/-  141.42 deg
#       lat_0                         :      1.448   +/-  127.26 deg
#       sigma                         :      3.231   +/-    1.37 deg
#       e                     (frozen):      0.000
#       phi                   (frozen):      0.000       deg
#
#   Component 3: SkyModel
#
#     Name                      : 1746
#     Datasets names            : None
#     Spectral model type       : PowerLawSpectralModel
#     Spatial  model type       : PointSpatialModel
#     Temporal model type       :
#     Parameters:
#       index                         :      3.435   +/-    0.52
#       amplitude                     :   6.30e-14   +/- 2.9e-14 1 / (cm2 s TeV)
#       reference             (frozen):      1.000       TeV
#       lon_0                         :      0.607   +/-    0.03 deg
#       lat_0                         :      0.001   +/-    0.03 deg
#
#   Component 4: SkyModel
#
#     Name                      : diff
#     Datasets names            : None
#     Spectral model type       : PowerLawNormSpectralModel
#     Spatial  model type       : TemplateSpatialModel
#     Temporal model type       :
#     Parameters:
#       norm                          :      2.703   +/-    0.08
#       tilt                  (frozen):      0.000
#       reference             (frozen):      1.000       TeV
#
#   Component 5: FoVBackgroundModel
#
#     Name                      : LcDu2fN2-bkg
#     Datasets names            : ['LcDu2fN2']
#     Spectral model type       : PowerLawNormSpectralModel
#     Parameters:
#       norm                          :      1.057   +/-    0.00
#       tilt                          :      0.074   +/-    0.00
#       reference             (frozen):      1.000       TeV

# %%
fig, ax = plt.subplots()
colors = plt.rcParams['axes.prop_cycle'].by_key()['color']

dataset_standard.plot_residuals_spectral(ax =ax, color= "tab:red")
ax.legend()
#fig.savefig(f"plots/1b_Residual_standard.pdf")
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
print(dataset_standard.models[0])
# Out:
# SkyModel
#
#   Name                      : Source
#   Datasets names            : None
#   Spectral model type       : ExpCutoffPowerLawSpectralModel
#   Spatial  model type       : PointSpatialModel
#   Temporal model type       :
#   Parameters:
#     index                         :      2.051   +/-    0.04
#     amplitude                     :   2.77e-12   +/- 8.5e-14 1 / (cm2 s TeV)
#     reference             (frozen):      1.000       TeV
#     lambda_                       :      0.089   +/-    0.02 1 / TeV
#     alpha                 (frozen):      1.000
#     lon_0                         :     -0.057   +/-    0.00 deg
#     lat_0                         :     -0.049   +/-    0.00 deg

# %%
estimator = TSMapEstimator(
    dataset_standard.models[0],
    kernel_width="1 deg",
    energy_edges=[0.7, 3] * u.TeV#energy_edges=dataset_standard.counts.geom.axes['energy'].edges[10:14]
)
maps = estimator.run(dataset_standard)
# Out:
# Position <SkyCoord (Galactic): (l, b) in deg
#     (355.31064696, 1.44801054)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (355.31064696, 1.44801054)> is outside valid IRF map range, using nearest IRF defined within

# %%
fig, (ax1, ax2, ax3) = plt.subplots(
    ncols=3,
    figsize=(15, 3),
    subplot_kw={"projection": dataset_standard.counts.geom.wcs},
    gridspec_kw={"left": 0.1, "right": 0.98},
)

maps["sqrt_ts"].plot(ax=ax1, add_cbar=True)
ax1.set_title("Significance map")
maps["flux"].plot(ax=ax2, add_cbar=True, stretch="sqrt", vmin=0)
ax2.set_title("Flux map")
maps["niter"].plot(ax=ax3, add_cbar=True)
ax3.set_title("Iteration map")
# Out:
# Text(0.5, 1.0, 'Iteration map')

# %%
sources = find_peaks(maps["sqrt_ts"], threshold=5, min_distance="0.25 deg")
nsou = len(sources)
display(sources)

# Plot sources on top of significance sky image
plt.figure(figsize=(9, 5))
ax = maps["sqrt_ts"].plot(add_cbar=True)

ax.scatter(
    sources["ra"],
    sources["dec"],
    transform=plt.gca().get_transform("icrs"),
    color="none",
    edgecolor="w",
    marker="o",
    s=600,
    lw=1.5,
)
plt.show()
# Out:
# <Table length=2>
#  value    x     y       ra       dec
#                        deg       deg
# float64 int64 int64  float64   float64
# ------- ----- ----- --------- ---------
#   5.934    73    73 266.59339 -28.89615
#  5.1892    92    59 266.78804 -30.77654

# %%
estimator = ExcessMapEstimator(
    correlation_radius=f"0.5 deg",
    energy_edges=dataset_standard.counts.geom.axes['energy'].edges[10:14])
result = estimator.run(dataset_standard)
result["sqrt_ts"].plot_grid(cmap="coolwarm", add_cbar=True, vmin=-5, vmax=5,);

# %%
model2 = Models(dataset_standard.models)
model2.remove('diff')

# %%
print(model2)
# Out:
# Models
#
# Component 0: SkyModel
#
#   Name                      : Source
#   Datasets names            : None
#   Spectral model type       : ExpCutoffPowerLawSpectralModel
#   Spatial  model type       : PointSpatialModel
#   Temporal model type       :
#   Parameters:
#     index                         :      2.051   +/-    0.04
#     amplitude                     :   2.77e-12   +/- 8.5e-14 1 / (cm2 s TeV)
#     reference             (frozen):      1.000       TeV
#     lambda_                       :      0.089   +/-    0.02 1 / TeV
#     alpha                 (frozen):      1.000
#     lon_0                         :     -0.057   +/-    0.00 deg
#     lat_0                         :     -0.049   +/-    0.00 deg
#
# Component 1: SkyModel
#
#   Name                      : g09
#   Datasets names            : None
#   Spectral model type       : PowerLawSpectralModel
#   Spatial  model type       : PointSpatialModel
#   Temporal model type       :
#   Parameters:
#     index                         :      2.407   +/-    0.06
#     amplitude                     :   6.38e-13   +/- 4.0e-14 1 / (cm2 s TeV)
#     reference             (frozen):      1.000       TeV
#     lon_0                         :      0.869   +/-    0.00 deg
#     lat_0                         :      0.074   +/-    0.00 deg
#
# Component 2: SkyModel
#
#   Name                      : 1745
#   Datasets names            : None
#   Spectral model type       : PowerLawSpectralModel
#   Spatial  model type       : GaussianSpatialModel
#   Temporal model type       :
#   Parameters:
#     index                         :      9.881   +/-    1.41
#     amplitude                     :   3.01e-15   +/- 1.4e-15 1 / (cm2 s TeV)
#     reference             (frozen):      1.000       TeV
#     lon_0                         :    355.311   +/-  141.42 deg
#     lat_0                         :      1.448   +/-  127.26 deg
#     sigma                         :      3.231   +/-    1.37 deg
#     e                     (frozen):      0.000
#     phi                   (frozen):      0.000       deg
#
# Component 3: SkyModel
#
#   Name                      : 1746
#   Datasets names            : None
#   Spectral model type       : PowerLawSpectralModel
#   Spatial  model type       : PointSpatialModel
#   Temporal model type       :
#   Parameters:
#     index                         :      3.435   +/-    0.52
#     amplitude                     :   6.30e-14   +/- 2.9e-14 1 / (cm2 s TeV)
#     reference             (frozen):      1.000       TeV
#     lon_0                         :      0.607   +/-    0.03 deg
#     lat_0                         :      0.001   +/-    0.03 deg
#
# Component 4: FoVBackgroundModel
#
#   Name                      : LcDu2fN2-bkg
#   Datasets names            : ['LcDu2fN2']
#   Spectral model type       : PowerLawNormSpectralModel
#   Parameters:
#     norm                          :      1.057   +/-    0.00
#     tilt                          :      0.074   +/-    0.00
#     reference             (frozen):      1.000       TeV

# %%
model2.write("data/1_model_standard_best_fit_mask.yml", overwrite= True)
