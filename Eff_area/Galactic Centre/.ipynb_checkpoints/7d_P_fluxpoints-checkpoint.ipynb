# %%
import gammapy 
print(f'loaded gammapy version: {gammapy.__version__} ' )
print(f'Supposed to be 1.0 (21-12-2022)' )
# Out:
# loaded gammapy version: 1.0
# Supposed to be 1.0 (21-12-2022)

# %%
#get_ipython().system('jupyter nbconvert --to script 1-Nui_Par_Fitting.ipynb')
import pyximport

pyximport.install()
import matplotlib.pyplot as plt
import numpy as np
import astropy.units as u
import gammapy

# from gammapy.datasets import MapDataset
from gammapy.maps import Map
from astropy.coordinates import SkyCoord, Angle
from gammapy.modeling import Fit, Parameter, Parameters, Covariance
from gammapy.datasets import MapDataset , Datasets#, MapDatasetNuisance
from gammapy.modeling.models import (
    PowerLawSpectralModel,
    create_crab_spectral_model,
    SkyModel,
    PointSpatialModel,
    ShellSpatialModel,
    GeneralizedGaussianSpatialModel,
    TemplateSpatialModel,
    LogParabolaSpectralModel,
    GaussianSpatialModel,
    DiskSpatialModel,
    PowerLawNormSpectralModel,
    Models,
    SpatialModel,
    FoVBackgroundModel,
    ExpCutoffPowerLawSpectralModel
)
from gammapy.estimators import TSMapEstimator, ExcessMapEstimator
from gammapy.estimators import FluxPoints
from gammapy.estimators import FluxPointsEstimator

from regions import CircleSkyRegion, RectangleSkyRegion
import yaml
import sys

#sys.path.append(
#    "/home/hpc/caph/mppi045h/3D_analysis/N_parameters_in_L/syserror_3d_bkgmodel/4-Fitting_nuisance_and_model_parameters"
#)
#from my_dataset_maps_20 import MapDatasetNuisance
#from MapDatasetNuisanceE import MapDatasetNuisanceE
#from  my_fit_20 import Fit
from Dataset_Creation import sys_dataset

# %% [markdown]
# ## Read dataset

# %%
source = 'Galactic Centre'
path = 'C:/Users/yt02izug/Downloads'

dataset_standard = MapDataset.read(f'{path}/GC_fullsys/GC_fullsys.fits')
#dataset_standard = dataset_standard.downsample(4)
#models = Models.read(f"{path}/nuisance_summary/Eff_area/Galactic Centre/GC_model.yml")
models = Models.read(f"{path}/nuisance_summary/Eff_area/Galactic Centre/data/1_model_standard_best_fit_mask.yml")

diff = Map.read(f'{path}/diffusetemplate.fits')
new_geom = diff.geom.rename_axes(['energy'], ['energy_true'])
diff_new = Map.from_geom(geom = new_geom, data = diff.data, unit = diff.unit) 
temp = TemplateSpatialModel(diff_new, normalize=False, filename = f'{path}/diffusetemplate.fits')
diff = SkyModel(spatial_model=temp, name = 'diff', spectral_model = PowerLawNormSpectralModel())
models.append(diff)
bkg_model = FoVBackgroundModel(dataset_name=dataset_standard.name)
bkg_model.parameters['tilt'].frozen  = False
models.append(bkg_model)
dataset_standard.models = models

dataset_standard.models[0].parameters['lon_0'].frozen = True
dataset_standard.models[0].parameters['lat_0'].frozen = True
dataset_standard.models[1].parameters['lon_0'].frozen = True
dataset_standard.models[1].parameters['lat_0'].frozen = True
#dataset_standard.models[2].parameters['lon_0'].frozen = True
#dataset_standard.models[2].parameters['lat_0'].frozen = True

#create asimov dataset
dataset_asimov = dataset_standard.copy()
dataset_asimov.counts = dataset_standard.npred()
models = Models(dataset_standard.models.copy())
bkg_model = FoVBackgroundModel(dataset_name=dataset_asimov.name)
bkg_model.parameters['tilt'].frozen  = False
models.append(bkg_model)
dataset_asimov.models = models


#Input Model for Comparison
dataset_input = dataset_standard.copy()
models_input = Models.read(f"{path}/nuisance_summary/Eff_area/Galactic Centre/GC_model.yml")
diff = Map.read(f'{path}/diffusetemplate.fits')
new_geom = diff.geom.rename_axes(['energy'], ['energy_true'])
diff_new = Map.from_geom(geom = new_geom, data = diff.data, unit = diff.unit) 
temp = TemplateSpatialModel(diff_new, normalize=False, filename = f'{path}/diffusetemplate.fits')
diff = SkyModel(spatial_model=temp, name = 'diff', spectral_model = PowerLawNormSpectralModel())
models_input.append(diff)
bkg_model = FoVBackgroundModel(dataset_name=dataset_input.name)
bkg_model.parameters['tilt'].frozen  = False
models_input.append(bkg_model)
dataset_input.models = models

#set mask to exclude J1745
j1745_coord = SkyCoord(358.6435538, -0.5617789, unit='deg',frame='galactic')
skyregion_1745 = RectangleSkyRegion(center=j1745_coord, width=1*u.deg,height=1*u.deg)#, angle = 108*u.deg)
geom = dataset_standard.counts.geom
mask_space = ~geom.region_mask([skyregion_1745])
dataset_standard.mask_fit = mask_space
dataset_asimov.mask_fit = mask_space

    
dataset_standard.counts.sum_over_axes().plot(add_cbar=1)
binsize = dataset_standard.geoms["geom"].width[1] / dataset_standard.geoms["geom"].data_shape[1]
print(
    "spatial binsize = ",
    binsize
)

print(dataset_standard)
# Out:
# spatial binsize =  [0.08] deg
# MapDataset
# ----------
#
#   Name                            : 1MUXqVCD
#
#   Total counts                    : 361088
#   Total background counts         : 360331.31
#   Total excess counts             : 756.96
#
#   Predicted counts                : 361088.27
#   Predicted background counts     : 360331.34
#   Predicted excess counts         : 756.93
#
#   Exposure min                    : 2.07e-01 m2 s
#   Exposure max                    : 2.41e+11 m2 s
#
#   Number of total bins            : 540000
#   Number of fit bins              : 180191
#
#   Fit statistic type              : cash
#   Fit statistic value (-2 log(L)) : -752490.77
#
#   Number of models                : 2
#   Number of parameters            : 13
#   Number of free parameters       : 8
#
#   Component 0: SkyModel
#
#     Name                      : Source
#     Datasets names            : None
#     Spectral model type       : ExpCutoffPowerLawSpectralModel
#     Spatial  model type       : GaussianSpatialModel
#     Temporal model type       :
#     Parameters:
#       index                         :      2.300   +/-    0.00
#       amplitude                     :   1.00e-12   +/- 0.0e+00 1 / (cm2 s TeV)
#       reference             (frozen):      1.000       TeV
#       lambda_                       :      0.100   +/-    0.00 1 / TeV
#       alpha                 (frozen):      1.000
#       lon_0                         :     83.631   +/-    0.00 deg
#       lat_0                         :     22.018   +/-    0.00 deg
#       sigma                         :      0.020   +/-    0.00 deg
#       e                     (frozen):      0.000
#       phi                   (frozen):      0.000       deg
#
#   Component 1: FoVBackgroundModel
#
#     Name                      : 1MUXqVCD-bkg
#     Datasets names            : ['1MUXqVCD']
#     Spectral model type       : PowerLawNormSpectralModel
#     Parameters:
#       norm                          :      1.000   +/-    0.00
#       tilt                          :      0.000   +/-    0.00
#       reference             (frozen):      1.000       TeV

# %% [markdown]
# ## Varying the Exposure

# %%
savefig = False
picformat = 'svg'
shift = 0.10 #0.085
tilt = 0.015

# %%
infos = np.loadtxt("data/7a_P_draw_info.txt")
pars = np.loadtxt("data/7a_P_draw_par.txt")
flux = np.loadtxt("data/7a_P_draw_flux.txt")
flux2e = np.loadtxt("data/7a_P_draw_flux2e.txt")


lem = len(infos)
N_max = 1000
N = np.min([lem, N_max])

print(N)

shift_rnds = infos[:N_max,0]
index_rnds = infos[:N_max,1]
stat_sums = infos[:N_max,2]


#amplitude', 'index', 'norm', 'tilt
amplitudes = pars[:N_max,0:2] 
indices = pars[:N_max,2:4] 
norms = pars[:N_max,4:6]
tilts = pars[:N_max,6:8]


fluxpoints = []
for f in shift_rnds:
    try:
        print(f'6_fluxpoints_{f:.6}')
        ff = FluxPoints.read(f'data/fluxpoints/6_fluxpoints_{f:.6}.fits') 
        fluxpoints.append(ff)
        
    except:
        pass
print(len(fluxpoints), len(shift_rnds))    
N = len(fluxpoints)
# Out:
# 808
# 6_fluxpoints_-0.141339
# 6_fluxpoints_-0.0475278
# 6_fluxpoints_0.117523
# 6_fluxpoints_-0.118048
# 6_fluxpoints_-0.0678559
# 6_fluxpoints_-0.0975679
# 6_fluxpoints_0.0549958
# 6_fluxpoints_0.00217773
# 6_fluxpoints_-0.113572
# 6_fluxpoints_0.0321862
# 6_fluxpoints_0.0965403
# 6_fluxpoints_-0.11956
# 6_fluxpoints_0.0886933
# 6_fluxpoints_0.0765476
# 6_fluxpoints_-0.0557637
# 6_fluxpoints_0.014891
# 6_fluxpoints_0.116272
# 6_fluxpoints_-0.0187219
# 6_fluxpoints_-0.059544
# 6_fluxpoints_-0.140573
# 6_fluxpoints_-0.0471873
# 6_fluxpoints_-0.144945
# 6_fluxpoints_-0.0268016
# 6_fluxpoints_-0.127437
# 6_fluxpoints_-0.121592
# 6_fluxpoints_0.0698907
# 6_fluxpoints_0.0881797
# 6_fluxpoints_0.182111
# 6_fluxpoints_-0.135265
# 6_fluxpoints_0.14797
# 6_fluxpoints_-0.0672787
# 6_fluxpoints_-0.103665
# 6_fluxpoints_0.040416
# 6_fluxpoints_-0.129986
# 6_fluxpoints_-0.0675315
# 6_fluxpoints_0.0394657
# 6_fluxpoints_-0.132002
# 6_fluxpoints_0.0726791
# 6_fluxpoints_0.0116396
# 6_fluxpoints_0.0699411
# 6_fluxpoints_-0.134403
# 6_fluxpoints_0.0826672
# 6_fluxpoints_0.0576981
# 6_fluxpoints_-0.112165
# 6_fluxpoints_0.0372136
# 6_fluxpoints_-0.0143947
# 6_fluxpoints_-0.0760034
# 6_fluxpoints_-0.0344008
# 6_fluxpoints_-0.136351
# 6_fluxpoints_0.00222954
# 6_fluxpoints_-0.118037
# 6_fluxpoints_-0.0718961
# 6_fluxpoints_-0.0620951
# 6_fluxpoints_-0.103926
# 6_fluxpoints_-0.104737
# 6_fluxpoints_-0.0848607
# 6_fluxpoints_0.133186
# 6_fluxpoints_0.0073643
# 6_fluxpoints_-0.1061
# 6_fluxpoints_-0.111221
# 6_fluxpoints_0.00344094
# 6_fluxpoints_-0.115959
# 6_fluxpoints_-0.0544441
# 6_fluxpoints_-0.0025308
# 6_fluxpoints_-0.0180531
# 6_fluxpoints_0.110487
# 6_fluxpoints_0.0878439
# 6_fluxpoints_-0.0303983
# 6_fluxpoints_0.019797
# 6_fluxpoints_0.015735
# 6_fluxpoints_-0.103418
# 6_fluxpoints_0.102968
# 6_fluxpoints_0.115271
# 6_fluxpoints_-0.00710865
# 6_fluxpoints_-0.0102434
# 6_fluxpoints_-0.0590313
# 6_fluxpoints_0.194457
# 6_fluxpoints_0.0706952
# 6_fluxpoints_-0.117333
# 6_fluxpoints_-0.000327759
# 6_fluxpoints_0.0280354
# 6_fluxpoints_0.0275842
# 6_fluxpoints_-0.00682228
# 6_fluxpoints_-0.0371601
# 6_fluxpoints_-0.0123091
# 6_fluxpoints_0.0756107
# 6_fluxpoints_-0.0138343
# 6_fluxpoints_-0.12137
# 6_fluxpoints_-0.0581398
# 6_fluxpoints_-0.00965462
# 6_fluxpoints_-0.0459833
# 6_fluxpoints_0.0399067
# 6_fluxpoints_0.0197895
# 6_fluxpoints_0.101121
# 6_fluxpoints_-0.0263686
# 6_fluxpoints_0.0185743
# 6_fluxpoints_-0.0833873
# 6_fluxpoints_-0.0511438
# 6_fluxpoints_0.135779
# 6_fluxpoints_-0.0801735
# 6_fluxpoints_0.0604145
# 6_fluxpoints_-0.0797626
# 6_fluxpoints_0.0247306
# 6_fluxpoints_0.0246241
# 6_fluxpoints_-0.121934
# 6_fluxpoints_0.128362
# 6_fluxpoints_-0.105943
# 6_fluxpoints_0.0735992
# 6_fluxpoints_-0.0158913
# 6_fluxpoints_-0.189535
# 6_fluxpoints_-0.168678
# 6_fluxpoints_0.128439
# 6_fluxpoints_0.0261731
# 6_fluxpoints_-0.0473388
# 6_fluxpoints_-0.0365592
# 6_fluxpoints_-0.0817324
# 6_fluxpoints_-0.162394
# 6_fluxpoints_0.121989
# 6_fluxpoints_0.0515611
# 6_fluxpoints_0.0311079
# 6_fluxpoints_-0.0368002
# 6_fluxpoints_-0.0328507
# 6_fluxpoints_-0.0435994
# 6_fluxpoints_-0.00617152
# 6_fluxpoints_0.0974953
# 6_fluxpoints_0.140761
# 6_fluxpoints_0.0705555
# 6_fluxpoints_-0.0621449
# 6_fluxpoints_-0.0142706
# 6_fluxpoints_-0.0896992
# 6_fluxpoints_-0.0642238
# 6_fluxpoints_0.0124355
# 6_fluxpoints_0.0596299
# 6_fluxpoints_-0.0199689
# 6_fluxpoints_-0.0946046
# 6_fluxpoints_-0.072322
# 6_fluxpoints_-0.0762911
# 6_fluxpoints_-0.149308
# 6_fluxpoints_0.0533451
# 6_fluxpoints_0.0386412
# 6_fluxpoints_0.144524
# 6_fluxpoints_0.00336313
# 6_fluxpoints_0.108329
# 6_fluxpoints_0.0516747
# 6_fluxpoints_-0.0954941
# 6_fluxpoints_0.0889249
# 6_fluxpoints_0.0212351
# 6_fluxpoints_-0.132822
# 6_fluxpoints_-0.025124
# 6_fluxpoints_-0.186212
# 6_fluxpoints_-0.190064
# 6_fluxpoints_-0.0976742
# 6_fluxpoints_-0.026244
# 6_fluxpoints_-0.0472819
# 6_fluxpoints_0.00161518
# 6_fluxpoints_-0.134625
# 6_fluxpoints_0.0827551
# 6_fluxpoints_0.171661
# 6_fluxpoints_-0.0370269
# 6_fluxpoints_0.0142582
# 6_fluxpoints_-0.14774
# 6_fluxpoints_0.0252712
# 6_fluxpoints_0.0106488
# 6_fluxpoints_-0.0532039
# 6_fluxpoints_-0.0673034
# 6_fluxpoints_-0.0221622
# 6_fluxpoints_-0.0671558
# 6_fluxpoints_0.00911906
# 6_fluxpoints_-0.00414001
# 6_fluxpoints_-0.0931723
# 6_fluxpoints_0.0816712
# 6_fluxpoints_-0.0753514
# 6_fluxpoints_-0.119364
# 6_fluxpoints_-0.0205834
# 6_fluxpoints_-0.14392
# 6_fluxpoints_-0.0208792
# 6_fluxpoints_0.140314
# 6_fluxpoints_-0.0478969
# 6_fluxpoints_-0.0110489
# 6_fluxpoints_-0.00360459
# 6_fluxpoints_-0.0766045
# 6_fluxpoints_-0.0500153
# 6_fluxpoints_0.0205578
# 6_fluxpoints_-0.0118709
# 6_fluxpoints_-0.0636695
# 6_fluxpoints_-0.0272026
# 6_fluxpoints_-0.076593
# 6_fluxpoints_-0.113696
# 6_fluxpoints_0.0218217
# 6_fluxpoints_-0.0271613
# 6_fluxpoints_0.0327267
# 6_fluxpoints_0.107783
# 6_fluxpoints_-0.0846928
# 6_fluxpoints_0.0794487
# 6_fluxpoints_-0.0731885
# 6_fluxpoints_-0.10966
# 6_fluxpoints_0.139159
# 6_fluxpoints_0.0627371
# 6_fluxpoints_0.0793244
# 6_fluxpoints_0.0648135
# 6_fluxpoints_0.0188859
# 6_fluxpoints_0.0278717
# 6_fluxpoints_-0.139277
# 6_fluxpoints_0.0295198
# 6_fluxpoints_0.0161027
# 6_fluxpoints_-0.0234362
# 6_fluxpoints_0.0162284
# 6_fluxpoints_0.0158397
# 6_fluxpoints_-0.0659028
# 6_fluxpoints_-0.0815302
# 6_fluxpoints_-0.0337201
# 6_fluxpoints_-0.0974175
# 6_fluxpoints_0.189385
# 6_fluxpoints_0.0171536
# 6_fluxpoints_0.0603757
# 6_fluxpoints_0.197564
# 6_fluxpoints_0.156377
# 6_fluxpoints_-0.0338197
# 6_fluxpoints_-0.0713987
# 6_fluxpoints_-0.0599459
# 6_fluxpoints_0.104715
# 6_fluxpoints_-0.083292
# 6_fluxpoints_0.0712713
# 6_fluxpoints_0.115743
# 6_fluxpoints_0.024767
# 6_fluxpoints_0.10657
# 6_fluxpoints_0.0167716
# 6_fluxpoints_-0.0206775
# 6_fluxpoints_0.0726778
# 6_fluxpoints_0.0306363
# 6_fluxpoints_-0.0649011
# 6_fluxpoints_0.0877103
# 6_fluxpoints_-0.110998
# 6_fluxpoints_0.0356465
# 6_fluxpoints_0.0403627
# 6_fluxpoints_0.0850831
# 6_fluxpoints_-0.0172935
# 6_fluxpoints_-0.0715044
# 6_fluxpoints_-0.0597036
# 6_fluxpoints_0.0009406
# 6_fluxpoints_0.04408
# 6_fluxpoints_0.0628866
# 6_fluxpoints_-0.0201738
# 6_fluxpoints_-0.0383883
# 6_fluxpoints_-0.0161618
# 6_fluxpoints_-0.104007
# 6_fluxpoints_0.0411428
# 6_fluxpoints_0.038808
# 6_fluxpoints_0.0151614
# 6_fluxpoints_0.0278508
# 6_fluxpoints_-0.163692
# 6_fluxpoints_-0.0612123
# 6_fluxpoints_0.0566708
# 6_fluxpoints_-0.0875752
# 6_fluxpoints_0.0752725
# 6_fluxpoints_-0.0272434
# 6_fluxpoints_-0.143028
# 6_fluxpoints_0.0767193
# 6_fluxpoints_-0.0334857
# 6_fluxpoints_0.0343701
# 6_fluxpoints_-0.0777749
# 6_fluxpoints_0.0337842
# 6_fluxpoints_-0.0436931
# 6_fluxpoints_-0.00105125
# 6_fluxpoints_-0.199537
# 6_fluxpoints_0.0331319
# 6_fluxpoints_0.00892959
# 6_fluxpoints_0.102121
# 6_fluxpoints_0.0358888
# 6_fluxpoints_0.117824
# 6_fluxpoints_0.0388418
# 6_fluxpoints_0.19525
# 6_fluxpoints_0.126906
# 6_fluxpoints_0.0172241
# 6_fluxpoints_-0.0317391
# 6_fluxpoints_0.0185935
# 6_fluxpoints_0.217928
# 6_fluxpoints_0.0115721
# 6_fluxpoints_0.0707654
# 6_fluxpoints_0.110385
# 6_fluxpoints_-0.00575058
# 6_fluxpoints_-0.0273726
# 6_fluxpoints_-0.0145885
# 6_fluxpoints_-0.167724
# 6_fluxpoints_0.0291935
# 6_fluxpoints_0.0105671
# 6_fluxpoints_0.0573492
# 6_fluxpoints_-0.0332799
# 6_fluxpoints_0.0975617
# 6_fluxpoints_-0.192442
# 6_fluxpoints_0.00993497
# 6_fluxpoints_0.00813782
# 6_fluxpoints_0.0860953
# 6_fluxpoints_0.18046
# 6_fluxpoints_-0.163233
# 6_fluxpoints_0.130911
# 6_fluxpoints_0.0259115
# 6_fluxpoints_-0.0620081
# 6_fluxpoints_-0.0053015
# 6_fluxpoints_0.00283211
# 6_fluxpoints_0.00481513
# 6_fluxpoints_0.00888033
# 6_fluxpoints_-0.062774
# 6_fluxpoints_-0.0624046
# 6_fluxpoints_0.184475
# 6_fluxpoints_0.241765
# 6_fluxpoints_0.0258456
# 6_fluxpoints_-0.225728
# 6_fluxpoints_0.0246613
# 6_fluxpoints_-0.0513694
# 6_fluxpoints_0.112082
# 6_fluxpoints_0.0524232
# 6_fluxpoints_-0.0942312
# 6_fluxpoints_0.043735
# 6_fluxpoints_-0.0464665
# 6_fluxpoints_-0.0220637
# 6_fluxpoints_-0.00331591
# 6_fluxpoints_-0.102417
# 6_fluxpoints_0.00912372
# 6_fluxpoints_0.0100444
# 6_fluxpoints_-0.0343612
# 6_fluxpoints_-0.109129
# 6_fluxpoints_0.0382261
# 6_fluxpoints_-0.0741563
# 6_fluxpoints_-0.106144
# 6_fluxpoints_-0.192563
# 6_fluxpoints_0.0359493
# 6_fluxpoints_-0.0634494
# 6_fluxpoints_-0.00536389
# 6_fluxpoints_0.00604037
# 6_fluxpoints_-0.058689
# 6_fluxpoints_-0.048035
# 6_fluxpoints_-0.115498
# 6_fluxpoints_-0.105181
# 6_fluxpoints_0.0549362
# 6_fluxpoints_-0.0499344
# 6_fluxpoints_0.0849929
# 6_fluxpoints_-0.00785029
# 6_fluxpoints_0.00981175
# 6_fluxpoints_0.109919
# 6_fluxpoints_-0.000330906
# 6_fluxpoints_-0.184746
# 6_fluxpoints_-0.0843861
# 6_fluxpoints_-0.0887826
# 6_fluxpoints_0.0713515
# 6_fluxpoints_-0.0274953
# 6_fluxpoints_0.0311113
# 6_fluxpoints_0.0416427
# 6_fluxpoints_0.121789
# 6_fluxpoints_-0.0548072
# 6_fluxpoints_-0.0817302
# 6_fluxpoints_0.115068
# 6_fluxpoints_0.0477384
# 6_fluxpoints_0.0446474
# 6_fluxpoints_0.019638
# 6_fluxpoints_0.0822537
# 6_fluxpoints_0.107424
# 6_fluxpoints_-0.0332652
# 6_fluxpoints_-0.0689076
# 6_fluxpoints_0.0227255
# 6_fluxpoints_-0.0191745
# 6_fluxpoints_-0.00735257
# 6_fluxpoints_-0.0346592
# 6_fluxpoints_-0.0307762
# 6_fluxpoints_-0.00879467
# 6_fluxpoints_-0.164893
# 6_fluxpoints_-0.00582795
# 6_fluxpoints_0.0579505
# 6_fluxpoints_0.0708422
# 6_fluxpoints_0.0531974
# 6_fluxpoints_-0.0428993
# 6_fluxpoints_0.116102
# 6_fluxpoints_-0.0727939
# 6_fluxpoints_0.00938591
# 6_fluxpoints_-0.0457051
# 6_fluxpoints_-0.0283829
# 6_fluxpoints_-0.0372426
# 6_fluxpoints_-0.0803897
# 6_fluxpoints_0.160162
# 6_fluxpoints_-0.1371
# 6_fluxpoints_-0.0426905
# 6_fluxpoints_-0.0685082
# 6_fluxpoints_-0.132116
# 6_fluxpoints_-0.0676008
# 6_fluxpoints_0.0183353
# 6_fluxpoints_-0.0884198
# 6_fluxpoints_-0.0646376
# 6_fluxpoints_0.032481
# 6_fluxpoints_-0.113174
# 6_fluxpoints_0.135531
# 6_fluxpoints_-0.0742134
# 6_fluxpoints_0.00886223
# 6_fluxpoints_0.0107675
# 6_fluxpoints_0.0470597
# 6_fluxpoints_0.0583799
# 6_fluxpoints_-0.126292
# 6_fluxpoints_0.0423883
# 6_fluxpoints_-0.130095
# 6_fluxpoints_-0.113626
# 6_fluxpoints_0.00240406
# 6_fluxpoints_0.0954391
# 6_fluxpoints_0.0412739
# 6_fluxpoints_-0.122017
# 6_fluxpoints_-0.067372
# 6_fluxpoints_-0.0147489
# 6_fluxpoints_-0.033468
# 6_fluxpoints_0.221995
# 6_fluxpoints_-0.0200235
# 6_fluxpoints_-0.111526
# 6_fluxpoints_-0.044853
# 6_fluxpoints_0.0502195
# 6_fluxpoints_0.0208399
# 6_fluxpoints_0.0155482
# 6_fluxpoints_0.0547318
# 6_fluxpoints_0.00310843
# 6_fluxpoints_0.00149404
# 6_fluxpoints_-0.04828
# 6_fluxpoints_0.0422706
# 6_fluxpoints_-0.00496809
# 6_fluxpoints_0.0537612
# 6_fluxpoints_0.0911326
# 6_fluxpoints_-0.0374634
# 6_fluxpoints_0.0375543
# 6_fluxpoints_-0.0525493
# 6_fluxpoints_-0.0829935
# 6_fluxpoints_-0.00677902
# 6_fluxpoints_0.0896309
# 6_fluxpoints_0.0133369
# 6_fluxpoints_0.054281
# 6_fluxpoints_-0.161296
# 6_fluxpoints_0.0729614
# 6_fluxpoints_0.019118
# 6_fluxpoints_-0.0386943
# 6_fluxpoints_0.0327135
# 6_fluxpoints_0.150079
# 6_fluxpoints_0.00978458
# 6_fluxpoints_-0.0129761
# 6_fluxpoints_-0.222145
# 6_fluxpoints_0.00364907
# 6_fluxpoints_-0.0358407
# 6_fluxpoints_0.0369467
# 6_fluxpoints_-0.0253713
# 6_fluxpoints_0.145347
# 6_fluxpoints_0.0542703
# 6_fluxpoints_0.082691
# 6_fluxpoints_0.0176701
# 6_fluxpoints_0.0471669
# 6_fluxpoints_0.110978
# 6_fluxpoints_-0.0516362
# 6_fluxpoints_0.0263608
# 6_fluxpoints_0.191095
# 6_fluxpoints_-0.00299728
# 6_fluxpoints_0.183556
# 6_fluxpoints_-0.140276
# 6_fluxpoints_0.044588
# 6_fluxpoints_0.14183
# 6_fluxpoints_0.0602198
# 6_fluxpoints_0.0368764
# 6_fluxpoints_-0.0727965
# 6_fluxpoints_-0.00799648
# 6_fluxpoints_-0.0418897
# 6_fluxpoints_0.0340343
# 6_fluxpoints_-0.0576894
# 6_fluxpoints_0.0372201
# 6_fluxpoints_-0.0251523
# 6_fluxpoints_-0.00966955
# 6_fluxpoints_0.0784108
# 6_fluxpoints_0.150649
# 6_fluxpoints_0.0941525
# 6_fluxpoints_-0.194184
# 6_fluxpoints_-0.016016
# 6_fluxpoints_-0.0968322
# 6_fluxpoints_0.00502435
# 6_fluxpoints_0.00315091
# 6_fluxpoints_0.0741349
# 6_fluxpoints_0.136244
# 6_fluxpoints_-0.21441
# 6_fluxpoints_-0.117929
# 6_fluxpoints_-0.0951055
# 6_fluxpoints_-0.0623716
# 6_fluxpoints_-0.0678927
# 6_fluxpoints_-0.0474612
# 6_fluxpoints_0.0801356
# 6_fluxpoints_-0.0980849
# 6_fluxpoints_0.128696
# 6_fluxpoints_-0.108522
# 6_fluxpoints_0.050143
# 6_fluxpoints_-0.0213635
# 6_fluxpoints_0.244103
# 6_fluxpoints_0.00656945
# 6_fluxpoints_-0.068836
# 6_fluxpoints_0.0302991
# 6_fluxpoints_0.115991
# 6_fluxpoints_0.125814
# 6_fluxpoints_-0.0796828
# 6_fluxpoints_0.106469
# 6_fluxpoints_0.0101956
# 6_fluxpoints_-0.162574
# 6_fluxpoints_0.0504444
# 6_fluxpoints_-0.14073
# 6_fluxpoints_-0.118643
# 6_fluxpoints_0.10889
# 6_fluxpoints_-0.108695
# 6_fluxpoints_-0.0997252
# 6_fluxpoints_-0.0366767
# 6_fluxpoints_0.0810706
# 6_fluxpoints_0.0370585
# 6_fluxpoints_0.0663999
# 6_fluxpoints_0.0336991
# 6_fluxpoints_-0.0613233
# 6_fluxpoints_0.0206658
# 6_fluxpoints_0.0498473
# 6_fluxpoints_0.0781902
# 6_fluxpoints_0.0772526
# 6_fluxpoints_-0.0628479
# 6_fluxpoints_0.0243009
# 6_fluxpoints_0.0591448
# 6_fluxpoints_-0.107749
# 6_fluxpoints_-0.0435546
# 6_fluxpoints_-0.000628388
# 6_fluxpoints_-0.0288663
# 6_fluxpoints_-0.0493348
# 6_fluxpoints_-0.177968
# 6_fluxpoints_0.0376687
# 6_fluxpoints_0.0703165
# 6_fluxpoints_0.0509109
# 6_fluxpoints_0.147579
# 6_fluxpoints_-0.18439
# 6_fluxpoints_0.0030701
# 6_fluxpoints_0.268552
# 6_fluxpoints_-0.049419
# 6_fluxpoints_-0.0618118
# 6_fluxpoints_0.0514815
# 6_fluxpoints_-0.00340874
# 6_fluxpoints_0.026234
# 6_fluxpoints_0.0370836
# 6_fluxpoints_0.015184
# 6_fluxpoints_-2.17099e-05
# 6_fluxpoints_-0.0617708
# 6_fluxpoints_0.102044
# 6_fluxpoints_-0.128587
# 6_fluxpoints_0.00422489
# 6_fluxpoints_-0.0298622
# 6_fluxpoints_-0.0575254
# 6_fluxpoints_0.105118
# 6_fluxpoints_-0.0991953
# 6_fluxpoints_-0.0198378
# 6_fluxpoints_-0.0275978
# 6_fluxpoints_-0.0437901
# 6_fluxpoints_0.0585191
# 6_fluxpoints_0.0966115
# 6_fluxpoints_0.0307243
# 6_fluxpoints_-0.085092
# 6_fluxpoints_-0.0472473
# 6_fluxpoints_-0.131122
# 6_fluxpoints_0.143167
# 6_fluxpoints_0.00338719
# 6_fluxpoints_-0.128674
# 6_fluxpoints_0.103581
# 6_fluxpoints_0.0302622
# 6_fluxpoints_0.0108073
# 6_fluxpoints_-0.00955071
# 6_fluxpoints_-0.044081
# 6_fluxpoints_0.0114896
# 6_fluxpoints_-0.0457509
# 6_fluxpoints_-0.0682756
# 6_fluxpoints_0.058503
# 6_fluxpoints_0.13805
# 6_fluxpoints_-0.017557
# 6_fluxpoints_0.153967
# 6_fluxpoints_0.0225687
# 6_fluxpoints_-0.0997562
# 6_fluxpoints_-0.049842
# 6_fluxpoints_0.168897
# 6_fluxpoints_0.00473888
# 6_fluxpoints_-0.0115815
# 6_fluxpoints_0.0761353
# 6_fluxpoints_-0.029231
# 6_fluxpoints_0.0875115
# 6_fluxpoints_0.0168459
# 6_fluxpoints_0.0145411
# 6_fluxpoints_0.0160032
# 6_fluxpoints_-0.0724463
# 6_fluxpoints_-0.0394524
# 6_fluxpoints_0.0839147
# 6_fluxpoints_0.115276
# 6_fluxpoints_-0.0743242
# 6_fluxpoints_-0.00135825
# 6_fluxpoints_0.0750708
# 6_fluxpoints_0.00999574
# 6_fluxpoints_0.0159972
# 6_fluxpoints_0.0690276
# 6_fluxpoints_0.036903
# 6_fluxpoints_-0.0447965
# 6_fluxpoints_0.0160355
# 6_fluxpoints_-0.0637313
# 6_fluxpoints_-0.115692
# 6_fluxpoints_0.0248621
# 6_fluxpoints_-0.00446497
# 6_fluxpoints_0.0504592
# 6_fluxpoints_-0.0360305
# 6_fluxpoints_0.0358108
# 6_fluxpoints_-0.105214
# 6_fluxpoints_0.0234649
# 6_fluxpoints_0.0495771
# 6_fluxpoints_-0.0528097
# 6_fluxpoints_0.00868287
# 6_fluxpoints_-0.0799073
# 6_fluxpoints_-0.0825482
# 6_fluxpoints_0.0299939
# 6_fluxpoints_0.0441833
# 6_fluxpoints_-0.0912068
# 6_fluxpoints_0.00646062
# 6_fluxpoints_0.0503555
# 6_fluxpoints_-0.14308
# 6_fluxpoints_-0.0358918
# 6_fluxpoints_-0.0364229
# 6_fluxpoints_0.0595498
# 6_fluxpoints_0.0694523
# 6_fluxpoints_-0.044229
# 6_fluxpoints_-0.0581902
# 6_fluxpoints_-0.0772146
# 6_fluxpoints_0.115052
# 6_fluxpoints_-0.0633083
# 6_fluxpoints_0.00431003
# 6_fluxpoints_-0.0268292
# 6_fluxpoints_0.00960862
# 6_fluxpoints_0.0507569
# 6_fluxpoints_0.0383124
# 6_fluxpoints_0.0470407
# 6_fluxpoints_0.0210428
# 6_fluxpoints_0.0524906
# 6_fluxpoints_0.0276463
# 6_fluxpoints_0.0519111
# 6_fluxpoints_0.0783008
# 6_fluxpoints_0.0465166
# 6_fluxpoints_-0.00965847
# 6_fluxpoints_0.0159883
# 6_fluxpoints_-0.0207504
# 6_fluxpoints_-0.00747912
# 6_fluxpoints_-0.111993
# 6_fluxpoints_0.0294281
# 6_fluxpoints_0.0723933
# 6_fluxpoints_0.027751
# 6_fluxpoints_0.0304529
# 6_fluxpoints_0.0224462
# 6_fluxpoints_-0.0423806
# 6_fluxpoints_0.0366656
# 6_fluxpoints_-0.174049
# 6_fluxpoints_-0.0800401
# 6_fluxpoints_0.167524
# 6_fluxpoints_-0.0999484
# 6_fluxpoints_-0.0844354
# 6_fluxpoints_-0.000596133
# 6_fluxpoints_0.0302353
# 6_fluxpoints_0.0145927
# 6_fluxpoints_-0.0362602
# 6_fluxpoints_0.0619917
# 6_fluxpoints_0.0109846
# 6_fluxpoints_0.00994213
# 6_fluxpoints_-0.154808
# 6_fluxpoints_0.0757244
# 6_fluxpoints_-0.0704464
# 6_fluxpoints_0.032009
# 6_fluxpoints_0.0204102
# 6_fluxpoints_-0.0637572
# 6_fluxpoints_-0.00290289
# 6_fluxpoints_0.0146141
# 6_fluxpoints_0.164655
# 6_fluxpoints_-0.0453248
# 6_fluxpoints_0.0966938
# 6_fluxpoints_-0.0173847
# 6_fluxpoints_0.00927834
# 6_fluxpoints_0.109282
# 6_fluxpoints_-0.042511
# 6_fluxpoints_-0.0259537
# 6_fluxpoints_0.116477
# 6_fluxpoints_0.00227554
# 6_fluxpoints_0.145347
# 6_fluxpoints_0.0174125
# 6_fluxpoints_0.0706642
# 6_fluxpoints_-0.00116456
# 6_fluxpoints_-0.0108729
# 6_fluxpoints_-0.00375589
# 6_fluxpoints_-0.0573718
# 6_fluxpoints_-0.00012803
# 6_fluxpoints_0.0121396
# 6_fluxpoints_-0.00661547
# 6_fluxpoints_-0.081032
# 6_fluxpoints_-0.1418
# 6_fluxpoints_-0.0768202
# 6_fluxpoints_0.0522189
# 6_fluxpoints_-0.0945684
# 6_fluxpoints_-0.0845712
# 6_fluxpoints_0.0563216
# 6_fluxpoints_0.0289256
# 6_fluxpoints_0.09974
# 6_fluxpoints_-0.0599102
# 6_fluxpoints_-0.0890719
# 6_fluxpoints_0.121888
# 6_fluxpoints_-0.116805
# 6_fluxpoints_0.00943068
# 6_fluxpoints_-0.0243672
# 6_fluxpoints_0.0793017
# 6_fluxpoints_-0.050584
# 6_fluxpoints_0.166175
# 6_fluxpoints_0.00811829
# 6_fluxpoints_0.0331311
# 6_fluxpoints_0.0757389
# 6_fluxpoints_0.0690854
# 6_fluxpoints_-0.114834
# 6_fluxpoints_-0.0840196
# 6_fluxpoints_-0.00714175
# 6_fluxpoints_-0.0945406
# 6_fluxpoints_0.0243423
# 6_fluxpoints_0.0760527
# 6_fluxpoints_0.04135
# 6_fluxpoints_0.018612
# 6_fluxpoints_0.195563
# 6_fluxpoints_-0.0960611
# 6_fluxpoints_0.00755016
# 6_fluxpoints_0.00339806
# 6_fluxpoints_-0.0823914
# 6_fluxpoints_-0.0777629
# 6_fluxpoints_-0.116518
# 6_fluxpoints_-0.0645525
# 6_fluxpoints_0.135232
# 6_fluxpoints_0.177122
# 6_fluxpoints_0.0393933
# 6_fluxpoints_-0.027706
# 6_fluxpoints_0.12606
# 6_fluxpoints_0.0944794
# 6_fluxpoints_0.00359612
# 6_fluxpoints_0.0644338
# 6_fluxpoints_-0.0626826
# 6_fluxpoints_0.12492
# 6_fluxpoints_0.0112618
# 6_fluxpoints_0.0111218
# 6_fluxpoints_0.0714286
# 6_fluxpoints_-0.0432879
# 6_fluxpoints_-0.0911139
# 6_fluxpoints_0.0688716
# 6_fluxpoints_-0.105309
# 6_fluxpoints_0.0123607
# 6_fluxpoints_-0.0387245
# 6_fluxpoints_0.0216481
# 6_fluxpoints_0.0685676
# 6_fluxpoints_0.00307722
# 6_fluxpoints_0.0346223
# 6_fluxpoints_0.0816836
# 6_fluxpoints_-0.000966989
# 6_fluxpoints_0.165057
# 6_fluxpoints_0.0122846
# 6_fluxpoints_0.0761652
# 6_fluxpoints_-0.030799
# 6_fluxpoints_-0.0935199
# 6_fluxpoints_0.0156244
# 6_fluxpoints_-0.0312853
# 6_fluxpoints_-0.0592583
# 6_fluxpoints_-0.0063299
# 6_fluxpoints_-0.0522347
# 6_fluxpoints_-0.0397834
# 6_fluxpoints_-0.0382121
# 6_fluxpoints_0.169755
# 6_fluxpoints_-0.0932819
# 6_fluxpoints_-0.0198432
# 6_fluxpoints_0.103158
# 6_fluxpoints_0.0424179
# 6_fluxpoints_-0.0116755
# 6_fluxpoints_-0.0178074
# 6_fluxpoints_-0.00511536
# 6_fluxpoints_0.0134064
# 6_fluxpoints_0.0304746
# 6_fluxpoints_0.0543859
# 6_fluxpoints_0.130789
# 6_fluxpoints_0.00441772
# 6_fluxpoints_0.0326995
# 6_fluxpoints_0.16458
# 6_fluxpoints_-0.0319144
# 6_fluxpoints_-0.0635619
# 6_fluxpoints_0.103501
# 6_fluxpoints_0.0695883
# 6_fluxpoints_0.0147356
# 6_fluxpoints_0.00341478
# 6_fluxpoints_0.00543633
# 6_fluxpoints_0.0785796
# 6_fluxpoints_-0.0192398
# 6_fluxpoints_-0.01491
# 6_fluxpoints_-0.129825
# 6_fluxpoints_0.0517516
# 6_fluxpoints_-0.0516586
# 6_fluxpoints_-0.00990319
# 6_fluxpoints_0.0218057
# 6_fluxpoints_-0.0587372
# 6_fluxpoints_0.0385884
# 6_fluxpoints_-0.0478425
# 6_fluxpoints_0.00628264
# 6_fluxpoints_-0.0248763
# 6_fluxpoints_0.0728569
# 6_fluxpoints_-0.0458087
# 6_fluxpoints_-0.0852196
# 6_fluxpoints_-0.089884
# 6_fluxpoints_0.0482701
# 6_fluxpoints_-0.0136263
# 6_fluxpoints_-0.131836
# 6_fluxpoints_-0.0789579
# 6_fluxpoints_0.169935
# 6_fluxpoints_-0.109191
# 808 808

# %%
sys_ = sys_dataset(dataset_asimov= dataset_asimov,
                        shift = 0, 
                        tilt = 0,
                        rnd = False)
dataset_asimov = sys_.create_dataset()
dataset_asimov_N = sys_.create_dataset_N()
zero = 1e-24
## additional parameter bias and resolution (ereco) but are frozen
penalising_invcovmatrix = np.zeros((4, 4))
np.fill_diagonal(penalising_invcovmatrix,
                 [1/shift**2, 1/tilt**2, 1/zero**2, 1/zero**2])
dataset_asimov_N.penalising_invcovmatrix = penalising_invcovmatrix


fit_cor = Fit(store_trace=False)
minuit_opts = {"tol": 0.001, "strategy": 2}
fit_cor.backend = "minuit"
fit_cor.optimize_opts = minuit_opts
result_cor = fit_cor.run([dataset_asimov])

fit_cor_N = Fit(store_trace=False)
minuit_opts = {"tol": 0.001, "strategy": 2}
fit_cor_N.backend = "minuit"
fit_cor_N.optimize_opts = minuit_opts
result_cor_N = fit_cor_N.run([dataset_asimov_N])

# %%
dataset_asimov_N.models[-1].parameters['norm_nuisance'].frozen = True
dataset_asimov_N.models[-1].parameters['tilt_nuisance'].frozen = True

# %%
mask = dataset_asimov.mask.data[:,60,60]
ebins = dataset_asimov.counts.geom.axes[0].center[mask]
energy_bounds = (ebins[0] , ebins[-1] ) *u.TeV

# %%
fig, (axs, ax1) = plt.subplots(1,2, figsize = (2*4,7/3))
nbins = 30
count, bins, ignored = axs.hist(shift_rnds, nbins, density=True, color = 'steelblue')
sigma =shift
mu = 0
axs.plot(bins, 1/(sigma * np.sqrt(2 * np.pi)) *
               np.exp( - (bins - mu)**2 / (2 * sigma**2) ),
         linewidth=2, color='r', label = f'$\mu = {mu}; \sigma = {sigma}$')

axs.set_xlabel("Systematic [%]")
axs.legend()

x = axs.get_xlim()
deltax = np.max([ mu - x[0] , x[1] - mu ])
axs.set_xlim(mu -deltax, 
                mu + deltax)


count, bins, ignored = ax1.hist(index_rnds, nbins, density=True, color = 'steelblue')
sigma =tilt
mu = 0
ax1.plot(bins, 1/(sigma * np.sqrt(2 * np.pi)) *
               np.exp( - (bins - mu)**2 / (2 * sigma**2) ),
         linewidth=2, color='r', label = f'$\mu = {mu}; \sigma = {sigma:.3}$')

ax1.set_xlabel("Systematic [%]")
ax1.set_title(f"N = {N}")
ax1.legend()

x = axs.get_xlim()
deltax = np.max([ mu - x[0] , x[1] - mu ])
axs.set_xlim(mu -deltax, 
                mu + deltax)
# Out:
# (-0.2932660375055615, 0.2932660375055615)

# %% [markdown]
# ## Compute Asimov Fluxpoints
#
# does not work because of the is_norm in the model

# %%
fluxpoints_asimov_N = FluxPoints.read("data/6_fluxpoints_asimov_N.fits")
fluxpoints_asimov = FluxPoints.read("data/6_fluxpoints_asimov.fits")

# %%
energy_edges = dataset_asimov.geoms['geom'].axes[0].edges

# %%
def plot_shifted (ff, shift):
    return ff.energy_ref* shift, ff.e2dnde.data[:,0,0],  ff.e2dnde_err.data[:,0,0],

# %%
fig, axs = plt.subplots(1,1, figsize = (6,4))
dataset_asimov_N.models[0].spectral_model.plot_error(energy_bounds,  energy_power = 2, ax = axs,
                                label = "$1\sigma$ Nuisance", facecolor = "green", alpha = 0.5)    
    
dataset_asimov.models[0].spectral_model.plot_error(energy_bounds,  energy_power = 2, ax = axs,
                                label = "$1\sigma$ Standard", facecolor = "red", alpha = 0.6)

dataset_asimov.models[0].spectral_model.plot(energy_bounds, linestyle=':', energy_power = 2, ax = axs,
                                label = "Input", color = "black", )




e_, f_, ferr_ = plot_shifted(fluxpoints_asimov, 1.1)
axs.errorbar(e_, f_, yerr = ferr_, color = 'darkred', fmt='o')  

e_, f_, ferr_ = plot_shifted(fluxpoints_asimov_N, 1.)
axs.errorbar(e_, f_, yerr = ferr_, color = 'darkgreen', fmt='o')  


axs.legend()
axs.set_title(f"N = {N}")
plt.tight_layout()

# %%
mask2 = fluxpoints[0].ts.data[:,0,0].data > 4
mask2

fluxpoints[0].ts.data[:,0,0].mask = mask2

# %%
e2dnde = []

for f in fluxpoints:
    mask2 = f.ts.data[:,0,0].data > 4
    e2dnde.append(f.e2dnde.data[:,0,0])
e2dnde = np.array(e2dnde)

# %%
fig, axs1 = plt.subplots(1,1,figsize = (6,4) )
for f,e  in zip(fluxpoints,e2dnde):
    axs1.plot(f.energy_ref* 1.0, e    , color = 'black', alpha = 0.01)
    
axs1.errorbar(f.energy_ref, e2dnde.mean(axis = 0), yerr = e2dnde.std(axis=0) , 
              label = "$\mu$, $\sigma$"
            )

dataset_asimov.models[0].spectral_model.plot(energy_bounds, linestyle=':', energy_power = 2, ax = axs1,
                                label = "Input", color = "black", )
ylim = axs.get_ylim()
axs1.set_ylim(ylim[0], ylim[1])
axs1.loglog()
axs1.set_title(f"N = {N}")
axs1.legend()
plt.tight_layout()

if savefig:
    fig.savefig(f"plots/7d_fluxpoints_rnd_{factor}_{N}." + picformat)

# %%
def fraction_within_e(lower_lim, upper_lim, data):
    withine = []
    for ie in range(len(lower_lim)):
        xs = []
        for f in data:
            value = f[ie]   
            lowerlim = (np.all(value >= lower_lim[ie]))
            upperlim = (np.all(value <= upper_lim[ie]))
            x = lowerlim & upperlim
            xs.append(x)
        withine.append(np.count_nonzero(xs) / len(data))
    withine  = np.array(withine)
    return withine[withine>0]

# %%
e_, f_, ferr_ = plot_shifted(fluxpoints_asimov, 1.05)
within_e = fraction_within_e(f_-ferr_ , f_ + ferr_, e2dnde)

e_, f_, ferr_ = plot_shifted(fluxpoints_asimov_N, 1.05)
within_eN = fraction_within_e(f_-ferr_ , f_ + ferr_, e2dnde)
within_eN
# Out:
# array([0.69925743, 0.70420792, 0.68564356, 0.7029703 , 0.70915842,
#        0.65841584, 0.64356436, 0.67450495, 0.68193069, 0.68811881,
#        0.6720297 , 0.62871287, 0.68440594, 0.69678218, 0.7289604 ,
#        0.69306931, 0.63737624, 0.52846535])

# %%
def compute_precision(N):
    Z = 1.645
    return  Z / np.sqrt(N)
p = compute_precision(N)

# %%
fig, (axs, ax2) = plt.subplots(2,1, gridspec_kw={'height_ratios': [3, 2]},
                         sharex = True, figsize = ((5,5)))

dataset_asimov_N.models[0].spectral_model.plot_error(energy_bounds,  energy_power = 2, ax = axs,
                                label = "", facecolor = "green", alpha = 0.5)    
    
dataset_asimov.models[0].spectral_model.plot_error(energy_bounds,  energy_power = 2, ax = axs,
                                label = "", facecolor = "red", alpha = 0.6)

dataset_asimov.models[0].spectral_model.plot(energy_bounds, linestyle=':', energy_power = 2, ax = axs,
                                label = "Input", color = "black", )

e_, f_, ferr_ = plot_shifted(fluxpoints_asimov_N, 1.)
axs.errorbar(e_, f_, yerr = ferr_, color = 'darkgreen', fmt='x', label = "Fluxpoints Nuisance")  

e_, f_, ferr_ = plot_shifted(fluxpoints_asimov, 1.05)
axs.errorbar(e_, f_, yerr = ferr_, color = 'darkred', fmt='x', label = "Fluxpoints Standard")  



axs.errorbar(f.energy_ref* 1.1, e2dnde.mean(axis = 0), yerr = e2dnde.std(axis=0) , 
                 label = "$\mu$, $\sigma$")


ax2.errorbar(ebins, within_e, yerr=p,color = 'red', label = f"Standard ")
ax2.errorbar(ebins, within_eN,yerr=p, color = 'green', label = "Nuisance")
ax2.plot(ebins, [0.68] * len(ebins), ':', color = 'green', label = "68 %")

axs.set_xlabel('')
axs.legend()
ax2.legend()
axs.set_title(f"N = {N}; (p={p:.2})")
ax2.set_xlabel('Energy [TeV]')
ax2.set_ylabel('Coverage')

axs.set_xlabel('')
axs.legend()

plt.tight_layout()
if savefig:
    fig.savefig(f"plots/7d_fluxpoints_coverage_{shift}_{N}." + picformat)
